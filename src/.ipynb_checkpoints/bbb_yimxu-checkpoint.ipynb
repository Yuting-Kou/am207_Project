# %% [markdown]
# # Name
#
# Yuting Kou, Yizhou Wang, Yiming Xu, Ziyi Zhou
#
# ## Content
#
# ## Method

# %% [markdown]
# ## Toy Example

# %%
import matplotlib.pyplot as plt
from autograd import numpy as np
import time
from Inference import Inference
from Subspace import Subspace
from model import Model
from util import hidecode
# hidecode()            % --------- remember to remove comments after finishing all the code. This function can simplify the code

# %%
# data = np.load(r'.\example\data.npy')
data = np.genfromtxt(r'../example/hw7_data.csv', delimiter=',')[1:]
x, y = data[:, 0], data[:, 1]

alpha = 1
c = 0
h = lambda x: np.exp(-alpha * (x - c)**2)

###neural network model design choices
width = 5
hidden_layers = 1
input_dim = 1
output_dim = 1

architecture = {'width': width,
               'hidden_layers': hidden_layers,
               'input_dim': input_dim,
               'output_dim': output_dim,
               'activation_fn_type': 'rbf',
               'activation_fn_params': 'c=0, alpha=1',
               'activation_fn': h}

# set random state to make the experiments replicable
rand_state = 0
random = np.random.RandomState(rand_state)

# create a model and train the model
my_nn = Model.create(submodel_type="Feedforward", architecture=architecture, Sigma_Y=0.25)

# use MSE result as params_init
params = {'step_size':1e-3, 
          'max_iteration':5000, 
          'random_restarts':1}

# fit my neural network to minimize MSE on the given data
my_nn.fit(x_train=x.reshape((1, -1)), y_train=y.reshape((1, -1)), params=params)
# Out:
# Iteration 0 lower bound 65.1166805377315; gradient mag: 164.7321094609157
# Iteration 100 lower bound 52.86436046756695; gradient mag: 56.954586390884565
# Iteration 200 lower bound 49.42633385370295; gradient mag: 28.31627548203755
# Iteration 300 lower bound 47.73326189562314; gradient mag: 18.311751879565836
# Iteration 400 lower bound 46.647745693540806; gradient mag: 13.47755254054697
# Iteration 500 lower bound 45.88691542805831; gradient mag: 10.503599898310592
# Iteration 600 lower bound 45.25067576634; gradient mag: 8.654932255566825
# Iteration 700 lower bound 30.562858257343013; gradient mag: 24.192575322800902
# Iteration 800 lower bound 26.97792508592485; gradient mag: 20.35417699419094
# Iteration 900 lower bound 24.278363637665734; gradient mag: 18.779125916898224
# Iteration 1000 lower bound 22.02986716940495; gradient mag: 17.427416991221943
# Iteration 1100 lower bound 20.10610040886032; gradient mag: 16.21045518866592
# Iteration 1200 lower bound 18.434367471681025; gradient mag: 15.092044558814077
# Iteration 1300 lower bound 16.967826824623163; gradient mag: 14.051620576729908
# Iteration 1400 lower bound 15.673763205688543; gradient mag: 13.07650688789188
# Iteration 1500 lower bound 14.527850196693981; gradient mag: 12.15858303432993
# Iteration 1600 lower bound 13.511041180892443; gradient mag: 11.2926913337729
# Iteration 1700 lower bound 12.607737627992941; gradient mag: 10.475901826346679
# Iteration 1800 lower bound 11.804614404003857; gradient mag: 9.707342852428729
# Iteration 1900 lower bound 11.08977327305976; gradient mag: 8.988599356616405
# Iteration 2000 lower bound 10.452003162028157; gradient mag: 8.324954075223923
# Iteration 2100 lower bound 9.879926845203451; gradient mag: 7.728107510229666
# Iteration 2200 lower bound 9.360728932888753; gradient mag: 7.221146412450928
# Iteration 2300 lower bound 8.878118698993095; gradient mag: 6.843182251011432
# Iteration 2400 lower bound 8.41037187354601; gradient mag: 6.627021939587407
# Iteration 2500 lower bound 7.937214402172415; gradient mag: 6.461888287390538
# Iteration 2600 lower bound 7.471807925987624; gradient mag: 6.054967192028709
# Iteration 2700 lower bound 7.048560738747637; gradient mag: 5.623261826592472
# Iteration 2800 lower bound 6.657649714610486; gradient mag: 5.30159601548905
# Iteration 2900 lower bound 6.286937924356821; gradient mag: 5.005817266509643
# Iteration 3000 lower bound 5.932348941430826; gradient mag: 4.738230196194088
# Iteration 3100 lower bound 5.591133620620948; gradient mag: 4.496972816298516
# Iteration 3200 lower bound 5.261275455408112; gradient mag: 4.278187646372163
# Iteration 3300 lower bound 4.941457959341479; gradient mag: 4.078179065269134
# Iteration 3400 lower bound 4.6310060561160205; gradient mag: 3.8933742950112142
# Iteration 3500 lower bound 4.329797769584354; gradient mag: 3.7204132445853815
# Iteration 3600 lower bound 4.038157311705764; gradient mag: 3.5562692067094717
# Iteration 3700 lower bound 3.756740063917854; gradient mag: 3.398336991338034
# Iteration 3800 lower bound 3.4864181903710856; gradient mag: 3.244478137088561
# Iteration 3900 lower bound 3.228173818091556; gradient mag: 3.0930278431838527
# Iteration 4000 lower bound 2.9830049840819997; gradient mag: 2.942772921229375
# Iteration 4100 lower bound 2.751847662450035; gradient mag: 2.792911369621929
# Iteration 4200 lower bound 2.5355150988915525; gradient mag: 2.643003494153076
# Iteration 4300 lower bound 2.334653699118806; gradient mag: 2.4929221870323555
# Iteration 4400 lower bound 2.149713314288466; gradient mag: 2.3428066637339144
# Iteration 4500 lower bound 1.9809292604652156; gradient mag: 2.193020647459892
# Iteration 4600 lower bound 1.8283137632422382; gradient mag: 2.04411366275006
# Iteration 4700 lower bound 1.691655364964972; gradient mag: 1.8967832576590287
# Iteration 4800 lower bound 1.570525681259662; gradient mag: 1.751836469573031
# Iteration 4900 lower bound 1.4642933738374682; gradient mag: 1.6101500586762456

# %%
x_test = np.linspace(-10, 10, 1000).reshape(1,-1)
y_test = my_nn.forward(x_test, use_subweights = False, weights = my_nn.weights)[0]
plt.scatter(x, y, alpha = 0.3)
plt.plot(x_test[0], y_test[0], color = 'red')
plt.xlabel('X')
plt.ylabel('Y');

# %%
output_noise = 0.5**2
def log_likelihood(y_actual, y_pred):
    return -0.5 * np.log(2 * np.pi * output_noise) - 0.5 * np.mean(((y_actual - y_pred)**2).sum(axis = 1)) / output_noise

# %% [markdown]
# ## random

# %%
my_subspace = Subspace.create(subspace_type="random", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y)
P, w = my_subspace.get_space()

# %%
bbb_tune_params= {'step_size': 5e-3,
                                'S': 2000,
                                'max_iteration': 5000,
                                'checkpoint': 200,
                                'verbose': True,
                                'position_init': None,
                                  'random_restart':1,
                                'init_var': np.exp(-10)}

# %%
my_inference = Inference.create(inference_type="BBB", model=my_nn, P=P, w_hat=w,  tune_params=bbb_tune_params,
                               Sigma_Z=25)

# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init,analytic_entropy=True, softplus=True)
end=time.time()
# Out:
# Iteration 0 lower bound -232.66604669344542; gradient mag: 45.808465203393816
# Iteration 200 lower bound -230.07953540509942; gradient mag: 29.43934795073935
# Iteration 400 lower bound -76.09349775354242; gradient mag: 73.22674525079118
# Iteration 600 lower bound -21.576066921485328; gradient mag: 35.462559525794106
# Iteration 800 lower bound -14.12758798511567; gradient mag: 13.347864457759039
# Iteration 1000 lower bound -11.64893469427354; gradient mag: 15.259379940447444
# Iteration 1200 lower bound -10.665002518039731; gradient mag: 10.552381192544216
# Iteration 1400 lower bound -10.032828582832195; gradient mag: 19.649650163659384
# Iteration 1600 lower bound -9.846809107202672; gradient mag: 12.198191400773203
# Iteration 1800 lower bound -9.483848885262919; gradient mag: 6.23506967580185
# Iteration 2000 lower bound -9.402223124385957; gradient mag: 2.0704350288459423
# Iteration 2200 lower bound -9.305625446642027; gradient mag: 11.125675418782603
# Iteration 2400 lower bound -9.23911558515756; gradient mag: 17.5755503995549
# Iteration 2600 lower bound -9.14777347997899; gradient mag: 2.324954281138844
# Iteration 2800 lower bound -9.092289022677889; gradient mag: 8.54801056674041
# Iteration 3000 lower bound -9.128102692592943; gradient mag: 17.74813431784022
# Iteration 3200 lower bound -9.058073253052399; gradient mag: 4.083827945216994
# Iteration 3400 lower bound -9.074152635244452; gradient mag: 4.78286067628457
# Iteration 3600 lower bound -9.088884000422095; gradient mag: 3.6243824805271467
# Iteration 3800 lower bound -9.0572296035063; gradient mag: 14.255952301696741
# Iteration 4000 lower bound -9.052874807695895; gradient mag: 5.1754969615973945
# Iteration 4200 lower bound -9.05573215227628; gradient mag: 8.681685510795027
# Iteration 4400 lower bound -9.040871360755299; gradient mag: 2.0380636157991177
# Iteration 4600 lower bound -9.017939547971737; gradient mag: 10.00743997663073
# Iteration 4800 lower bound -9.045333259576562; gradient mag: 8.922654066366231

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 10.56 min

# %%
fig, ax = plt.subplots(1,2, figsize=(20,5))
ax[0].plot(my_inference.ELBO)
ax[0].set_xlabel('Iteration')
ax[0].set_ylabel('ELBO')

ax[1].plot(my_inference.ELBO[-1000:])
ax[1].set_xlabel('Iteration (Last 1000)')
ax[1].set_ylabel('ELBO');

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |BBB')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|BBB')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
# check for convergence
post_sample=my_inference.get_posterior(n_samples=10000)
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
for i in range(my_inference.D_z):
#     row = 1
    col = i % 2
    ax[col].plot(range(len(post_sample)), post_sample[:, i], color='gray', alpha=0.7)
fig.suptitle('Trace plots for all neural network parameters')
plt.show()

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_random = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_random))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -58.2702

# %% [markdown]
# ## PCA

# %%
my_subspace = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y)
P, w = my_subspace.get_space()

# %%
bbb_tune_params= {'step_size': 5e-3,
                                'S': 2000,
                                'max_iteration': 5000,
                                'checkpoint': 200,
                                'verbose': True,
                                'position_init': None,
                                  'random_restart':1,
                                'init_var': np.exp(-10)}

# %%
my_inference = Inference.create(inference_type="BBB", model=my_nn, P=P, w_hat=w,  tune_params=bbb_tune_params,
                               Sigma_Z=5)
# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

# %%
begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init,analytic_entropy=True, softplus=True)
end=time.time()
# Out:
# Iteration 0 lower bound -15.281148235602133; gradient mag: 4.772889881790363
# Iteration 200 lower bound -10.668284438554197; gradient mag: 3.8310108733805235
# Iteration 400 lower bound -7.614380127248929; gradient mag: 2.9965357756826423
# Iteration 600 lower bound -5.72497381187767; gradient mag: 2.321737930822825
# Iteration 800 lower bound -4.402285744900138; gradient mag: 1.6895134158145582
# Iteration 1000 lower bound -3.684586806107648; gradient mag: 1.1929098341183706
# Iteration 1200 lower bound -3.282277819296061; gradient mag: 0.7912933654147407
# Iteration 1400 lower bound -3.0987094372412636; gradient mag: 0.5652030991407123
# Iteration 1600 lower bound -3.0156486866114705; gradient mag: 0.32457791801676616
# Iteration 1800 lower bound -2.9625106146882394; gradient mag: 0.16017547052615386
# Iteration 2000 lower bound -2.9720874231718986; gradient mag: 0.14857984409851285
# Iteration 2200 lower bound -2.972496341439494; gradient mag: 0.04789098261750999
# Iteration 2400 lower bound -2.955238314322248; gradient mag: 0.0780099063978944
# Iteration 2600 lower bound -2.94854726618159; gradient mag: 0.010048741288311602
# Iteration 2800 lower bound -2.944460842421882; gradient mag: 0.021697609891820787
# Iteration 3000 lower bound -2.974454860822717; gradient mag: 0.025374861347984282
# Iteration 3200 lower bound -2.9432260675019983; gradient mag: 0.03765086825352436
# Iteration 3400 lower bound -2.981120761696139; gradient mag: 0.02534344847458031
# Iteration 3600 lower bound -2.976231518574854; gradient mag: 0.04831724045550169
# Iteration 3800 lower bound -2.975619761137458; gradient mag: 0.016770069245337617
# Iteration 4000 lower bound -2.9579386250734516; gradient mag: 0.03365685710579276
# Iteration 4200 lower bound -2.9749280242190514; gradient mag: 0.03273717072664961
# Iteration 4400 lower bound -2.945058334183594; gradient mag: 0.010628826093556304
# Iteration 4600 lower bound -2.930743828876997; gradient mag: 0.04747319296192152
# Iteration 4800 lower bound -2.978517342490508; gradient mag: 0.04818769010865191

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 8.75 min

# %%
fig, ax = plt.subplots(1,2, figsize=(20,5))
ax[0].plot(my_inference.ELBO)
ax[0].set_xlabel('Iteration')
ax[0].set_ylabel('ELBO')

ax[1].plot(my_inference.ELBO[-2000:])
ax[1].set_xlabel('Iteration (Last 2000)')
ax[1].set_ylabel('ELBO');

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |BBB')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|BBB')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
# check for convergence
post_sample=my_inference.get_posterior(n_samples=10000)
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
for i in range(my_inference.D_z):
#     row = 1
    col = i % 2
    ax[col].plot(range(len(post_sample)), post_sample[:, i], color='gray', alpha=0.7)
fig.suptitle('Trace plots for all neural network parameters')
plt.show()

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_pca = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_pca))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -2.7449

# %% [markdown]
# ## PCA (extension)
#
# (The documentation is written in hmc_yimxu)

# %% [markdown]
# ### the smallest deviations

# %%
my_subspace = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y, method='S') # chose the method as L
P, w = my_subspace.get_space()

# %%
bbb_tune_params= {'step_size': 5e-3,
                                'S': 2000,
                                'max_iteration': 5000,
                                'checkpoint': 200,
                                'verbose': True,
                                'position_init': None,
                                  'random_restart':1,
                                'init_var': np.exp(-10)}

# %%
my_inference = Inference.create(inference_type="BBB", model=my_nn, P=P, w_hat=w,  tune_params=bbb_tune_params,
                               Sigma_Z=5)
# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

# %%
begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init,analytic_entropy=True, softplus=True)
end=time.time()
# Out:
# Iteration 0 lower bound -26.84587744389261; gradient mag: 9.123947310884923
# Iteration 200 lower bound -18.181595534637253; gradient mag: 7.985910722190474
# Iteration 400 lower bound -11.762881247843733; gradient mag: 6.442521957678777
# Iteration 600 lower bound -7.617388553340697; gradient mag: 4.589879239749125
# Iteration 800 lower bound -5.345924666255337; gradient mag: 3.195551288409141
# Iteration 1000 lower bound -4.099960016033984; gradient mag: 2.0546461431749243
# Iteration 1200 lower bound -3.516178867385201; gradient mag: 1.3195445222842268
# Iteration 1400 lower bound -3.261096012876015; gradient mag: 0.7510749809718028
# Iteration 1600 lower bound -3.20187944514491; gradient mag: 0.4123342329440724
# Iteration 1800 lower bound -3.146621305004204; gradient mag: 0.20208219967084923
# Iteration 2000 lower bound -3.1455260339754605; gradient mag: 0.10320579947881874
# Iteration 2200 lower bound -3.1460281502742733; gradient mag: 0.07108958736686433
# Iteration 2400 lower bound -3.1579999209751124; gradient mag: 0.1079752397664969
# Iteration 2600 lower bound -3.1441769210916437; gradient mag: 0.038272276032265615
# Iteration 2800 lower bound -3.1233147631163254; gradient mag: 0.03791194376533859
# Iteration 3000 lower bound -3.1468315590901597; gradient mag: 0.02695443885081596
# Iteration 3200 lower bound -3.125379167425548; gradient mag: 0.018176715223586853
# Iteration 3400 lower bound -3.1342178805837637; gradient mag: 0.042879429810819304
# Iteration 3600 lower bound -3.1722928018785423; gradient mag: 0.04567674635525687
# Iteration 3800 lower bound -3.1430901189061276; gradient mag: 0.0315229597106466
# Iteration 4000 lower bound -3.1488765112790444; gradient mag: 0.04023955888223245
# Iteration 4200 lower bound -3.1446319075144213; gradient mag: 0.06188540818129885
# Iteration 4400 lower bound -3.140440495889325; gradient mag: 0.042564786859585466
# Iteration 4600 lower bound -3.10619238324478; gradient mag: 0.03427807051886565
# Iteration 4800 lower bound -3.130902456216705; gradient mag: 0.04936167910344111

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 10.37 min

# %%
fig, ax = plt.subplots(1,2, figsize=(20,5))
ax[0].plot(my_inference.ELBO)
ax[0].set_xlabel('Iteration')
ax[0].set_ylabel('ELBO')

ax[1].plot(my_inference.ELBO[-2000:])
ax[1].set_xlabel('Iteration (Last 2000)')
ax[1].set_ylabel('ELBO');

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |BBB')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|BBB')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
# check for convergence
post_sample=my_inference.get_posterior(n_samples=10000)
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
for i in range(my_inference.D_z):
#     row = 1
    col = i % 2
    ax[col].plot(range(len(post_sample)), post_sample[:, i], color='gray', alpha=0.7)
fig.suptitle('Trace plots for all neural network parameters')
plt.show()

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_pca_smallest = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_pca_smallest))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -2.9177

# %% [markdown]
# ### the largest deviations

# %%
my_subspace = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y, method='L') # chose the method as L
P, w = my_subspace.get_space()

# %%
bbb_tune_params= {'step_size': 5e-3,
                                'S': 2000,
                                'max_iteration': 5000,
                                'checkpoint': 200,
                                'verbose': True,
                                'position_init': None,
                                  'random_restart':1,
                                'init_var': np.exp(-10)}

# %%
my_inference = Inference.create(inference_type="BBB", model=my_nn, P=P, w_hat=w,  tune_params=bbb_tune_params,
                               Sigma_Z=5)
# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

# %%
begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init,analytic_entropy=True, softplus=True)
end=time.time()
# Out:
# Iteration 0 lower bound -199.12934154078323; gradient mag: 82.03401247386195
# Iteration 200 lower bound -157.1527919565324; gradient mag: 50.80702251359754
# Iteration 400 lower bound -42.86363700908911; gradient mag: 46.21886306654061
# Iteration 600 lower bound -16.495351484831204; gradient mag: 20.1321789517726
# Iteration 800 lower bound -11.344672197307125; gradient mag: 8.698107712859672
# Iteration 1000 lower bound -9.366659564856082; gradient mag: 8.958946126824687
# Iteration 1200 lower bound -8.51987520246681; gradient mag: 5.686214839204961
# Iteration 1400 lower bound -8.022688094962344; gradient mag: 6.480032400602905
# Iteration 1600 lower bound -7.757357939613922; gradient mag: 4.290413330438235
# Iteration 1800 lower bound -7.504616365745962; gradient mag: 3.057850267808513
# Iteration 2000 lower bound -7.437425302962084; gradient mag: 4.826399937283748
# Iteration 2200 lower bound -7.363482481150301; gradient mag: 3.0773683332255874
# Iteration 2400 lower bound -7.261795069392591; gradient mag: 5.599120433043171
# Iteration 2600 lower bound -7.210827274286402; gradient mag: 1.6128347745578924
# Iteration 2800 lower bound -7.188580967945177; gradient mag: 2.604823044394606
# Iteration 3000 lower bound -7.217950464054448; gradient mag: 2.7608207126452533
# Iteration 3200 lower bound -7.1563767810718675; gradient mag: 2.1820621114855028
# Iteration 3400 lower bound -7.214100775607431; gradient mag: 5.330838487895569
# Iteration 3600 lower bound -7.181681236608647; gradient mag: 5.171910324477833
# Iteration 3800 lower bound -7.18225467151508; gradient mag: 1.2220401910661993
# Iteration 4000 lower bound -7.157774190584297; gradient mag: 3.8783724150236067
# Iteration 4200 lower bound -7.178903701543179; gradient mag: 1.2975994292097488
# Iteration 4400 lower bound -7.140951024062036; gradient mag: 1.287684967314634
# Iteration 4600 lower bound -7.133110540751963; gradient mag: 5.3403039974873385
# Iteration 4800 lower bound -7.183327320756419; gradient mag: 0.41087380753924424

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 10.49 min

# %%
fig, ax = plt.subplots(1,2, figsize=(20,5))
ax[0].plot(my_inference.ELBO)
ax[0].set_xlabel('Iteration')
ax[0].set_ylabel('ELBO')

ax[1].plot(my_inference.ELBO[-1000:])
ax[1].set_xlabel('Iteration (Last 1000)')
ax[1].set_ylabel('ELBO');

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |BBB')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|BBB')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
# check for convergence
post_sample=my_inference.get_posterior(n_samples=10000)
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
for i in range(my_inference.D_z):
#     row = 1
    col = i % 2
    ax[col].plot(range(len(post_sample)), post_sample[:, i], color='gray', alpha=0.7)
fig.suptitle('Trace plots for all neural network parameters')
plt.show()

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_pca_largest = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_pca_largest))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -45.7271
