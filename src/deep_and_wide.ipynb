# %% [markdown]
# # Name
#
# Yuting Kou, Yizhou Wang, Yiming Xu, Ziyi Zhou
#
# ## Content
#
# ## Method

# %% [markdown]
# ## Toy Example

# %%
import matplotlib.pyplot as plt
from autograd import numpy as np
import time
from Inference import Inference
from Subspace import Subspace
from model import Model
from util import hidecode
# hidecode()            % --------- remember to remove comments after finishing all the code. This function can simplify the code

# %%
# data = np.load(r'.\example\data.npy')
data = np.genfromtxt(r'../example/hw7_data.csv', delimiter=',')[1:]
x, y = data[:, 0], data[:, 1]

alpha = 1
c = 0
h = lambda x: np.exp(-alpha * (x - c)**2)

###neural network model design choices
width = 5
hidden_layers = 1
input_dim = 1
output_dim = 1

architecture = {'width': width,
               'hidden_layers': hidden_layers,
               'input_dim': input_dim,
               'output_dim': output_dim,
               'activation_fn_type': 'rbf',
               'activation_fn_params': 'c=0, alpha=1',
               'activation_fn': h}

# set random state to make the experiments replicable
rand_state = 0
random = np.random.RandomState(rand_state)

# create a model and train the model
my_nn_1_5 = Model.create(submodel_type="Feedforward", architecture=architecture, Sigma_Y=0.25)

# use MSE result as params_init
params = {'step_size':1e-3, 
          'max_iteration':5000, 
          'random_restarts':1}

# fit my neural network to minimize MSE on the given data
my_nn_1_5.fit(x_train=x.reshape((1, -1)), y_train=y.reshape((1, -1)), params=params)
# Out:
# Iteration 0 lower bound 65.1166805377315; gradient mag: 164.73210946091572
# Iteration 100 lower bound 52.86436046756695; gradient mag: 56.95458639088454
# Iteration 200 lower bound 49.42633385370295; gradient mag: 28.31627548203755
# Iteration 300 lower bound 47.73326189562313; gradient mag: 18.31175187956584
# Iteration 400 lower bound 46.647745693540806; gradient mag: 13.47755254054697
# Iteration 500 lower bound 45.88691542805831; gradient mag: 10.503599898310593
# Iteration 600 lower bound 45.25067576634; gradient mag: 8.654932255566825
# Iteration 700 lower bound 30.562858257343006; gradient mag: 24.19257532280088
# Iteration 800 lower bound 26.97792508592485; gradient mag: 20.354176994190933
# Iteration 900 lower bound 24.27836363766573; gradient mag: 18.77912591689822
# Iteration 1000 lower bound 22.029867169404945; gradient mag: 17.427416991221943
# Iteration 1100 lower bound 20.106100408860318; gradient mag: 16.21045518866592
# Iteration 1200 lower bound 18.43436747168103; gradient mag: 15.092044558814075
# Iteration 1300 lower bound 16.967826824623163; gradient mag: 14.051620576729906
# Iteration 1400 lower bound 15.673763205688541; gradient mag: 13.07650688789188
# Iteration 1500 lower bound 14.527850196693977; gradient mag: 12.158583034329933
# Iteration 1600 lower bound 13.51104118089244; gradient mag: 11.292691333772902
# Iteration 1700 lower bound 12.60773762799294; gradient mag: 10.475901826346677
# Iteration 1800 lower bound 11.804614404003853; gradient mag: 9.70734285242872
# Iteration 1900 lower bound 11.08977327305976; gradient mag: 8.988599356616401
# Iteration 2000 lower bound 10.452003162028152; gradient mag: 8.324954075223916
# Iteration 2100 lower bound 9.87992684520345; gradient mag: 7.728107510229662
# Iteration 2200 lower bound 9.36072893288875; gradient mag: 7.221146412450923
# Iteration 2300 lower bound 8.87811869899309; gradient mag: 6.843182251011428
# Iteration 2400 lower bound 8.410371873546007; gradient mag: 6.627021939587406
# Iteration 2500 lower bound 7.937214402172413; gradient mag: 6.461888287390534
# Iteration 2600 lower bound 7.471807925987622; gradient mag: 6.054967192028711
# Iteration 2700 lower bound 7.048560738747637; gradient mag: 5.6232618265924685
# Iteration 2800 lower bound 6.657649714610485; gradient mag: 5.301596015489046
# Iteration 2900 lower bound 6.2869379243568195; gradient mag: 5.005817266509644
# Iteration 3000 lower bound 5.932348941430822; gradient mag: 4.73823019619409
# Iteration 3100 lower bound 5.591133620620948; gradient mag: 4.4969728162985145
# Iteration 3200 lower bound 5.261275455408108; gradient mag: 4.278187646372163
# Iteration 3300 lower bound 4.941457959341477; gradient mag: 4.0781790652691345
# Iteration 3400 lower bound 4.631006056116017; gradient mag: 3.8933742950112165
# Iteration 3500 lower bound 4.329797769584348; gradient mag: 3.720413244585376
# Iteration 3600 lower bound 4.038157311705761; gradient mag: 3.556269206709468
# Iteration 3700 lower bound 3.7567400639178508; gradient mag: 3.3983369913380352
# Iteration 3800 lower bound 3.486418190371085; gradient mag: 3.2444781370885365
# Iteration 3900 lower bound 3.2281738180915527; gradient mag: 3.093027843183847
# Iteration 4000 lower bound 2.9830049840819948; gradient mag: 2.9427729212293774
# Iteration 4100 lower bound 2.751847662450033; gradient mag: 2.792911369621913
# Iteration 4200 lower bound 2.5355150988915507; gradient mag: 2.6430034941530884
# Iteration 4300 lower bound 2.3346536991188054; gradient mag: 2.4929221870323492
# Iteration 4400 lower bound 2.1497133142884652; gradient mag: 2.342806663733915
# Iteration 4500 lower bound 1.9809292604652138; gradient mag: 2.1930206474598894
# Iteration 4600 lower bound 1.8283137632422375; gradient mag: 2.0441136627500613
# Iteration 4700 lower bound 1.691655364964971; gradient mag: 1.8967832576590329
# Iteration 4800 lower bound 1.5705256812596613; gradient mag: 1.7518364695730269
# Iteration 4900 lower bound 1.4642933738374657; gradient mag: 1.6101500586762643

# %%
x_test = np.linspace(-10, 10, 1000).reshape(1,-1)
y_test = my_nn_1_5.forward(x_test, use_subweights = False, weights = my_nn_1_5.weights)[0]
plt.scatter(x, y, alpha = 0.3)
plt.plot(x_test[0], y_test[0], color = 'red')
plt.xlabel('X')
plt.ylabel('Y');

# %%
output_noise = 0.5**2
def log_likelihood(y_actual, y_pred):
    return -0.5 * np.log(2 * np.pi * output_noise) - 0.5 * np.mean(((y_actual - y_pred)**2).sum(axis = 1)) / output_noise

# %% [markdown]
# ## Random structure: layer = 1, width = 5

# %%
my_subspace_1_5 = Subspace.create(subspace_type="random", model=my_nn_1_5, n_subspace=2)
my_subspace_1_5.collect_vector(X=x, y=y)
P, w = my_subspace_1_5.get_space()

# %%
hmc_tune_params={'step_size':1e-3,
                'leapfrog_steps': 10,
                'total_samples': 20000,
                'burn_in': 0.2,
                'warm_start': True,
                'thinning_factor': 2,
                'mom_std': 1,
                'diagnostic_mode': False}

my_inference_1_5 = Inference.create(inference_type="HMC", model=my_nn_1_5, P=P, w_hat=w,  tune_params=hmc_tune_params,
                               Sigma_Z=25)

# get initial weights (in subspace dimension!!)
position_init = my_nn_1_5.get_z_from_W(weights=my_nn_1_5.weights, P=my_inference_1_5.P, w_hat=my_inference_1_5.w_hat)

# %%
begin=time.time()
my_inference_1_5.train(X=x, y=y, warm_start=False, position_init=position_init)
end=time.time()
# Out:
# HMC 200: accept rate of 100.0 with step size 0.001
# HMC 400: accept rate of 99.75 with step size 0.002499340131779616
# HMC 600: accept rate of 99.83333333333333 with step size 0.003999340131779616
# HMC 800: accept rate of 99.625 with step size 0.005498440796089194
# HMC 1000: accept rate of 99.7 with step size 0.0069984407960891944
# HMC 1200: accept rate of 99.75 with step size 0.008498440796089194
# HMC 1400: accept rate of 99.5 with step size 0.009998440796089194
# HMC 1600: accept rate of 99.5 with step size 0.011131891850685758
# HMC 1800: accept rate of 99.44444444444444 with step size 0.012615511645627075
# HMC 2000: accept rate of 99.3 with step size 0.014115511645627075
# HMC 2200: accept rate of 99.18181818181819 with step size 0.015615511645627075
# HMC 2400: accept rate of 98.95833333333334 with step size 0.017115511645627076
# HMC 2600: accept rate of 98.61538461538461 with step size 0.018615511645627077
# HMC 2800: accept rate of 98.60714285714286 with step size 0.019954583155066888
# HMC 3000: accept rate of 98.5 with step size 0.020919555898843794
# HMC 3200: accept rate of 98.1875 with step size 0.022419555898843795
# HMC 3400: accept rate of 97.76470588235294 with step size 0.023919555898843797
# HMC 3600: accept rate of 97.44444444444444 with step size 0.025419555898843798
# HMC 3800: accept rate of 97.10526315789474 with step size 0.026562738089753152
# HMC 200: accept rate of 93.5
# HMC 400: accept rate of 88.5
# HMC 600: accept rate of 87.0
# HMC 800: accept rate of 89.0
# HMC 1000: accept rate of 88.3
# HMC 1200: accept rate of 88.25
# HMC 1400: accept rate of 89.0
# HMC 1600: accept rate of 88.9375
# HMC 1800: accept rate of 88.33333333333333
# HMC 2000: accept rate of 88.05
# HMC 2200: accept rate of 87.68181818181819
# HMC 2400: accept rate of 86.875
# HMC 2600: accept rate of 86.15384615384616
# HMC 2800: accept rate of 85.60714285714286
# HMC 3000: accept rate of 84.13333333333334
# HMC 3200: accept rate of 82.78125
# HMC 3400: accept rate of 82.23529411764706
# HMC 3600: accept rate of 81.88888888888889
# HMC 3800: accept rate of 82.21052631578948
# HMC 4000: accept rate of 82.025
# HMC 4200: accept rate of 81.73809523809524
# HMC 4400: accept rate of 81.52272727272727
# HMC 4600: accept rate of 81.34782608695652
# HMC 4800: accept rate of 81.02083333333333
# HMC 5000: accept rate of 80.74
# HMC 5200: accept rate of 80.51923076923077
# HMC 5400: accept rate of 80.57407407407408
# HMC 5600: accept rate of 80.78571428571429
# HMC 5800: accept rate of 80.91379310344827
# HMC 6000: accept rate of 81.05
# HMC 6200: accept rate of 80.75806451612904
# HMC 6400: accept rate of 80.765625
# HMC 6600: accept rate of 80.72727272727273
# HMC 6800: accept rate of 80.6029411764706
# HMC 7000: accept rate of 80.28571428571429
# HMC 7200: accept rate of 79.95833333333333
# HMC 7400: accept rate of 79.37837837837837
# HMC 7600: accept rate of 78.85526315789474
# HMC 7800: accept rate of 78.3076923076923
# HMC 8000: accept rate of 77.825
# HMC 8200: accept rate of 77.41463414634147
# HMC 8400: accept rate of 77.44047619047619
# HMC 8600: accept rate of 77.59302325581395
# HMC 8800: accept rate of 77.26136363636364
# HMC 9000: accept rate of 77.33333333333333
# HMC 9200: accept rate of 76.94565217391305
# HMC 9400: accept rate of 76.85106382978724
# HMC 9600: accept rate of 76.96875
# HMC 9800: accept rate of 76.98979591836735
# HMC 10000: accept rate of 77.15
# HMC 10200: accept rate of 77.25490196078431
# HMC 10400: accept rate of 77.32692307692308
# HMC 10600: accept rate of 77.29245283018868
# HMC 10800: accept rate of 77.25
# HMC 11000: accept rate of 77.27272727272727
# HMC 11200: accept rate of 77.10714285714286
# HMC 11400: accept rate of 77.01754385964912
# HMC 11600: accept rate of 76.65517241379311
# HMC 11800: accept rate of 76.36440677966101
# HMC 12000: accept rate of 76.30833333333334
# HMC 12200: accept rate of 76.09836065573771
# HMC 12400: accept rate of 75.8225806451613
# HMC 12600: accept rate of 75.4920634920635
# HMC 12800: accept rate of 75.1953125
# HMC 13000: accept rate of 74.93846153846154
# HMC 13200: accept rate of 74.74242424242425
# HMC 13400: accept rate of 74.65671641791045
# HMC 13600: accept rate of 74.63970588235294
# HMC 13800: accept rate of 74.44927536231884
# HMC 14000: accept rate of 74.29285714285714
# HMC 14200: accept rate of 74.02816901408451
# HMC 14400: accept rate of 73.84722222222223
# HMC 14600: accept rate of 73.65753424657534
# HMC 14800: accept rate of 73.38513513513513
# HMC 15000: accept rate of 73.56
# HMC 15200: accept rate of 73.63157894736842
# HMC 15400: accept rate of 73.51948051948052
# HMC 15600: accept rate of 73.34615384615384
# HMC 15800: accept rate of 73.0632911392405
# HMC 16000: accept rate of 73.06875
# HMC 16200: accept rate of 72.90123456790124
# HMC 16400: accept rate of 72.7439024390244
# HMC 16600: accept rate of 72.75903614457832
# HMC 16800: accept rate of 72.81547619047619
# HMC 17000: accept rate of 72.58235294117647
# HMC 17200: accept rate of 72.61046511627907
# HMC 17400: accept rate of 72.63793103448276
# HMC 17600: accept rate of 72.72727272727273
# HMC 17800: accept rate of 72.7247191011236
# HMC 18000: accept rate of 72.7611111111111
# HMC 18200: accept rate of 72.74175824175825
# HMC 18400: accept rate of 72.82065217391305
# HMC 18600: accept rate of 72.89784946236558
# HMC 18800: accept rate of 72.82978723404256
# HMC 19000: accept rate of 72.92631578947369
# HMC 19200: accept rate of 72.78645833333333
# HMC 19400: accept rate of 72.69587628865979
# HMC 19600: accept rate of 72.48979591836735
# HMC 19800: accept rate of 72.14646464646465

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 5.63 min

# %%
# get posterior z
n_sample = 100
post_sample = my_inference_1_5.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn_1_5 = my_nn_1_5.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn_1_5.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive: HMC + random + 1 layer 5 width')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn_1_5[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn_1_5.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn_1_5, 0.25, axis=0), np.percentile(y_test_bnn_1_5, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive with 95% CI: HMC + random + 1 layer 5 width')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
y_pred= my_nn_1_5.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_random = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_random))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -4.4163

# %% [markdown]
# ## Random structure: layer = 1, width = 30

# %%
###neural network model design choices
width = 30
hidden_layers = 1
input_dim = 1
output_dim = 1

architecture = {'width': width,
               'hidden_layers': hidden_layers,
               'input_dim': input_dim,
               'output_dim': output_dim,
               'activation_fn_type': 'rbf',
               'activation_fn_params': 'c=0, alpha=1',
               'activation_fn': h}

# set random state to make the experiments replicable
rand_state = 0
random = np.random.RandomState(rand_state)

# create a model and train the model
my_nn_1_30 = Model.create(submodel_type="Feedforward", architecture=architecture, Sigma_Y=0.25)

# use MSE result as params_init
params = {'step_size':1e-3, 
          'max_iteration':5000, 
          'random_restarts':1}

# fit my neural network to minimize MSE on the given data
my_nn_1_30.fit(x_train=x.reshape((1, -1)), y_train=y.reshape((1, -1)), params=params)
# Out:
# Iteration 0 lower bound 32.58793915718334; gradient mag: 94.39143716072499
# Iteration 100 lower bound 8.473450997830842; gradient mag: 41.69363082960816
# Iteration 200 lower bound 3.6493116898032696; gradient mag: 14.762985279078086
# Iteration 300 lower bound 1.8855206455131108; gradient mag: 5.029492342722086
# Iteration 400 lower bound 1.3453948601924908; gradient mag: 2.434003197860627
# Iteration 500 lower bound 1.075847103012563; gradient mag: 1.6184009486589837
# Iteration 600 lower bound 0.8990651351045867; gradient mag: 1.1805931584788822
# Iteration 700 lower bound 0.7779115101311369; gradient mag: 0.8918417732253724
# Iteration 800 lower bound 0.6911452868762314; gradient mag: 0.6960259361393869
# Iteration 900 lower bound 0.6251712278078676; gradient mag: 0.5617487991498086
# Iteration 1000 lower bound 0.5720066616921051; gradient mag: 0.4642564214612612
# Iteration 1100 lower bound 0.5274133350175305; gradient mag: 0.3873386672660175
# Iteration 1200 lower bound 0.48920309157935765; gradient mag: 0.3236705373376262
# Iteration 1300 lower bound 0.45611863132646957; gradient mag: 0.2710488659696415
# Iteration 1400 lower bound 0.4272858572205764; gradient mag: 0.22861849801986908
# Iteration 1500 lower bound 0.40200064205055974; gradient mag: 0.19553777198121897
# Iteration 1600 lower bound 0.3796521724183483; gradient mag: 0.17100459540609786
# Iteration 1700 lower bound 0.3596936806363471; gradient mag: 0.15435745107782503
# Iteration 1800 lower bound 0.34162705576989794; gradient mag: 0.14507288530181822
# Iteration 1900 lower bound 0.32498521073020536; gradient mag: 0.142820720705468
# Iteration 2000 lower bound 0.3093126158031493; gradient mag: 0.14710720716667683
# Iteration 2100 lower bound 0.29419373905376817; gradient mag: 0.1549093167730239
# Iteration 2200 lower bound 0.27941374674542657; gradient mag: 0.15866545312570843
# Iteration 2300 lower bound 0.26508739906413253; gradient mag: 0.15451197505289882
# Iteration 2400 lower bound 0.25143644968955675; gradient mag: 0.14808960643865304
# Iteration 2500 lower bound 0.23854386734821714; gradient mag: 0.1443909703296158
# Iteration 2600 lower bound 0.22636645938161007; gradient mag: 0.14384935291810097
# Iteration 2700 lower bound 0.21480378971127884; gradient mag: 0.14504382318811337
# Iteration 2800 lower bound 0.20374878442799957; gradient mag: 0.14607735205379155
# Iteration 2900 lower bound 0.1931351440998689; gradient mag: 0.14521078242170818
# Iteration 3000 lower bound 0.18295894181230926; gradient mag: 0.14166501787404537
# Iteration 3100 lower bound 0.17325375818605593; gradient mag: 0.1359520147029528
# Iteration 3200 lower bound 0.1640509857935496; gradient mag: 0.12918794051258337
# Iteration 3300 lower bound 0.1553634204868694; gradient mag: 0.1222549493173359
# Iteration 3400 lower bound 0.14718717168071083; gradient mag: 0.11559917688877253
# Iteration 3500 lower bound 0.13950665705162343; gradient mag: 0.10938984250384197
# Iteration 3600 lower bound 0.13229893162427084; gradient mag: 0.10366323563061457
# Iteration 3700 lower bound 0.12553729280760284; gradient mag: 0.09839121850038916
# Iteration 3800 lower bound 0.11919398996818441; gradient mag: 0.09351412105231108
# Iteration 3900 lower bound 0.1132419961438558; gradient mag: 0.08896059819432815
# Iteration 4000 lower bound 0.10765599109043673; gradient mag: 0.08466087219945662
# Iteration 4100 lower bound 0.10241276147399886; gradient mag: 0.08055550310007975
# Iteration 4200 lower bound 0.09749120362236473; gradient mag: 0.07660074335728553
# Iteration 4300 lower bound 0.09287208119401517; gradient mag: 0.07277082999431946
# Iteration 4400 lower bound 0.08853766663751228; gradient mag: 0.06905724837500311
# Iteration 4500 lower bound 0.08447137470321112; gradient mag: 0.06546525923093284
# Iteration 4600 lower bound 0.08065746635321695; gradient mag: 0.06200859781821881
# Iteration 4700 lower bound 0.07708086123621923; gradient mag: 0.058703749771285424
# Iteration 4800 lower bound 0.07372705774786809; gradient mag: 0.055565196783337885
# Iteration 4900 lower bound 0.07058213423748755; gradient mag: 0.05260248318179525

# %%
my_subspace_1_30 = Subspace.create(subspace_type="random", model=my_nn_1_30, n_subspace=2)
my_subspace_1_30.collect_vector(X=x, y=y)
P, w = my_subspace_1_30.get_space()

hmc_tune_params={'step_size':1e-2,
                'leapfrog_steps': 10,
                'total_samples': 20000,
                'burn_in': 0.2,
                'warm_start': True,
                'thinning_factor': 2,
                'mom_std': 1,
                'diagnostic_mode': False}

my_inference_1_30 = Inference.create(inference_type="HMC", model=my_nn_1_30, P=P, w_hat=w,  tune_params=hmc_tune_params,
                               Sigma_Z=25)

# get initial weights (in subspace dimension!!)
position_init = my_nn_1_30.get_z_from_W(weights=my_nn_1_30.weights, P=my_inference_1_30.P, w_hat=my_inference_1_30.w_hat)

# %%
begin=time.time()
my_inference_1_30.train(X=x, y=y, warm_start=False, position_init=position_init)
end=time.time()
# Out:
# HMC 200: accept rate of 98.0 with step size 0.01
# HMC 400: accept rate of 96.25 with step size 0.011498764726526056
# HMC 600: accept rate of 96.0 with step size 0.012998764726526056
# HMC 800: accept rate of 94.875 with step size 0.014474686626948705
# HMC 1000: accept rate of 94.1 with step size 0.013928640855923616
# HMC 1200: accept rate of 93.58333333333333 with step size 0.015428640855923615
# HMC 1400: accept rate of 92.71428571428572 with step size 0.016928640855923615
# HMC 1600: accept rate of 91.375 with step size 0.017195546842612236
# HMC 1800: accept rate of 89.94444444444444 with step size 0.018449418307303626
# HMC 2000: accept rate of 86.8 with step size 0.019574376620079263
# HMC 2200: accept rate of 86.68181818181819 with step size 0.016877025048833757
# HMC 2400: accept rate of 85.20833333333333 with step size 0.018377025048833758
# HMC 2600: accept rate of 84.76923076923077 with step size 0.01804237430303004
# HMC 2800: accept rate of 83.57142857142857 with step size 0.018806811141484782
# HMC 3000: accept rate of 82.89999999999999 with step size 0.018689560245846098
# HMC 3200: accept rate of 81.25 with step size 0.0201895602458461
# HMC 3400: accept rate of 79.23529411764706 with step size 0.0216895602458461
# HMC 3600: accept rate of 77.27777777777777 with step size 0.0216895602458461
# HMC 3800: accept rate of 75.5 with step size 0.0216895602458461
# HMC 200: accept rate of 46.5
# HMC 400: accept rate of 49.0
# HMC 600: accept rate of 48.5
# HMC 800: accept rate of 50.75
# HMC 1000: accept rate of 50.8
# HMC 1200: accept rate of 50.583333333333336
# HMC 1400: accept rate of 53.785714285714285
# HMC 1600: accept rate of 57.8125
# HMC 1800: accept rate of 60.833333333333336
# HMC 2000: accept rate of 62.6
# HMC 2200: accept rate of 63.18181818181818
# HMC 2400: accept rate of 62.166666666666664
# HMC 2600: accept rate of 63.34615384615385
# HMC 2800: accept rate of 65.25
# HMC 3000: accept rate of 66.5
# HMC 3200: accept rate of 67.46875
# HMC 3400: accept rate of 68.91176470588235
# HMC 3600: accept rate of 69.91666666666667
# HMC 3800: accept rate of 70.63157894736842
# HMC 4000: accept rate of 70.55
# HMC 4200: accept rate of 69.83333333333333
# HMC 4400: accept rate of 70.61363636363636
# HMC 4600: accept rate of 70.97826086956522
# HMC 4800: accept rate of 71.66666666666667
# HMC 5000: accept rate of 72.1
# HMC 5200: accept rate of 72.53846153846153
# HMC 5400: accept rate of 73.24074074074075
# HMC 5600: accept rate of 73.80357142857143
# HMC 5800: accept rate of 74.25862068965517
# HMC 6000: accept rate of 74.58333333333333
# HMC 6200: accept rate of 74.80645161290323
# HMC 6400: accept rate of 74.671875
# HMC 6600: accept rate of 74.24242424242425
# HMC 6800: accept rate of 74.23529411764706
# HMC 7000: accept rate of 73.94285714285714
# HMC 7200: accept rate of 73.34722222222223
# HMC 7400: accept rate of 73.51351351351352
# HMC 7600: accept rate of 73.47368421052632
# HMC 7800: accept rate of 73.2051282051282
# HMC 8000: accept rate of 72.625
# HMC 8200: accept rate of 71.97560975609755
# HMC 8400: accept rate of 70.98809523809524
# HMC 8600: accept rate of 70.82558139534883
# HMC 8800: accept rate of 70.95454545454545
# HMC 9000: accept rate of 70.9
# HMC 9200: accept rate of 70.8586956521739
# HMC 9400: accept rate of 70.5
# HMC 9600: accept rate of 69.83333333333333
# HMC 9800: accept rate of 69.77551020408163
# HMC 10000: accept rate of 69.92
# HMC 10200: accept rate of 69.96078431372548
# HMC 10400: accept rate of 69.84615384615384
# HMC 10600: accept rate of 70.08490566037736
# HMC 10800: accept rate of 70.21296296296296
# HMC 11000: accept rate of 70.2909090909091
# HMC 11200: accept rate of 70.65178571428571
# HMC 11400: accept rate of 70.95614035087719
# HMC 11600: accept rate of 71.09482758620689
# HMC 11800: accept rate of 71.10169491525424
# HMC 12000: accept rate of 71.13333333333334
# HMC 12200: accept rate of 71.06557377049181
# HMC 12400: accept rate of 70.75806451612904
# HMC 12600: accept rate of 70.18253968253968
# HMC 12800: accept rate of 70.1015625
# HMC 13000: accept rate of 69.95384615384616
# HMC 13200: accept rate of 70.12121212121212
# HMC 13400: accept rate of 69.93283582089552
# HMC 13600: accept rate of 70.04411764705883
# HMC 13800: accept rate of 69.89855072463769
# HMC 14000: accept rate of 69.85
# HMC 14200: accept rate of 70.11267605633803
# HMC 14400: accept rate of 70.27777777777777
# HMC 14600: accept rate of 70.44520547945206
# HMC 14800: accept rate of 70.70270270270271
# HMC 15000: accept rate of 70.97333333333333
# HMC 15200: accept rate of 71.10526315789474
# HMC 15400: accept rate of 71.1103896103896
# HMC 15600: accept rate of 71.10897435897436
# HMC 15800: accept rate of 70.87974683544304
# HMC 16000: accept rate of 70.54375
# HMC 16200: accept rate of 70.19135802469135
# HMC 16400: accept rate of 69.82926829268293
# HMC 16600: accept rate of 69.73493975903614
# HMC 16800: accept rate of 69.79761904761905
# HMC 17000: accept rate of 69.67058823529412
# HMC 17200: accept rate of 69.78488372093024
# HMC 17400: accept rate of 70.00574712643679
# HMC 17600: accept rate of 70.19318181818181
# HMC 17800: accept rate of 70.3932584269663
# HMC 18000: accept rate of 70.50555555555556
# HMC 18200: accept rate of 70.46153846153847
# HMC 18400: accept rate of 70.53260869565217
# HMC 18600: accept rate of 70.56451612903226
# HMC 18800: accept rate of 70.45212765957447
# HMC 19000: accept rate of 70.22105263157894
# HMC 19200: accept rate of 70.234375
# HMC 19400: accept rate of 70.08247422680412
# HMC 19600: accept rate of 69.84693877551021
# HMC 19800: accept rate of 69.52525252525253

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 5.96 min

# %%
# get posterior z
n_sample = 100
post_sample = my_inference_1_30.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn_1_30 = my_nn_1_30.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn_1_30.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive: HMC + random + 1 layer 30 width')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn_1_30[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn_1_30.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn_1_30, 0.25, axis=0), np.percentile(y_test_bnn_1_30, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive with 95% CI: : HMC + random + 1 layer 30 width')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
y_pred= my_nn_1_30.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_random = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_random))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -2.2122

# %% [markdown]
# ## Random structure: layer = 2, width = 5

# %%
###neural network model design choices
width = 5
hidden_layers = 2
input_dim = 1
output_dim = 1

architecture = {'width': width,
               'hidden_layers': hidden_layers,
               'input_dim': input_dim,
               'output_dim': output_dim,
               'activation_fn_type': 'rbf',
               'activation_fn_params': 'c=0, alpha=1',
               'activation_fn': h}

# set random state to make the experiments replicable
rand_state = 0
random = np.random.RandomState(rand_state)

# create a model and train the model
my_nn_2_5 = Model.create(submodel_type="Feedforward", architecture=architecture, Sigma_Y=0.25)

# use MSE result as params_init
params = {'step_size':1e-3, 
          'max_iteration':5000, 
          'random_restarts':1}

# fit my neural network to minimize MSE on the given data
my_nn_2_5.fit(x_train=x.reshape((1, -1)), y_train=y.reshape((1, -1)), params=params)
# Out:
# Iteration 0 lower bound 58.51737965235858; gradient mag: 146.22784407127557
# Iteration 100 lower bound 46.58811441002415; gradient mag: 40.140639166229654
# Iteration 200 lower bound 44.50828280943876; gradient mag: 17.036262898343303
# Iteration 300 lower bound 13.936341003308048; gradient mag: 60.17215353190675
# Iteration 400 lower bound 6.7789666426703485; gradient mag: 15.636085842033989
# Iteration 500 lower bound 5.291787455219593; gradient mag: 13.931373366657537
# Iteration 600 lower bound 4.0765812415145275; gradient mag: 9.457487080045432
# Iteration 700 lower bound 3.2905119643969165; gradient mag: 5.376004592445491
# Iteration 800 lower bound 2.8225066742216107; gradient mag: 3.643371355531353
# Iteration 900 lower bound 2.52621586763896; gradient mag: 2.9279791537402438
# Iteration 1000 lower bound 2.3228335679826007; gradient mag: 2.530805273403531
# Iteration 1100 lower bound 2.1723846557701085; gradient mag: 2.1395101712264464
# Iteration 1200 lower bound 2.0567908655121516; gradient mag: 1.721827349642761
# Iteration 1300 lower bound 1.9680538432488215; gradient mag: 1.357126846455537
# Iteration 1400 lower bound 1.9009041681511412; gradient mag: 1.083789697941618
# Iteration 1500 lower bound 1.8504335664229812; gradient mag: 0.8958703939729586
# Iteration 1600 lower bound 1.8122419161018208; gradient mag: 0.7746687118282845
# Iteration 1700 lower bound 1.782800382628017; gradient mag: 0.7030264003975766
# Iteration 1800 lower bound 1.7594404984019054; gradient mag: 0.6674610271138604
# Iteration 1900 lower bound 1.7401437377969462; gradient mag: 0.6576004676312717
# Iteration 2000 lower bound 1.7233265737303625; gradient mag: 0.6657477678770036
# Iteration 2100 lower bound 1.7076931804980386; gradient mag: 0.686199174157356
# Iteration 2200 lower bound 1.6921634246168147; gradient mag: 0.7141002251356994
# Iteration 2300 lower bound 1.6758690424779847; gradient mag: 0.7442625917711013
# Iteration 2400 lower bound 1.658202878556577; gradient mag: 0.7706246819274003
# Iteration 2500 lower bound 1.6388704190565475; gradient mag: 0.7873620950411138
# Iteration 2600 lower bound 1.6178401744618718; gradient mag: 0.7921294022266566
# Iteration 2700 lower bound 1.5951515633493585; gradient mag: 0.7883774552957212
# Iteration 2800 lower bound 1.5707504711058216; gradient mag: 0.7819040605641164
# Iteration 2900 lower bound 1.5444828498095282; gradient mag: 0.7753776057153013
# Iteration 3000 lower bound 1.516113183710697; gradient mag: 0.7682091923385078
# Iteration 3100 lower bound 1.4852654976998747; gradient mag: 0.7592902676535679
# Iteration 3200 lower bound 1.4512723413644932; gradient mag: 0.7484804057449765
# Iteration 3300 lower bound 1.4128658990719811; gradient mag: 0.7381051490682408
# Iteration 3400 lower bound 1.3676600685300806; gradient mag: 0.7356275500515014
# Iteration 3500 lower bound 1.3117898525530496; gradient mag: 0.7530860276963118
# Iteration 3600 lower bound 1.240973823127977; gradient mag: 0.7964262910936151
# Iteration 3700 lower bound 1.153463826417491; gradient mag: 0.8565879252643901
# Iteration 3800 lower bound 1.0518609865471324; gradient mag: 0.915698343086837
# Iteration 3900 lower bound 0.9419884927552573; gradient mag: 0.9556617628727947
# Iteration 4000 lower bound 0.8310963682451842; gradient mag: 0.9651196616903763
# Iteration 4100 lower bound 0.7261743162377066; gradient mag: 0.9440328735136027
# Iteration 4200 lower bound 0.6318754647405767; gradient mag: 0.9030047423080199
# Iteration 4300 lower bound 0.5490441053610304; gradient mag: 0.8565716664294021
# Iteration 4400 lower bound 0.475398868269424; gradient mag: 0.8128881330665796
# Iteration 4500 lower bound 0.40816629604337523; gradient mag: 0.7687953831646955
# Iteration 4600 lower bound 0.3462208866607515; gradient mag: 0.7174387471506257
# Iteration 4700 lower bound 0.28995469152563275; gradient mag: 0.6577913004613635
# Iteration 4800 lower bound 0.24017327171097208; gradient mag: 0.5928707106861166
# Iteration 4900 lower bound 0.19755376002500175; gradient mag: 0.5247455153325796

# %%
x_test = np.linspace(-10, 10, 1000).reshape(1,-1)
y_test = my_nn_2_5.forward(x_test, use_subweights = False, weights = my_nn_2_5.weights)[0]
plt.scatter(x, y, alpha = 0.3)
plt.plot(x_test[0], y_test[0], color = 'red')
plt.xlabel('X')
plt.ylabel('Y');

# %%
my_subspace_2_5 = Subspace.create(subspace_type="random", model=my_nn_2_5, n_subspace=2)
my_subspace_2_5.collect_vector(X=x, y=y)
P, w = my_subspace_2_5.get_space()

hmc_tune_params={'step_size':0.005,
                'leapfrog_steps': 10,
                'total_samples': 20000,
                'burn_in': 0.1,
                'warm_start': True,
                'thinning_factor': 2,
                'mom_std': 1,
                'diagnostic_mode': False}

my_inference_2_5 = Inference.create(inference_type="HMC", model=my_nn_2_5, P=P, w_hat=w,  tune_params=hmc_tune_params,
                               Sigma_Z=25)

# get initial weights (in subspace dimension!!)
position_init = my_nn_2_5.get_z_from_W(weights=my_nn_2_5.weights, P=my_inference_2_5.P, w_hat=my_inference_2_5.w_hat)

begin=time.time()
my_inference_2_5.train(X=x, y=y, warm_start=False, position_init=position_init)
end=time.time()
# Out:
# HMC 200: accept rate of 98.5 with step size 0.005
# HMC 400: accept rate of 98.25 with step size 0.006368964964212175
# HMC 600: accept rate of 96.16666666666667 with step size 0.007820082841808327
# HMC 800: accept rate of 90.5 with step size 0.009178824522239388
# HMC 1000: accept rate of 89.2 with step size 0.009157606535228931
# HMC 1200: accept rate of 83.08333333333333 with step size 0.01065760653522893
# HMC 1400: accept rate of 79.5 with step size 0.010273389792533503
# HMC 1600: accept rate of 73.1875 with step size 0.010273389792533503
# HMC 1800: accept rate of 71.0 with step size 0.010273389792533503
# HMC 200: accept rate of 67.0
# HMC 400: accept rate of 36.5
# HMC 600: accept rate of 48.333333333333336
# HMC 800: accept rate of 55.0
# HMC 1000: accept rate of 61.5
# HMC 1200: accept rate of 53.833333333333336
# HMC 1400: accept rate of 57.642857142857146
# HMC 1600: accept rate of 58.75
# HMC 1800: accept rate of 59.55555555555556
# HMC 2000: accept rate of 57.8
# HMC 2200: accept rate of 57.18181818181818
# HMC 2400: accept rate of 56.958333333333336
# HMC 2600: accept rate of 59.76923076923077
# HMC 2800: accept rate of 62.32142857142857
# HMC 3000: accept rate of 63.233333333333334
# HMC 3200: accept rate of 62.1875
# HMC 3400: accept rate of 64.26470588235294
# HMC 3600: accept rate of 66.0
# HMC 3800: accept rate of 67.55263157894737
# HMC 4000: accept rate of 68.65
# HMC 4200: accept rate of 68.42857142857143
# HMC 4400: accept rate of 69.47727272727273
# HMC 4600: accept rate of 70.58695652173913
# HMC 4800: accept rate of 71.1875
# HMC 5000: accept rate of 71.62
# HMC 5200: accept rate of 71.9423076923077
# HMC 5400: accept rate of 72.81481481481481
# HMC 5600: accept rate of 73.71428571428571
# HMC 5800: accept rate of 74.22413793103448
# HMC 6000: accept rate of 74.11666666666666
# HMC 6200: accept rate of 73.2741935483871
# HMC 6400: accept rate of 73.796875
# HMC 6600: accept rate of 73.92424242424242
# HMC 6800: accept rate of 74.58823529411765
# HMC 7000: accept rate of 74.6
# HMC 7200: accept rate of 74.04166666666667
# HMC 7400: accept rate of 74.58108108108108
# HMC 7600: accept rate of 74.27631578947368
# HMC 7800: accept rate of 73.62820512820512
# HMC 8000: accept rate of 72.975
# HMC 8200: accept rate of 72.6219512195122
# HMC 8400: accept rate of 71.85714285714286
# HMC 8600: accept rate of 71.55813953488372
# HMC 8800: accept rate of 71.55681818181819
# HMC 9000: accept rate of 71.65555555555555
# HMC 9200: accept rate of 71.57608695652173
# HMC 9400: accept rate of 71.41489361702128
# HMC 9600: accept rate of 71.86458333333333
# HMC 9800: accept rate of 71.34693877551021
# HMC 10000: accept rate of 71.5
# HMC 10200: accept rate of 71.38235294117646
# HMC 10400: accept rate of 71.88461538461539
# HMC 10600: accept rate of 72.36792452830188
# HMC 10800: accept rate of 72.60185185185185
# HMC 11000: accept rate of 72.28181818181818
# HMC 11200: accept rate of 72.58928571428571
# HMC 11400: accept rate of 72.6842105263158
# HMC 11600: accept rate of 73.04310344827586
# HMC 11800: accept rate of 73.3135593220339
# HMC 12000: accept rate of 72.93333333333334
# HMC 12200: accept rate of 72.39344262295081
# HMC 12400: accept rate of 72.70967741935483
# HMC 12600: accept rate of 72.84126984126983
# HMC 12800: accept rate of 72.9296875
# HMC 13000: accept rate of 73.08461538461539
# HMC 13200: accept rate of 73.1969696969697
# HMC 13400: accept rate of 73.04477611940298
# HMC 13600: accept rate of 73.38970588235294
# HMC 13800: accept rate of 73.28260869565217
# HMC 14000: accept rate of 73.39285714285714
# HMC 14200: accept rate of 73.47183098591549
# HMC 14400: accept rate of 73.73611111111111
# HMC 14600: accept rate of 74.03424657534246
# HMC 14800: accept rate of 74.27027027027027
# HMC 15000: accept rate of 74.44
# HMC 15200: accept rate of 74.51973684210526
# HMC 15400: accept rate of 73.8896103896104
# HMC 15600: accept rate of 73.34615384615384
# HMC 15800: accept rate of 73.57594936708861
# HMC 16000: accept rate of 73.7875
# HMC 16200: accept rate of 73.76543209876543
# HMC 16400: accept rate of 73.29268292682927
# HMC 16600: accept rate of 72.55421686746988
# HMC 16800: accept rate of 72.25595238095238
# HMC 17000: accept rate of 72.14117647058823
# HMC 17200: accept rate of 71.65116279069767
# HMC 17400: accept rate of 71.85057471264368
# HMC 17600: accept rate of 71.79545454545455
# HMC 17800: accept rate of 71.29213483146067
# HMC 18000: accept rate of 71.42222222222222
# HMC 18200: accept rate of 71.21428571428571
# HMC 18400: accept rate of 70.84782608695652
# HMC 18600: accept rate of 70.25268817204301
# HMC 18800: accept rate of 70.05851063829788
# HMC 19000: accept rate of 70.32631578947368
# HMC 19200: accept rate of 69.97395833333333
# HMC 19400: accept rate of 69.34020618556701
# HMC 19600: accept rate of 68.6938775510204
# HMC 19800: accept rate of 68.18686868686869

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 6.45 min

# %%
# get posterior z
n_sample = 100
post_sample = my_inference_2_5.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn_2_5 = my_nn_2_5.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn_2_5.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive: HMC + random + 2 layer 5 width')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn_2_5[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn_2_5.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn_2_5, 0.25, axis=0), np.percentile(y_test_bnn_2_5, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive with 95% CI: : HMC + random + 2 layer 5 width')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
y_pred= my_nn_2_5.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_random = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_random))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -13.9473

# %%
plt.figure(figsize=(20, 5))
plt.subplot(1, 3, 1)
plt.grid()
plt.title('Posterior Predictive: HMC + random + 1 layer 5 width')
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn_1_5[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()

plt.subplot(1, 3, 2)
plt.grid()
plt.title('Posterior Predictive: HMC + random + 1 layer 30 width')
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn_1_30[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()

plt.subplot(1, 3, 3)
plt.grid()
plt.title('Posterior Predictive: HMC + random + 2 layer 5 width')
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn_2_5[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()

# %% [markdown]
# ## PCA

# %%
my_subspace = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y)
P, w = my_subspace.get_space()

# %%
hmc_tune_params={'step_size':5e-2,
                'leapfrog_steps': 10,
                'total_samples': 20000,
                'burn_in': 0.2,
                'warm_start': True,
                'thinning_factor': 2,
                'mom_std': 1,
                'diagnostic_mode': False}

# %%
my_inference = Inference.create(inference_type="HMC", model=my_nn, P=P, w_hat=w,  tune_params=hmc_tune_params,
                               Sigma_Z=5)

# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

# %%
begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init)
end=time.time()
# Out:
# HMC 200: accept rate of 100.0 with step size 0.05
# HMC 400: accept rate of 100.0 with step size 0.05149590628513469
# HMC 600: accept rate of 100.0 with step size 0.05299590628513469
# HMC 800: accept rate of 100.0 with step size 0.05449448304423065
# HMC 1000: accept rate of 99.9 with step size 0.05599448304423065
# HMC 1200: accept rate of 99.91666666666667 with step size 0.057493318828562366
# HMC 1400: accept rate of 99.92857142857143 with step size 0.05899331882856237
# HMC 1600: accept rate of 99.9375 with step size 0.060491307848387584
# HMC 1800: accept rate of 99.94444444444444 with step size 0.061991307848387585
# HMC 2000: accept rate of 99.95 with step size 0.06348952546446875
# HMC 2200: accept rate of 99.95454545454545 with step size 0.06498566052361361
# HMC 2400: accept rate of 99.95833333333334 with step size 0.06648323861727212
# HMC 2600: accept rate of 99.96153846153845 with step size 0.067973645140047
# HMC 2800: accept rate of 99.96428571428572 with step size 0.06947264431418144
# HMC 3000: accept rate of 99.93333333333332 with step size 0.07097264431418145
# HMC 3200: accept rate of 99.9375 with step size 0.07247264431418145
# HMC 3400: accept rate of 99.94117647058823 with step size 0.0739723377200632
# HMC 3600: accept rate of 99.94444444444444 with step size 0.0754723377200632
# HMC 3800: accept rate of 99.92105263157895 with step size 0.0769723377200632
# HMC 200: accept rate of 100.0
# HMC 400: accept rate of 100.0
# HMC 600: accept rate of 100.0
# HMC 800: accept rate of 100.0
# HMC 1000: accept rate of 100.0
# HMC 1200: accept rate of 100.0
# HMC 1400: accept rate of 99.92857142857143
# HMC 1600: accept rate of 99.9375
# HMC 1800: accept rate of 99.94444444444444
# HMC 2000: accept rate of 99.9
# HMC 2200: accept rate of 99.9090909090909
# HMC 2400: accept rate of 99.91666666666667
# HMC 2600: accept rate of 99.92307692307692
# HMC 2800: accept rate of 99.89285714285714
# HMC 3000: accept rate of 99.9
# HMC 3200: accept rate of 99.90625
# HMC 3400: accept rate of 99.91176470588235
# HMC 3600: accept rate of 99.91666666666667
# HMC 3800: accept rate of 99.89473684210526
# HMC 4000: accept rate of 99.875
# HMC 4200: accept rate of 99.88095238095238
# HMC 4400: accept rate of 99.86363636363636
# HMC 4600: accept rate of 99.84782608695652
# HMC 4800: accept rate of 99.83333333333333
# HMC 5000: accept rate of 99.84
# HMC 5200: accept rate of 99.8076923076923
# HMC 5400: accept rate of 99.81481481481481
# HMC 5600: accept rate of 99.80357142857143
# HMC 5800: accept rate of 99.8103448275862
# HMC 6000: accept rate of 99.81666666666666
# HMC 6200: accept rate of 99.8225806451613
# HMC 6400: accept rate of 99.8125
# HMC 6600: accept rate of 99.81818181818181
# HMC 6800: accept rate of 99.80882352941177
# HMC 7000: accept rate of 99.8
# HMC 7200: accept rate of 99.80555555555556
# HMC 7400: accept rate of 99.78378378378379
# HMC 7600: accept rate of 99.78947368421052
# HMC 7800: accept rate of 99.76923076923077
# HMC 8000: accept rate of 99.775
# HMC 8200: accept rate of 99.78048780487805
# HMC 8400: accept rate of 99.78571428571429
# HMC 8600: accept rate of 99.77906976744185
# HMC 8800: accept rate of 99.7840909090909
# HMC 9000: accept rate of 99.77777777777777
# HMC 9200: accept rate of 99.73913043478261
# HMC 9400: accept rate of 99.73404255319149
# HMC 9600: accept rate of 99.72916666666667
# HMC 9800: accept rate of 99.73469387755102
# HMC 10000: accept rate of 99.71
# HMC 10200: accept rate of 99.70588235294117
# HMC 10400: accept rate of 99.6923076923077
# HMC 10600: accept rate of 99.69811320754717
# HMC 10800: accept rate of 99.69444444444444
# HMC 11000: accept rate of 99.67272727272727
# HMC 11200: accept rate of 99.67857142857143
# HMC 11400: accept rate of 99.67543859649123
# HMC 11600: accept rate of 99.68103448275862
# HMC 11800: accept rate of 99.6864406779661
# HMC 12000: accept rate of 99.68333333333334
# HMC 12200: accept rate of 99.68032786885246
# HMC 12400: accept rate of 99.68548387096774
# HMC 12600: accept rate of 99.69047619047619
# HMC 12800: accept rate of 99.6875
# HMC 13000: accept rate of 99.68461538461538
# HMC 13200: accept rate of 99.68939393939394
# HMC 13400: accept rate of 99.69402985074628
# HMC 13600: accept rate of 99.69852941176471
# HMC 13800: accept rate of 99.70289855072464
# HMC 14000: accept rate of 99.69285714285714
# HMC 14200: accept rate of 99.69718309859155
# HMC 14400: accept rate of 99.69444444444444
# HMC 14600: accept rate of 99.6986301369863
# HMC 14800: accept rate of 99.70270270270271
# HMC 15000: accept rate of 99.70666666666666
# HMC 15200: accept rate of 99.71052631578948
# HMC 15400: accept rate of 99.71428571428571
# HMC 15600: accept rate of 99.71794871794872
# HMC 15800: accept rate of 99.71518987341773
# HMC 16000: accept rate of 99.7125
# HMC 16200: accept rate of 99.70987654320987
# HMC 16400: accept rate of 99.71341463414635
# HMC 16600: accept rate of 99.6987951807229
# HMC 16800: accept rate of 99.69047619047619
# HMC 17000: accept rate of 99.68823529411765
# HMC 17200: accept rate of 99.69186046511628
# HMC 17400: accept rate of 99.69540229885058
# HMC 17600: accept rate of 99.69886363636364
# HMC 17800: accept rate of 99.69662921348315
# HMC 18000: accept rate of 99.69444444444444
# HMC 18200: accept rate of 99.6978021978022
# HMC 18400: accept rate of 99.69565217391305
# HMC 18600: accept rate of 99.6989247311828
# HMC 18800: accept rate of 99.70212765957447
# HMC 19000: accept rate of 99.70526315789473
# HMC 19200: accept rate of 99.70833333333333
# HMC 19400: accept rate of 99.71134020618557
# HMC 19600: accept rate of 99.69897959183673
# HMC 19800: accept rate of 99.70202020202021

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 7.92 min

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |HMC')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|HMC')
plt.grid()
plt.show()

# %%
post_sample=my_inference.get_posterior(n_samples=10000)
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
for i in range(my_inference.D_z):
    col = i % 2
    ax[col].plot(range(len(post_sample)), post_sample[:, i], color='gray', alpha=0.7)
fig.suptitle('Trace plots for all neural network parameters')
plt.show()

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_pca = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_pca))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -4.3521

# %% [markdown]
# ## PCA (extension)

# %% [markdown]
# In paper, the deviation matrix is updated during equal epoch intervals. However, to construct a more precise subspace, it's natural for us to have the hypothesis that forming the projection matrix $P$ with the PCA component of the smallest deviation could be better than that of the equal-interval deviations.

# %% [markdown]
# To formulate the hypothesis, we define the expressions as follows:
# <br>$w0$: pretrained weights;
# <br>$\eta$: learning rate;
# <br>$T$: number of steps;
# <br>$c$: moment update frequency;
# <br>$M$: maximum number of columns in deviation matrix;
# <br>$K$: rank of PCA approximation;
# <br>$A$: deviation matrix;
# <br>$P$: projection matrix for subspace

# %% [markdown]
# The original algorithm to construct subspace with PCA goes as follows:
#
# <p style="text-align: right">step0 [Initialize mean] </p>
# <br>$w_{SWA} \leftarrow w_0$
# <p style="text-align: right">step1 [SGD Update]</p>
# <br>for $i\leftarrow1,2,\cdots, T \text{ do}$
# <br>$\quad$ $w_i \leftarrow w_{i-1} - \eta \nabla_{w}\mathcal{L}(w_{i-1})$
# <p style="text-align: right">step2 [SWA Update]</p>
# <br>$\quad$ if MOD$(i,c)=0$ then
# <br>$\quad\quad$ $n\leftarrow i/c$
# <br>$\quad\quad$ $w_{SWA}\leftarrow \frac{nw_{SWA} + w_i}{n+1}$
# <p style="text-align: right">step3 [devation matrix Update]</p>
# <br>$\quad\quad$ if NUM_COLS($A$) = $M$ then
# <br>$\quad\quad\quad$ REMOVE_COL($A$[:,1])
# <br>$\quad\quad$ APPEND_COLS($A$, $w_i - \bar{w}$)
# <p style="text-align: right">step4 [Truncated SVD]</p>
# <br>$U,S,V^{T}\leftarrow SVD(A)$
# <br>return $\hat{w} = w_{SWA}$, $P = SV^T$
#
# In our algorithm, we construct the deviation matrix with the smallest $M$ deviations. The main difference betweem our algorithm and the paper lies in step3 (deviation matrix update process). One difficulty of our algorithm is how to find the minimum $M$ deviations with an efficient use of memory. That is to say, if we first store all possible devations in a matrix and then pick the smallest deviations, there will be a high demand for memory which makes our algorithm hard to scale up. Therefore, we come up with a training in on-line fashion, that is to construct a matrix which stores the smallest $M$ deviations so far and keep updating the matrix when new deviations come in. Under this method, the maximum of the use of memory is $M$, which is the same as theirs. To be more specific, our algorithm goes as below:
# <p style="text-align: right">step0 [Initialize mean] </p>
# <br>$w_{SWA} \leftarrow w_0$
# <p style="text-align: right">step1 [SGD Update]</p>
# <br>for $i\leftarrow1,2,\cdots, T \text{ do}$
# <br>$\quad$ $w_i \leftarrow w_{i-1} - \eta \nabla_{w}\mathcal{L}(w_{i-1})$
# <p style="text-align: right">step2 [SWA Update]</p>
# <br>$\quad$ if MOD$(i,c)=0$ then
# <br>$\quad\quad$ $n\leftarrow i/c$
# <br>$\quad\quad$ $w_{SWA}\leftarrow \frac{nw_{SWA} + w_i}{n+1}$
# <p style="text-align: right"><b>step3 [devation matrix Update]</b></p>
# <br>$\quad\quad$ if NUM_COLS($A$) = $M$ then
# <br>$\quad\quad\quad$ if norm($w_i - \bar{w}$) < norm(A[:,-1]) then
# <br>$\quad\quad\quad\quad$ REMOVE_COL($A$[:,-1])
# <br>$\quad\quad\quad\quad$ APPEND_COLS($A$, $w_i - \bar{w}$)
# <br>$\quad\quad\quad\quad$ SORT_BY_NORM($A$, ascending=True)
# <br>$\quad\quad$ else:
# <br>$\quad\quad\quad$ APPEND_COLS($A$, $w_i - \bar{w}$)
# <br>$\quad\quad\quad$ SORT_BY_NORM($A$, ascending=True)
# <p style="text-align: right">step4 [Truncated SVD]</p>
# <br>$U,S,V^{T}\leftarrow SVD(A)$
# <br>return $\hat{w} = w_{SWA}$, $P = SV^T$

# %% [markdown]
# ### the smallest deviations

# %%
my_subspace = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y, method='S') # chose the method as L
P, w = my_subspace.get_space()

# %%
hmc_tune_params={'step_size':5e-2,
                'leapfrog_steps': 10,
                'total_samples': 20000,
                'burn_in': 0.2,
                'warm_start': True,
                'thinning_factor': 2,
                'mom_std': 1,
                'diagnostic_mode': False}

# %%
my_inference = Inference.create(inference_type="HMC", model=my_nn, P=P, w_hat=w,  tune_params=hmc_tune_params,
                               Sigma_Z=5)

# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

# %%
begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init)
end=time.time()
# Out:
# HMC 200: accept rate of 100.0 with step size 0.05
# HMC 400: accept rate of 100.0 with step size 0.05149605792925664
# HMC 600: accept rate of 100.0 with step size 0.05299605792925664
# HMC 800: accept rate of 99.875 with step size 0.054496057929256644
# HMC 1000: accept rate of 99.8 with step size 0.055996057929256646
# HMC 1200: accept rate of 99.83333333333333 with step size 0.0574947659062378
# HMC 1400: accept rate of 99.85714285714286 with step size 0.05898888637377429
# HMC 1600: accept rate of 99.875 with step size 0.06048835268356851
# HMC 1800: accept rate of 99.8888888888889 with step size 0.06198835268356851
# HMC 2000: accept rate of 99.9 with step size 0.0634883526835685
# HMC 2200: accept rate of 99.90909090909092 with step size 0.06497280104637061
# HMC 2400: accept rate of 99.91666666666667 with step size 0.06647280104637061
# HMC 2600: accept rate of 99.92307692307692 with step size 0.06796592043713326
# HMC 2800: accept rate of 99.92857142857143 with step size 0.06946380836921373
# HMC 3000: accept rate of 99.9 with step size 0.0709560305975279
# HMC 3200: accept rate of 99.90625 with step size 0.0724560305975279
# HMC 3400: accept rate of 99.91176470588236 with step size 0.07395603059752791
# HMC 3600: accept rate of 99.91666666666667 with step size 0.07545555293115049
# HMC 3800: accept rate of 99.92105263157895 with step size 0.0769533850693078
# HMC 200: accept rate of 100.0
# HMC 400: accept rate of 100.0
# HMC 600: accept rate of 100.0
# HMC 800: accept rate of 100.0
# HMC 1000: accept rate of 100.0
# HMC 1200: accept rate of 100.0
# HMC 1400: accept rate of 99.85714285714286
# HMC 1600: accept rate of 99.8125
# HMC 1800: accept rate of 99.83333333333333
# HMC 2000: accept rate of 99.85
# HMC 2200: accept rate of 99.81818181818181
# HMC 2400: accept rate of 99.83333333333333
# HMC 2600: accept rate of 99.84615384615384
# HMC 2800: accept rate of 99.85714285714286
# HMC 3000: accept rate of 99.86666666666666
# HMC 3200: accept rate of 99.875
# HMC 3400: accept rate of 99.88235294117646
# HMC 3600: accept rate of 99.88888888888889
# HMC 3800: accept rate of 99.86842105263158
# HMC 4000: accept rate of 99.85
# HMC 4200: accept rate of 99.85714285714286
# HMC 4400: accept rate of 99.8409090909091
# HMC 4600: accept rate of 99.82608695652173
# HMC 4800: accept rate of 99.8125
# HMC 5000: accept rate of 99.82
# HMC 5200: accept rate of 99.8076923076923
# HMC 5400: accept rate of 99.81481481481481
# HMC 5600: accept rate of 99.82142857142857
# HMC 5800: accept rate of 99.8103448275862
# HMC 6000: accept rate of 99.81666666666666
# HMC 6200: accept rate of 99.8225806451613
# HMC 6400: accept rate of 99.8125
# HMC 6600: accept rate of 99.81818181818181
# HMC 6800: accept rate of 99.80882352941177
# HMC 7000: accept rate of 99.77142857142857
# HMC 7200: accept rate of 99.76388888888889
# HMC 7400: accept rate of 99.75675675675676
# HMC 7600: accept rate of 99.76315789473684
# HMC 7800: accept rate of 99.75641025641026
# HMC 8000: accept rate of 99.7625
# HMC 8200: accept rate of 99.76829268292683
# HMC 8400: accept rate of 99.77380952380952
# HMC 8600: accept rate of 99.75581395348837
# HMC 8800: accept rate of 99.73863636363636
# HMC 9000: accept rate of 99.73333333333333
# HMC 9200: accept rate of 99.70652173913044
# HMC 9400: accept rate of 99.70212765957447
# HMC 9600: accept rate of 99.6875
# HMC 9800: accept rate of 99.6938775510204
# HMC 10000: accept rate of 99.7
# HMC 10200: accept rate of 99.70588235294117
# HMC 10400: accept rate of 99.70192307692308
# HMC 10600: accept rate of 99.70754716981132
# HMC 10800: accept rate of 99.71296296296296
# HMC 11000: accept rate of 99.66363636363636
# HMC 11200: accept rate of 99.66964285714286
# HMC 11400: accept rate of 99.67543859649123
# HMC 11600: accept rate of 99.68103448275862
# HMC 11800: accept rate of 99.6864406779661
# HMC 12000: accept rate of 99.69166666666666
# HMC 12200: accept rate of 99.69672131147541
# HMC 12400: accept rate of 99.70161290322581
# HMC 12600: accept rate of 99.7063492063492
# HMC 12800: accept rate of 99.6953125
# HMC 13000: accept rate of 99.6923076923077
# HMC 13200: accept rate of 99.68939393939394
# HMC 13400: accept rate of 99.69402985074628
# HMC 13600: accept rate of 99.69852941176471
# HMC 13800: accept rate of 99.69565217391305
# HMC 14000: accept rate of 99.7
# HMC 14200: accept rate of 99.69718309859155
# HMC 14400: accept rate of 99.70138888888889
# HMC 14600: accept rate of 99.70547945205479
# HMC 14800: accept rate of 99.70945945945945
# HMC 15000: accept rate of 99.70666666666666
# HMC 15200: accept rate of 99.70394736842105
# HMC 15400: accept rate of 99.7012987012987
# HMC 15600: accept rate of 99.7051282051282
# HMC 15800: accept rate of 99.70886075949367
# HMC 16000: accept rate of 99.70625
# HMC 16200: accept rate of 99.70987654320987
# HMC 16400: accept rate of 99.71341463414635
# HMC 16600: accept rate of 99.71084337349397
# HMC 16800: accept rate of 99.71428571428571
# HMC 17000: accept rate of 99.71176470588236
# HMC 17200: accept rate of 99.71511627906976
# HMC 17400: accept rate of 99.71264367816092
# HMC 17600: accept rate of 99.7159090909091
# HMC 17800: accept rate of 99.71348314606742
# HMC 18000: accept rate of 99.71111111111111
# HMC 18200: accept rate of 99.71428571428571
# HMC 18400: accept rate of 99.71739130434783
# HMC 18600: accept rate of 99.72043010752688
# HMC 18800: accept rate of 99.72340425531915
# HMC 19000: accept rate of 99.72631578947369
# HMC 19200: accept rate of 99.72916666666667
# HMC 19400: accept rate of 99.73195876288659
# HMC 19600: accept rate of 99.72448979591837
# HMC 19800: accept rate of 99.72727272727273

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 10.91 min

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |HMC')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|HMC')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
post_sample=my_inference.get_posterior(n_samples=10000)
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
for i in range(my_inference.D_z):
#     row = 1
    col = i % 2
    ax[col].plot(range(len(post_sample)), post_sample[:, i], color='gray', alpha=0.7)
fig.suptitle('Trace plots for all neural network parameters')
plt.show()

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_pca_smallest = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_pca_smallest))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -4.7667

# %% [markdown]
# From the test statistics above we can see that PCA with our extension of the smallest deviations does a job as good as the PCA with equal interval published in the paper. However from the posterior predictive plots above, PCA with equal interval is more informative.
#
# `[补充一下为什么smallest deviations没有equal deviation好以及update一下hypothesis]`
#
# To fully test our hypothesis, we also examine PCA's behavior with the larget deviations. Under our hypothesis, this method should have the worst performance both in visualization as well as in test statistics as it captures more unrelavant information in constructing the subspace from those large deviations.

# %% [markdown]
# ### the largest deviations

# %%
my_subspace = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y, method='L') # chose the method as L
P, w = my_subspace.get_space()

# %%
hmc_tune_params={'step_size':5e-2,
                'leapfrog_steps': 10,
                'total_samples': 20000,
                'burn_in': 0.2,
                'warm_start': True,
                'thinning_factor': 2,
                'mom_std': 1,
                'diagnostic_mode': False}

# %%
my_inference = Inference.create(inference_type="HMC", model=my_nn, P=P, w_hat=w,  tune_params=hmc_tune_params,
                               Sigma_Z=5)

# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

# %%
begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init)
end=time.time()
# Out:
# HMC 200: accept rate of 0.0 with step size 0.05
# HMC 400: accept rate of 0.0 with step size 0.0475
# HMC 600: accept rate of 0.0 with step size 0.045
# HMC 800: accept rate of 0.0 with step size 0.042499999999999996
# HMC 1000: accept rate of 0.0 with step size 0.039999999999999994
# HMC 1200: accept rate of 0.0 with step size 0.03749999999999999
# HMC 1400: accept rate of 0.0 with step size 0.03499999999999999
# HMC 1600: accept rate of 0.0 with step size 0.03249999999999999
# HMC 1800: accept rate of 0.0 with step size 0.02999999999999999
# HMC 2000: accept rate of 0.05 with step size 0.02749999999999999
# HMC 2200: accept rate of 0.09090909090909091 with step size 0.02499999999999999
# HMC 2400: accept rate of 3.208333333333333 with step size 0.022499999999999992
# HMC 2600: accept rate of 8.269230769230768 with step size 0.019999999999999993
# HMC 2800: accept rate of 12.714285714285714 with step size 0.019623682229304676
# HMC 3000: accept rate of 15.7 with step size 0.022123682229304675
# HMC 3200: accept rate of 14.75 with step size 0.024623682229304673
# HMC 3400: accept rate of 17.058823529411764 with step size 0.022123682229304675
# HMC 3600: accept rate of 16.13888888888889 with step size 0.024623682229304673
# HMC 3800: accept rate of 18.13157894736842 with step size 0.022123682229304675
# HMC 200: accept rate of 0.0
# HMC 400: accept rate of 28.0
# HMC 600: accept rate of 47.5
# HMC 800: accept rate of 53.875
# HMC 1000: accept rate of 55.2
# HMC 1200: accept rate of 54.75
# HMC 1400: accept rate of 47.642857142857146
# HMC 1600: accept rate of 50.4375
# HMC 1800: accept rate of 54.05555555555556
# HMC 2000: accept rate of 55.95
# HMC 2200: accept rate of 55.36363636363637
# HMC 2400: accept rate of 51.125
# HMC 2600: accept rate of 52.34615384615385
# HMC 2800: accept rate of 52.785714285714285
# HMC 3000: accept rate of 54.333333333333336
# HMC 3200: accept rate of 55.15625
# HMC 3400: accept rate of 57.44117647058823
# HMC 3600: accept rate of 58.80555555555556
# HMC 3800: accept rate of 59.973684210526315
# HMC 4000: accept rate of 61.35
# HMC 4200: accept rate of 62.142857142857146
# HMC 4400: accept rate of 61.63636363636363
# HMC 4600: accept rate of 59.54347826086956
# HMC 4800: accept rate of 60.0
# HMC 5000: accept rate of 60.12
# HMC 5200: accept rate of 61.26923076923077
# HMC 5400: accept rate of 61.44444444444444
# HMC 5600: accept rate of 61.94642857142857
# HMC 5800: accept rate of 62.758620689655174
# HMC 6000: accept rate of 62.95
# HMC 6200: accept rate of 62.854838709677416
# HMC 6400: accept rate of 61.734375
# HMC 6600: accept rate of 61.878787878787875
# HMC 6800: accept rate of 62.11764705882353
# HMC 7000: accept rate of 62.41428571428571
# HMC 7200: accept rate of 62.75
# HMC 7400: accept rate of 62.229729729729726
# HMC 7600: accept rate of 60.81578947368421
# HMC 7800: accept rate of 60.8974358974359
# HMC 8000: accept rate of 60.7375
# HMC 8200: accept rate of 59.84146341463415
# HMC 8400: accept rate of 58.476190476190474
# HMC 8600: accept rate of 58.7906976744186
# HMC 8800: accept rate of 58.67045454545455
# HMC 9000: accept rate of 58.6
# HMC 9200: accept rate of 59.141304347826086
# HMC 9400: accept rate of 59.45744680851064
# HMC 9600: accept rate of 59.75
# HMC 9800: accept rate of 59.52040816326531
# HMC 10000: accept rate of 59.93
# HMC 10200: accept rate of 60.05882352941177
# HMC 10400: accept rate of 60.15384615384615
# HMC 10600: accept rate of 60.34905660377358
# HMC 10800: accept rate of 60.75925925925926
# HMC 11000: accept rate of 60.981818181818184
# HMC 11200: accept rate of 60.75892857142857
# HMC 11400: accept rate of 59.824561403508774
# HMC 11600: accept rate of 59.991379310344826
# HMC 11800: accept rate of 59.889830508474574
# HMC 12000: accept rate of 59.24166666666667
# HMC 12200: accept rate of 59.278688524590166
# HMC 12400: accept rate of 59.41129032258065
# HMC 12600: accept rate of 59.08730158730159
# HMC 12800: accept rate of 58.828125
# HMC 13000: accept rate of 58.723076923076924
# HMC 13200: accept rate of 59.13636363636363
# HMC 13400: accept rate of 59.19402985074627
# HMC 13600: accept rate of 59.36764705882353
# HMC 13800: accept rate of 59.61594202898551
# HMC 14000: accept rate of 59.878571428571426
# HMC 14200: accept rate of 60.24647887323944
# HMC 14400: accept rate of 60.520833333333336
# HMC 14600: accept rate of 60.52739726027397
# HMC 14800: accept rate of 60.58783783783784
# HMC 15000: accept rate of 60.46
# HMC 15200: accept rate of 60.6578947368421
# HMC 15400: accept rate of 60.46103896103896
# HMC 15600: accept rate of 60.56410256410256
# HMC 15800: accept rate of 60.68354430379747
# HMC 16000: accept rate of 60.90625
# HMC 16200: accept rate of 61.25308641975309
# HMC 16400: accept rate of 61.38414634146341
# HMC 16600: accept rate of 61.602409638554214
# HMC 16800: accept rate of 61.69642857142857
# HMC 17000: accept rate of 61.64705882352941
# HMC 17200: accept rate of 61.76744186046512
# HMC 17400: accept rate of 61.90229885057471
# HMC 17600: accept rate of 62.10227272727273
# HMC 17800: accept rate of 62.42134831460674
# HMC 18000: accept rate of 62.61666666666667
# HMC 18200: accept rate of 62.81868131868132
# HMC 18400: accept rate of 63.125
# HMC 18600: accept rate of 63.215053763440864
# HMC 18800: accept rate of 63.18617021276596
# HMC 19000: accept rate of 63.42631578947368
# HMC 19200: accept rate of 63.671875
# HMC 19400: accept rate of 63.845360824742265
# HMC 19600: accept rate of 63.9030612244898
# HMC 19800: accept rate of 63.92424242424242

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 9.73 min

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |HMC')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|HMC')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_pca_largest = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_pca_largest))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -34.6261

# %% [markdown]
# From the plots and test statistics above we can see that PCA with largest deviations does the worst job indeed.

# %% [markdown]
# ## Comparison

# %% [markdown]
# From all the traceplots and documented time above, we can see that all our HMC and BBB sampler has converged in around 10 minutes.
# `[这一段主要是想和不reduce dimension做比较（时间和converge的效果）,我明天继续train一下]`

# %% [markdown]
# From all the posterior predictive plots above we can see that the one from PCA (especially PCA with HMC as inference method) has the most meaningful visualization over uncertainty. To be more specific, it has clearly displayed both aleatoric uncertainty and epistemic uncertainty: it has a wider range of uncertainty over the area where has little data and small narrower range over the area where has more data. By contrast, random subspace construct the projection matrix by random, which by nature can not fully reveal and distinguish those two kinds of uncertainties.

# %% [markdown]
# From all the posterior predictive log-likelihood we can see that PCA (HMC: -4.3521; BBB: -2.7449) does the best job, and PCA with smallest deviation also does a great job (HMC: -4.7667; BBB: -2.9177), and then comes random subspace (HMC: -9.9284; BBB: -58.2702) and PCA with the largest deviation (HMC: -34.6261; BBB: -45.7271).
