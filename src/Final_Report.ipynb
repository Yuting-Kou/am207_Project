# %% [markdown]
# # Subspace Inference of Bayesian Deep Learning and Sensitivity Testing
#
# Yuting Kou, Yizhou Wang, Yiming Xu, Ziyi Zhou
#
# ## 1. Introduction
# Our paper’s name is [Subspace Inference for Bayesian Deep Learning](https://arxiv.org/abs/1907.07504).  In this paper, it is trying to solve the following problem:  Bayesian inference has been a  useful  tool  to  perform  inference  with  neural  networks,  but  using  it  could be  challenging  when  the  neural  network  becomes  deeper  or  larger,  since  the parameter space becomes extremely high dimensional and the posterior distribution is highly zig-zag. ![可以放一个这个图](https://i.ibb.co/54NkMcT/zigzag.png).. **需不需要加点文字描述** Common methods can easily fall into local minima or take a long time to converge. How could we still use Bayesian methods to perform inference with those deep neural networks?  This problem is important in the modern world, because all the neural networks are built to be deeper and wider.  These models can have almost perfect predictions, but other than predictions,  we care about the inference on the parameters in them as well.  We want to know what the predictive distribution and uncertaintylook like.  This paper addresses this issue by an approach, in which the original parameter space is reduced into a low-dimensional subspace by some methods, and  then  we  can  perform  Bayesian  inference  over  the  parameters  within  the subspace.
#
# This paper lists some related work for which the main points are summarized here:
# 1. The SWAG method can define a distribution over low-dimensional subspace, given the first principal components of the stochastic gradient descent (SGD) iterates.  It's useful in getting a Gaussian posterior over neural network weights.
# 2. Bayesian  inference  could  be  applied  to  probabilistic  PCA  using  projected methods for latent variable models.
# 3. Various ways have been proposed to perform variational inference in a low-dimensional subspace for Bayesian neural network.
# 4. There  is  a  theoretical  guarantee  for  Bayesian  inference  in  the  setting  of constrained posteriors.  The constraints (e.g.  the subspace) can be chosen before or after performing unconstrained inference via SGD.
# 5. Other approaches have tried to perform efficient inference by operating solely in data space, rather than in parameter space.
#
# The gap in literature that the paper is trying to fill is that no one previously has proposed the method to approximate Bayesian inference in low-dimensional subspace of the weight space for high-dimensional neural networks.  Therefore, this  method  is  the  authors'  main  contribution  and  they  named  it  `Subspace Inference` (SI)
#
#
#
# ## 2. Technical content
#
# ### 2.1. High level
# Bayesian neural network often involves high dimensional problem over the parameter space. In this paper, they designed a Subspace Inference which conduct dimension reduction over parameter space, then form posterior inference and Bayesian model average. This Subspace Inference shows great performance in terms of accuracy and likelihood and thus implies the low-dimension subspaces contains a rich representations of full space.
#
# On the high level, their proposed Bayesian subspace inference algorithm contains three steps:  1) construct subspace, 2) posterior inference within subspace, 3)  form  a  Bayesian  model  average.   During  the  subspace  construction  stage, they  tried  three  subspaces  including  random  subspace,  the  subspace  spanned by the first few PCA components of the SGD trajectory, and curve subspace. They then propose using various methods including the MCMC methods suchas Hamiltonian Monte Carlo (HMC) or elliptical slice sampling (ESS) for the approximate inference procedures
#
# ### 2.2. Details

# %% [markdown]
# #### Overview
# We perform inference in a K-dimensional subspace $\mathcal{S}$ defined by
# \begin{aligned}
# \mathcal{S} &= \{w|w = \hat{w} + z_1v_1 + \ldots + z_Kv_K\} \\
# &= \{w|w = \hat{w} + Pz\}.
# \end{aligned}
# With a fixed $\hat{w}$ and projection matrix $P$, over which we perform inference, the free parameters of the model are now simply $z\in\mathbb{R}^K$. The new model thus has the likelihood function $$p(\mathcal{D}|z) = p_\mathcal{M}(\mathcal{D}|w = \hat{w} + Pz).$$ We can then perform Bayesian model averaging on new test data points $\mathcal{D}^*$, using the posterior over the parameters in the subspace:
# \begin{aligned}
# p(\mathcal{D}^*|\mathcal{D}) &= \int p_\mathcal{M}(\mathcal{D}^*|\tilde{w} = \hat{w} + Pz)p(z|\mathcal{D})\text{d}z \\
# &\approx \frac{1}{J}\sum_{j=1}^Jp_\mathcal{M}(\mathcal{D}^*|\tilde{w} = \hat{w}+P\tilde{z}_j),\quad \tilde{z}_j \sim p(z|\mathcal{D}).
# \end{aligned}

# %% [markdown]
# #### Subspace Construction
# In this section we will show various ways to construct subspace $\mathcal{S}$.
#
# **1. Random Subspaces**
#
# The basis $P$ is constructed by ranomly drawing $K$ vectors $v_1, \ldots, v_K \sim \mathcal{N}(0, I_p)$ in th weight space. We then rescale them to have norm 1. The shift vector is generated using the weights of a network pre-trained with stochastic weight averaging (SWA): $\hat{w} = w_{\text{SWA}}$. In particular, we run SGD with a high constant learning rate from a pre-trained solution, and form the average $w_{\text{SWA}} = \frac{1}{T}\sum_i w_i$ from the SGD iterates $w_i$.
#
# **2. PCA of the SGD Trajectory**
#
# In the method of PCA, it also uses the $w_{\text{SWA}}$ which is used in random subspace but records additional information during the SGD trajectory. Specifically, we also run SGD with a high constant learning rate from a pre-trained soution, but at each fixed-length interval $c$, we capture the snapshots $w_i$ and use it to update two information:
# - $w_{\text{SWA}}$: the weighted average of previous $w_{\text{SWA}}$ and this $w_i$. (the same in random subspace)
# - deviation vector $a_i$: which equals $w_{\text{SWA}}$ - $w_i$. (only in PCA subspace)
#
# Then given the amount of memory we have, we come up with an number $M$, and we store the last $M$ deviation vector in a single deviation matrix $A$. We then run PCA based on randomized SVD on the matrix $A$ and  use the first $K$ principal component $v_1, \ldots, v_K$ to define the subspace.
#
# **3. Curve Subspaces**
#
# In this method, we find paths of near-constant low loss in the weight space between converged SGD solutions starting from different random initializations. Let $w_0, w_1$ be two sets of weights corresponding to the same neural network. Moreover, let $\phi_\theta: [0,1] \rightarrow \mathbb{R}^d$ be a continuous piecewise smooth parametric curve, with parameters $\theta$, such that $\phi_\theta(0) = w_0, \phi_\theta(1) = w_1$. To find a path of high accuracy between $w_0, w_1$, we propose to find parameters $\theta$ that minimize the expectation over a uniform distribution on the curve, $\hat{l}(\theta)$:
# \begin{aligned}
# \hat{l}(\theta) &= \frac{\int \mathcal{L}(\phi_\theta)\text{d}\phi_\theta}{\int\text{d}\phi_\theta} = \frac{\int_0^1\mathcal{L}(\phi_\theta(t))\|\phi_\theta^{'}(t)\|\text{d}t}{\int_0^1 \|\phi_\theta^{'}(t)\|\text{d}t} \\
# &= \int_0^1 \mathcal{L}(\phi_\theta(t))q_\theta(t)\text{d}t = \mathbb{E}_{t\sim q_\theta(t)}\left[\mathcal{L}(\phi_\theta(t))\right],
# \end{aligned}
# where the distribution $q_\theta(t)$ on $t\in[0, 1]$ is defined as $q_\theta(t) := \|\phi_\theta^{'}(t)\|\cdot\left(\int_0^1 \|\phi_\theta^{'}(t)\|\text{d}t\right)^{-1}.$ Note that stochastic gradients of $\theta$ are generally intractable since $q_\theta(t)$ depends on $\theta$. Therefore we will use a more computationally tractable loss:
# $$
# l(\theta) = \int_0^1 \mathcal{L}(\phi_\theta(t))\text{d}t = \mathbb{E}_{t\sim U(0,1)}\mathcal{L}(\phi_\theta(t)).
# $$
# To minimize $l(\theta)$, at each iteration we sample $\tilde{t}$ from the unifrom distribution $U(0,1)$ and make a gradient step for $\theta$ with respect to the loss $\mathcal{L}(\phi_\theta(\tilde{t}))$. This way we can get unbiased estimates of the gradient of $l(\theta)$:
# $$
# \nabla_\theta\mathcal{L}(\phi_\theta(\tilde{t})) = \mathbb{E}_{t\sim U(0,1)} \nabla_\theta \mathcal{L}(\phi_\theta(t)) = \nabla_\theta \mathbb{E}_{t\sim U(0,1)} \mathcal{L}(\phi_\theta(t)) = \nabla_\theta l(\theta).
# $$
# Then we can perform gradient descent on $\theta$ to obtain the optimal curve.
#
#
# In this work we employ the **Polygonal chain**. The trained weights $w_0$ and $w_1$ serve as the endpoints of the chain and the bends of the chain are the parameters $\theta$ of the curve parametrization. We only consider the simplest case of a chain with one bend $\theta$. Then
# $$
# \phi_\theta = \begin{cases} 2(t\theta + (0.5-t)w_0), & 0 \leq t \leq 0.5 \\
# 2((t-0.5)w_1 + (1-t)\theta), & 0.5 < t \leq 1. \end{cases}
# $$

# %% [markdown]
# ### Experiments
#
# They then compare the subspace inference methods on UCI regression tasks to a variety of methods for approximate Bayesian inference with neural networks. This time the comparison is done quantitatively and they compute Gaussian test likelihood as the metric. They show that subspace inference achieves as good or better test log-likelihoods compared to SGD and SWAG on the original parameter space.
#
#
# Next, they test the proposed method on state-of-the-art convolutional networks on CIFAR datasets. They report the accuracy and negative log-likelihood for each of the subspaces. Going from random, to PCA, to curve subspaces provides progressively better results. It's also shown that subspace inference is competitive with SWAG and consistently outperforms most of the other baselines, including MC-dropout.

# %% [markdown]
# ### Evaluation
# The authors of the paper evaluate subspace inference by combining the three subspaces with different approximate posterior inference methods.  They first compare the performance of each combination on their data and show the comparison visually by drawing the predictive distribution.  From the visualization plots on their data, they find that all the inference methods would work with the random and PCA subspace, but since the curve subspace has a more complex shaped posterior, variational methods do not produce reasonable fits.  The plots also show that the random subspace does not allow growing uncertainty when farther away from the data,  whereas the curve  subspace is the best to adapt uncertainty.
#
#
# They essentially want to prove subspace inference can do just as well as performing inference in the original parameter space, or even better, so they visualize the predictive distributions for simple variational inference applied in the original parameter space. From the visualization, they see the SWAG's predictive distribution is similar to the PCA subspace's one. However, variational inference tends to underfit data, and Gaussian process (GP) with an RBF kernel becomes underconfident when farther away from the neighborhood of data, meaning that uncertainty quickly blows up. It's shown in this procedure that subspace inference might show even better results than original-space inference.
#
#
# It's interesting to see that subspaces can be chosen to contain a diverse variety of representations, corresponding to different high quality predictions. It's also surprising to see that subspace inference can outperform inference in original parameter space sometimes. This work is definitely technically sound as it provides an easier yet promising way for inference with neural networks. The proposed method is practical to use on real data, as people using it only need to train a neural network, find the lower-dimension subspace, perform a much easier inference in the subspace, and convert back to the original parameter space. The experimental section contains enough evidence to support the claims.

# %% [markdown]
# ## 3. Our Extension: Sensitivity Testing
#
#
# Now, we are going to follow the guidance of this paper to conduct our own experiments, to test whether the subspace inference method can be generalized onto a smaller dataset and various hypotheses that are related to the network structure and subspace construction. In our project, we are interested in the stability of this Subspace Inference framework. More specifically, we test its sensitivity from two aspects:
# 1. How does subspace method improve the Bayesian deep neural network in terms of efficiency and uncertainty estimation?
# 2. Does it display similar performance over deep and wide neural network?
# 3. Does it sensitive to the initial value to start with?
#
# We also expand PCA subspace with different "SWA" methods: instead of update the deviation matrix every T steps , we choose to update the deviation matrix with the smallest deviations.
#
# For more detailed information about our extension, please see **4.3.**

# %% [markdown]
# ## 4. Experiments
# ### 4.1. Code structure
#
# Following is our code structure: ![code structure](https://i.ibb.co/ggmrRfY/2.png) We use the unify structure of `model`, `subspace` and `inference` class, and enable the same API usage.
#
# ### 4.2. Toy example

# %%
import matplotlib.pyplot as plt
from autograd import numpy as np
import time
from Inference import Inference
from Subspace import Subspace
from model import Model
import CurveSubspace as curve
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim
from mpl_toolkits.mplot3d import Axes3D
from util import hidecode
# hidecode()            % --------- remember to remove comments after finishing all the code. This function can simplify the code

# %%
data = np.genfromtxt(r'../example/hw7_data.csv', delimiter=',')[1:]
x, y = data[:, 0], data[:, 1]

alpha = 1
c = 0
h = lambda x: np.exp(-alpha * (x - c)**2)

###neural network model design choices
width = 5
hidden_layers = 1
input_dim = 1
output_dim = 1

architecture = {'width': width,
               'hidden_layers': hidden_layers,
               'input_dim': input_dim,
               'output_dim': output_dim,
               'activation_fn_type': 'rbf',
               'activation_fn_params': 'c=0, alpha=1',
               'activation_fn': h}

# set random state to make the experiments replicable
rand_state = 0
random = np.random.RandomState(rand_state)

# create a model and train the model
my_nn = Model.create(submodel_type="Feedforward", architecture=architecture, Sigma_Y=0.25)

# use MSE result as params_init
params = {'step_size':1e-3, 
          'max_iteration':5000, 
          'random_restarts':1}

# fit my neural network to minimize MSE on the given data
my_nn.fit(x_train=x.reshape((1, -1)), y_train=y.reshape((1, -1)), params=params)
# Out:
# Iteration 0 lower bound 65.1166805377315; gradient mag: 164.73210946091575
# Iteration 100 lower bound 52.86436046756695; gradient mag: 56.95458639088457
# Iteration 200 lower bound 49.42633385370295; gradient mag: 28.31627548203755
# Iteration 300 lower bound 47.73326189562314; gradient mag: 18.311751879565836
# Iteration 400 lower bound 46.647745693540806; gradient mag: 13.47755254054697
# Iteration 500 lower bound 45.88691542805831; gradient mag: 10.503599898310592
# Iteration 600 lower bound 45.25067576634; gradient mag: 8.654932255566825
# Iteration 700 lower bound 30.562858257343013; gradient mag: 24.192575322800902
# Iteration 800 lower bound 26.97792508592485; gradient mag: 20.354176994190937
# Iteration 900 lower bound 24.278363637665734; gradient mag: 18.77912591689822
# Iteration 1000 lower bound 22.029867169404948; gradient mag: 17.427416991221943
# Iteration 1100 lower bound 20.10610040886032; gradient mag: 16.21045518866593
# Iteration 1200 lower bound 18.434367471681025; gradient mag: 15.092044558814077
# Iteration 1300 lower bound 16.967826824623163; gradient mag: 14.051620576729908
# Iteration 1400 lower bound 15.673763205688546; gradient mag: 13.076506887891881
# Iteration 1500 lower bound 14.527850196693981; gradient mag: 12.158583034329935
# Iteration 1600 lower bound 13.511041180892443; gradient mag: 11.292691333772902
# Iteration 1700 lower bound 12.60773762799294; gradient mag: 10.475901826346682
# Iteration 1800 lower bound 11.804614404003857; gradient mag: 9.707342852428733
# Iteration 1900 lower bound 11.08977327305976; gradient mag: 8.988599356616403
# Iteration 2000 lower bound 10.452003162028152; gradient mag: 8.32495407522392
# Iteration 2100 lower bound 9.87992684520345; gradient mag: 7.728107510229668
# Iteration 2200 lower bound 9.360728932888753; gradient mag: 7.221146412450927
# Iteration 2300 lower bound 8.878118698993092; gradient mag: 6.843182251011429
# Iteration 2400 lower bound 8.410371873546007; gradient mag: 6.627021939587407
# Iteration 2500 lower bound 7.937214402172414; gradient mag: 6.461888287390538
# Iteration 2600 lower bound 7.471807925987624; gradient mag: 6.054967192028709
# Iteration 2700 lower bound 7.048560738747637; gradient mag: 5.623261826592471
# Iteration 2800 lower bound 6.657649714610486; gradient mag: 5.301596015489049
# Iteration 2900 lower bound 6.286937924356821; gradient mag: 5.005817266509643
# Iteration 3000 lower bound 5.932348941430826; gradient mag: 4.738230196194087
# Iteration 3100 lower bound 5.591133620620948; gradient mag: 4.496972816298515
# Iteration 3200 lower bound 5.26127545540811; gradient mag: 4.278187646372165
# Iteration 3300 lower bound 4.94145795934148; gradient mag: 4.078179065269133
# Iteration 3400 lower bound 4.6310060561160205; gradient mag: 3.893374295011214
# Iteration 3500 lower bound 4.329797769584354; gradient mag: 3.720413244585381
# Iteration 3600 lower bound 4.038157311705764; gradient mag: 3.5562692067094743
# Iteration 3700 lower bound 3.756740063917853; gradient mag: 3.3983369913380335
# Iteration 3800 lower bound 3.4864181903710874; gradient mag: 3.244478137088563
# Iteration 3900 lower bound 3.228173818091557; gradient mag: 3.0930278431838505
# Iteration 4000 lower bound 2.9830049840819997; gradient mag: 2.9427729212293756
# Iteration 4100 lower bound 2.7518476624500345; gradient mag: 2.7929113696219305
# Iteration 4200 lower bound 2.535515098891551; gradient mag: 2.6430034941530747
# Iteration 4300 lower bound 2.334653699118807; gradient mag: 2.492922187032353
# Iteration 4400 lower bound 2.1497133142884643; gradient mag: 2.3428066637339153
# Iteration 4500 lower bound 1.9809292604652153; gradient mag: 2.193020647459891
# Iteration 4600 lower bound 1.8283137632422373; gradient mag: 2.0441136627500596
# Iteration 4700 lower bound 1.691655364964971; gradient mag: 1.8967832576590373
# Iteration 4800 lower bound 1.570525681259662; gradient mag: 1.7518364695730453
# Iteration 4900 lower bound 1.4642933738374684; gradient mag: 1.610150058676236

# %%
x_test = np.linspace(-10, 10, 1000).reshape(1,-1)
y_test = my_nn.forward(x_test, use_subweights = False, weights = my_nn.weights)[0]
plt.scatter(x, y, alpha = 0.3)
plt.plot(x_test[0], y_test[0], color = 'red')
plt.xlabel('X')
plt.ylabel('Y');

# %% [markdown]
# #### 4.2.1 Subspace Construct

# %% [markdown]
# **Random Subspace.**

# %%
begin=time.time()
my_subspace_rand = Subspace.create(subspace_type="random", model=my_nn, n_subspace=2)
my_subspace_rand.collect_vector(X=x, y=y)
end=time.time()
print('It costs {:.2f} sec to calculate Random Subspace'.format(end-begin) )
# Out:
# It costs 6.71 sec to calculate Random Subspace

# %% [markdown]
# **PCA Subspace.**

# %%
begin=time.time()
my_subspace_pca = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace_pca.collect_vector(X=x, y=y)
end=time.time()
print('It costs {:.2f} sec to calculate PCA Subspace'.format(end-begin) )
# Out:
# It costs 7.13 sec to calculate PCA Subspace

# %% [markdown]
# **Curve Subspace.**

# %%
def CurveNetGen(w0, w1):
    return curve.CurveNet(1, width, hidden_layers, w0, w1)

# for training the mid-points
params_curve = {'sample_size': 500}
net = curve.BaseNet(1, width, hidden_layers)

optimizer = optim.Adam(net.parameters(), lr = 0.001)
criterion = nn.MSELoss()

dataset = TensorDataset(torch.Tensor(x.reshape(-1, 1)), torch.Tensor(y))
loader = DataLoader(dataset, batch_size=64, shuffle = True)

# for training the two endpoints
#params_base = {'epochs': 1000}
params_base = params
begin=time.time()
my_subspace_curve = Subspace.create(subspace_type="curve", net = net, params_base = params_base, nn = my_nn, 
                              X = x, y = y, loader = loader, criterion = criterion, 
                              curve_net_gen = CurveNetGen, params_curve = params_curve)
my_subspace_curve.collect_vector(epochs = 200, callback = 20, restart = False)
end=time.time()
# Out:
# [epoch 1] loss: 0.234
# [epoch 21] loss: 0.229
# [epoch 41] loss: 0.228
# [epoch 61] loss: 0.226
# [epoch 81] loss: 0.225
# [epoch 101] loss: 0.224
# [epoch 121] loss: 0.217
# [epoch 141] loss: 0.222
# [epoch 161] loss: 0.219
# [epoch 181] loss: 0.219

# %%
print('It costs {:.2f} sec to calculate Curve Subspace'.format(end-begin) )
# Out:
# It costs 122.12 sec to calculate Curve Subspace

# %% [markdown]
# Curve subspace is 20 times more than PCA and random subspace.

# %% [markdown]
# #### 4.2.2 Subspace Inference

# %% [markdown]
# There are 3 parameters that we can deal with:
#
# - leapfrog_steps = 10
# - adjust epislon to tune the acceptance rate to an acceptable value (0.651)
# - mass matrix
#
# For this pset, I will focus on the former 2. (The suggested params are found through https://mc-stan.org/docs/2_20/reference-manual/hmc-algorithm-parameters.html)

# %% [markdown]
# **todo:**
# PCA+RANDOM+(curve) 和HMC+BBB的结果放过来。可以有表格的方式。

# %% [markdown]
# #### 4.2.3 Conclusion and Discussion

# %% [markdown]
# |Subspace Method|Inference Method|Subspace Construction (sec)|Subspace Inference (sec)|Total (sec)|
# |---------------|----------------|---------------------|------------------|-----|
# |Random Subspace | HMC| 6.71|637.8|644.51|
# |Random Subspace | BBB| 6.71|559.2|565.91|
# |PCA Subspace | HMC| 7.13|535.2|542.33|
# |PCA Subspace | BBB| 7.13|604.8|506.12|
# |Curve Subspace | HMC| 122.12|384.9|507.02|
# |Curve Subspace | BBB| 122.12|1738.8|1860.92|

# %% [markdown]
# ### 4.3. Extension

# %% [markdown]
# #### 4.3.1. Subspace Methods VS Original Dimension
# (To make the notebook as concise as possible, we only keep the relevant output in this section. To see the complete code of this extension, please visit: https://github.com/YimingXu1213/am207_Project/blob/master/src/originDimension.ipynb)
#
# To fully test the improvement of subspace method regarding Bayesian deep neural network in terms of efficiency and uncertainty estimation, we compare their results with the one from converged HMC sampler on full parameter space both in terms of uncertainty visualization and time consumption.
#
# We trained the HMC sampler in full parameter space as follows:

# %%
###Bayesian model parameterss
#covariance matrix of the Gaussian prior on weights
Sigma_W = 5**2 * np.eye(nn.D)
#Gaussian likelihood std
sigma_y = 0.5
#number of data points
N = 12
#precision matrix of the Gaussian prior on weights
Sigma_W_inv = np.linalg.inv(Sigma_W)
#determinant of the covaraince matrix of the Gaussian prior on weights
Sigma_W_det = np.linalg.det(Sigma_W)

###definition of the log prior
def log_prior(W):
    assert len(W.shape) == 2 and W.shape[1] == nn.D
    S = len(W)
    constant_W = -0.5 * (nn.D * np.log(2 * np.pi) + np.log(Sigma_W_det))
    exponential_W = -0.5 * np.diag(np.dot(np.dot(W, Sigma_W_inv), W.T))
    assert exponential_W.shape == (S, )
    log_p_W = constant_W + exponential_W
    return log_p_W

###definition of the log likelihood
def log_lklhd(W):
    assert len(W.shape) == 2 and W.shape[1] == nn.D
    S = W.shape[0]
    constant = (-np.log(sigma_y) - 0.5 * np.log(2 * np.pi)) * N
    exponential = -0.5 * sigma_y**-2 * np.sum((y.reshape(1, -1).reshape((1, 1, N)) - nn.forward(W, x.reshape(1, -1)))**2, axis=2).flatten()
    assert exponential.shape == (S, )
    return constant + exponential

def joint_log_nn(W):
    return log_prior(W) + log_lklhd(W)

# %%
params_nn_converge = {'step_size':0.01, 
          'leapfrog_steps':10, 
          'total_samples':500000, 
          'burn_in':.1, 
          'thinning_factor':2,
          'position_init': nn.weights.reshape((1, nn.D))}

U_function_nn = lambda W: -joint_log_nn(W)

# %%
def get_HMC(U_function, params):
    """
    Input
    ----------    
    U_function : func
    params: a dictionary, containing key-value pairs as follows:
        step_size: float
        leapfrog_steps: int
        total_samples: int
        burn_in: float
        thinning_factor: int
        position_init: np.array, with shape (D, )


    Output
    -------
    np.array, with shape (n_samples_clean, D)
    """
    # read parameters
    step_size = params['step_size']
    leapfrog_steps = params['leapfrog_steps']
    total_samples = params['total_samples']
    burn_in = params['burn_in']
    thinning_factor = params['thinning_factor']
    position_init = params['position_init']

    dUdq = grad(U_function) # define dUdq   
    
    samples = list([position_init]) 
    size = (total_samples, ) + (position_init.shape[-1], ) # define the size of output
    
    momentum = st.norm(0, 1)
    alpha_list = []
    for p0 in momentum.rvs(size = size): # directly generate moments for shape (n_samples, n_params)
        # Leap-Frog Integration
        q_new, p_new = leap_frog(samples[-1], p0, dUdq, leapfrog_steps, step_size)

        # correction for simulation error
        cur_total = U_function(samples[-1]) - np.sum(momentum.logpdf(p0))
        new_total = U_function(q_new) - np.sum(momentum.logpdf(p_new))
        
        alpha = min(1, np.exp(cur_total - new_total))
        u = np.random.uniform(0,1)
        
        # constantly adjust the step_size according to acceptance rate
        if alpha < 0.5:
            step_size -= (0.5 - float(alpha)) * 0.005
        elif alpha > 0.7:
            step_size += (float(alpha) - 0.7) * 0.005
        alpha_list.append(alpha)
        
        if u <= alpha:
            samples.append(q_new)
        else:
            samples.append(np.copy(samples[-1]))
        if (len(samples) - 1) % 100 == 0:
            print('{0} Samples. Acceptance Rate: {1:6.2f} % step_size : {2:6.4f}'.format(len(samples)-1, float(np.mean(alpha_list[len(samples)-101:len(samples)-1]) * 100), step_size))
    
    output_samples = np.array(samples[1:]).reshape(total_samples, position_init.shape[-1]) 
    
    return output_samples[int(burn_in * total_samples)::thinning_factor]

# %%
begin=time.time()
np.random.seed(2019)
samples_nn_HMC_converge = get_HMC(U_function_nn, params_nn_converge)
end=time.time()
# Out:
# 100 Samples. Acceptance Rate:  62.50 % step_size : 0.0125
# 200 Samples. Acceptance Rate:  62.16 % step_size : 0.0158
# 300 Samples. Acceptance Rate:  63.55 % step_size : 0.0252
# 400 Samples. Acceptance Rate:  61.86 % step_size : 0.0238
# 500 Samples. Acceptance Rate:  60.43 % step_size : 0.0190
# 600 Samples. Acceptance Rate:  62.87 % step_size : 0.0211
# 700 Samples. Acceptance Rate:  62.13 % step_size : 0.0225
# 800 Samples. Acceptance Rate:  62.78 % step_size : 0.0295
# 900 Samples. Acceptance Rate:  61.22 % step_size : 0.0282
# 1000 Samples. Acceptance Rate:  60.05 % step_size : 0.0225
# 1100 Samples. Acceptance Rate:  60.95 % step_size : 0.0208
# 1200 Samples. Acceptance Rate:  63.55 % step_size : 0.0258
# 1300 Samples. Acceptance Rate:  62.44 % step_size : 0.0298
# 1400 Samples. Acceptance Rate:  61.70 % step_size : 0.0264
# 1500 Samples. Acceptance Rate:  61.30 % step_size : 0.0240
# 1600 Samples. Acceptance Rate:  60.17 % step_size : 0.0172
# 1700 Samples. Acceptance Rate:  64.04 % step_size : 0.0254
# 1800 Samples. Acceptance Rate:  60.78 % step_size : 0.0178
# 1900 Samples. Acceptance Rate:  61.12 % step_size : 0.0161
# 2000 Samples. Acceptance Rate:  61.85 % step_size : 0.0184
# 2100 Samples. Acceptance Rate:  62.69 % step_size : 0.0187
# 2200 Samples. Acceptance Rate:  63.01 % step_size : 0.0214
# 2300 Samples. Acceptance Rate:  63.53 % step_size : 0.0255
# 2400 Samples. Acceptance Rate:  63.32 % step_size : 0.0265
# 2500 Samples. Acceptance Rate:  62.54 % step_size : 0.0268
# 2600 Samples. Acceptance Rate:  60.21 % step_size : 0.0196
# 2700 Samples. Acceptance Rate:  59.40 % step_size : 0.0116
# 2800 Samples. Acceptance Rate:  62.58 % step_size : 0.0176
# 2900 Samples. Acceptance Rate:  62.44 % step_size : 0.0198
# 3000 Samples. Acceptance Rate:  60.46 % step_size : 0.0156
# 3100 Samples. Acceptance Rate:  62.63 % step_size : 0.0180
# 3200 Samples. Acceptance Rate:  61.80 % step_size : 0.0194
# 3300 Samples. Acceptance Rate:  62.72 % step_size : 0.0239
# 3400 Samples. Acceptance Rate:  60.52 % step_size : 0.0192
# 3500 Samples. Acceptance Rate:  62.78 % step_size : 0.0242
# 3600 Samples. Acceptance Rate:  59.91 % step_size : 0.0176
# 3700 Samples. Acceptance Rate:  64.16 % step_size : 0.0256
# 3800 Samples. Acceptance Rate:  60.41 % step_size : 0.0209
# 3900 Samples. Acceptance Rate:  63.23 % step_size : 0.0246
# 4000 Samples. Acceptance Rate:  61.09 % step_size : 0.0200
# 4100 Samples. Acceptance Rate:  63.01 % step_size : 0.0232
# 4200 Samples. Acceptance Rate:  63.25 % step_size : 0.0279
# 4300 Samples. Acceptance Rate:  59.49 % step_size : 0.0174
# 4400 Samples. Acceptance Rate:  63.75 % step_size : 0.0227
# 4500 Samples. Acceptance Rate:  62.10 % step_size : 0.0226
# 4600 Samples. Acceptance Rate:  62.60 % step_size : 0.0229
# 4700 Samples. Acceptance Rate:  63.29 % step_size : 0.0270
# 4800 Samples. Acceptance Rate:  61.08 % step_size : 0.0219
# 4900 Samples. Acceptance Rate:  61.25 % step_size : 0.0207
# 5000 Samples. Acceptance Rate:  65.08 % step_size : 0.0305
# 5100 Samples. Acceptance Rate:  61.43 % step_size : 0.0282
# 5200 Samples. Acceptance Rate:  61.45 % step_size : 0.0258
# 5300 Samples. Acceptance Rate:  62.98 % step_size : 0.0283
# 5400 Samples. Acceptance Rate:  60.95 % step_size : 0.0237
# 5500 Samples. Acceptance Rate:  60.74 % step_size : 0.0172
# 5600 Samples. Acceptance Rate:  62.29 % step_size : 0.0189
# 5700 Samples. Acceptance Rate:  62.20 % step_size : 0.0181
# 5800 Samples. Acceptance Rate:  62.21 % step_size : 0.0194
# 5900 Samples. Acceptance Rate:  62.13 % step_size : 0.0203
# 6000 Samples. Acceptance Rate:  63.56 % step_size : 0.0274
# 6100 Samples. Acceptance Rate:  61.99 % step_size : 0.0275
# 6200 Samples. Acceptance Rate:  60.44 % step_size : 0.0238
# 6300 Samples. Acceptance Rate:  63.61 % step_size : 0.0270
# 6400 Samples. Acceptance Rate:  62.55 % step_size : 0.0298
# 6500 Samples. Acceptance Rate:  61.29 % step_size : 0.0244
# 6600 Samples. Acceptance Rate:  61.44 % step_size : 0.0226
# 6700 Samples. Acceptance Rate:  60.44 % step_size : 0.0197
# 6800 Samples. Acceptance Rate:  63.73 % step_size : 0.0255
# 6900 Samples. Acceptance Rate:  61.28 % step_size : 0.0219
# 7000 Samples. Acceptance Rate:  63.17 % step_size : 0.0260
# 7100 Samples. Acceptance Rate:  61.21 % step_size : 0.0209
# 7200 Samples. Acceptance Rate:  62.89 % step_size : 0.0268
# 7300 Samples. Acceptance Rate:  61.70 % step_size : 0.0241
# 7400 Samples. Acceptance Rate:  60.51 % step_size : 0.0175
# 7500 Samples. Acceptance Rate:  62.46 % step_size : 0.0190
# 7600 Samples. Acceptance Rate:  64.69 % step_size : 0.0288
# 7700 Samples. Acceptance Rate:  61.80 % step_size : 0.0271
# 7800 Samples. Acceptance Rate:  62.98 % step_size : 0.0305
# 7900 Samples. Acceptance Rate:  61.33 % step_size : 0.0265
# 8000 Samples. Acceptance Rate:  62.17 % step_size : 0.0283
# 8100 Samples. Acceptance Rate:  61.08 % step_size : 0.0251
# 8200 Samples. Acceptance Rate:  62.16 % step_size : 0.0260
# 8300 Samples. Acceptance Rate:  62.90 % step_size : 0.0280
# 8400 Samples. Acceptance Rate:  60.33 % step_size : 0.0226
# 8500 Samples. Acceptance Rate:  62.83 % step_size : 0.0235
# 8600 Samples. Acceptance Rate:  62.12 % step_size : 0.0220
# 8700 Samples. Acceptance Rate:  62.93 % step_size : 0.0225
# 8800 Samples. Acceptance Rate:  63.34 % step_size : 0.0257
# 8900 Samples. Acceptance Rate:  60.39 % step_size : 0.0190
# 9000 Samples. Acceptance Rate:  63.91 % step_size : 0.0272
# 9100 Samples. Acceptance Rate:  63.12 % step_size : 0.0298
# 9200 Samples. Acceptance Rate:  59.29 % step_size : 0.0164
# 9300 Samples. Acceptance Rate:  65.15 % step_size : 0.0264
# 9400 Samples. Acceptance Rate:  59.64 % step_size : 0.0146
# 9500 Samples. Acceptance Rate:  61.30 % step_size : 0.0136
# 9600 Samples. Acceptance Rate:  63.54 % step_size : 0.0198
# 9700 Samples. Acceptance Rate:  63.05 % step_size : 0.0233
# 9800 Samples. Acceptance Rate:  62.77 % step_size : 0.0262
# 9900 Samples. Acceptance Rate:  61.71 % step_size : 0.0242
# 10000 Samples. Acceptance Rate:  60.90 % step_size : 0.0208
# 10100 Samples. Acceptance Rate:  61.26 % step_size : 0.0155
# 10200 Samples. Acceptance Rate:  64.72 % step_size : 0.0235
# 10300 Samples. Acceptance Rate:  61.56 % step_size : 0.0214
# 10400 Samples. Acceptance Rate:  62.47 % step_size : 0.0222
# 10500 Samples. Acceptance Rate:  60.93 % step_size : 0.0164
# 10600 Samples. Acceptance Rate:  62.38 % step_size : 0.0179
# 10700 Samples. Acceptance Rate:  64.13 % step_size : 0.0265
# 10800 Samples. Acceptance Rate:  63.71 % step_size : 0.0339
# 10900 Samples. Acceptance Rate:  58.65 % step_size : 0.0209
# 11000 Samples. Acceptance Rate:  64.04 % step_size : 0.0287
# 11100 Samples. Acceptance Rate:  61.93 % step_size : 0.0302
# 11200 Samples. Acceptance Rate:  60.43 % step_size : 0.0227
# 11300 Samples. Acceptance Rate:  62.27 % step_size : 0.0240
# 11400 Samples. Acceptance Rate:  61.29 % step_size : 0.0236
# 11500 Samples. Acceptance Rate:  62.78 % step_size : 0.0278
# 11600 Samples. Acceptance Rate:  58.74 % step_size : 0.0155
# 11700 Samples. Acceptance Rate:  63.97 % step_size : 0.0209
# 11800 Samples. Acceptance Rate:  60.15 % step_size : 0.0143
# 11900 Samples. Acceptance Rate:  61.76 % step_size : 0.0144
# 12000 Samples. Acceptance Rate:  63.21 % step_size : 0.0182
# 12100 Samples. Acceptance Rate:  63.90 % step_size : 0.0238
# 12200 Samples. Acceptance Rate:  63.67 % step_size : 0.0284
# 12300 Samples. Acceptance Rate:  60.40 % step_size : 0.0196
# 12400 Samples. Acceptance Rate:  61.66 % step_size : 0.0201
# 12500 Samples. Acceptance Rate:  61.89 % step_size : 0.0204
# 12600 Samples. Acceptance Rate:  62.69 % step_size : 0.0244
# 12700 Samples. Acceptance Rate:  62.49 % step_size : 0.0259
# 12800 Samples. Acceptance Rate:  60.25 % step_size : 0.0198
# 12900 Samples. Acceptance Rate:  62.62 % step_size : 0.0222
# 13000 Samples. Acceptance Rate:  63.71 % step_size : 0.0265
# 13100 Samples. Acceptance Rate:  60.05 % step_size : 0.0206
# 13200 Samples. Acceptance Rate:  63.28 % step_size : 0.0256
# 13300 Samples. Acceptance Rate:  61.49 % step_size : 0.0248
# 13400 Samples. Acceptance Rate:  60.09 % step_size : 0.0186
# 13500 Samples. Acceptance Rate:  63.12 % step_size : 0.0221
# 13600 Samples. Acceptance Rate:  63.33 % step_size : 0.0262
# 13700 Samples. Acceptance Rate:  59.50 % step_size : 0.0187
# 13800 Samples. Acceptance Rate:  63.30 % step_size : 0.0261
# 13900 Samples. Acceptance Rate:  58.33 % step_size : 0.0131
# 14000 Samples. Acceptance Rate:  60.71 % step_size : 0.0101
# 14100 Samples. Acceptance Rate:  62.08 % step_size : 0.0085
# 14200 Samples. Acceptance Rate:  63.05 % step_size : 0.0108
# 14300 Samples. Acceptance Rate:  62.06 % step_size : 0.0099
# 14400 Samples. Acceptance Rate:  62.56 % step_size : 0.0131
# 14500 Samples. Acceptance Rate:  61.48 % step_size : 0.0100
# 14600 Samples. Acceptance Rate:  62.50 % step_size : 0.0101
# 14700 Samples. Acceptance Rate:  62.70 % step_size : 0.0105
# 14800 Samples. Acceptance Rate:  63.17 % step_size : 0.0158
# 14900 Samples. Acceptance Rate:  63.98 % step_size : 0.0243
# 15000 Samples. Acceptance Rate:  62.42 % step_size : 0.0264
# 15100 Samples. Acceptance Rate:  62.06 % step_size : 0.0261
# 15200 Samples. Acceptance Rate:  60.82 % step_size : 0.0214
# 15300 Samples. Acceptance Rate:  62.89 % step_size : 0.0207
# 15400 Samples. Acceptance Rate:  64.47 % step_size : 0.0268
# 15500 Samples. Acceptance Rate:  60.69 % step_size : 0.0211
# 15600 Samples. Acceptance Rate:  61.95 % step_size : 0.0197
# 15700 Samples. Acceptance Rate:  62.17 % step_size : 0.0221
# 15800 Samples. Acceptance Rate:  60.89 % step_size : 0.0198
# 15900 Samples. Acceptance Rate:  62.72 % step_size : 0.0224
# 16000 Samples. Acceptance Rate:  62.10 % step_size : 0.0211
# 16100 Samples. Acceptance Rate:  63.18 % step_size : 0.0212
# 16200 Samples. Acceptance Rate:  63.22 % step_size : 0.0277
# 16300 Samples. Acceptance Rate:  62.23 % step_size : 0.0279
# 16400 Samples. Acceptance Rate:  61.64 % step_size : 0.0250
# 16500 Samples. Acceptance Rate:  61.12 % step_size : 0.0208
# 16600 Samples. Acceptance Rate:  64.87 % step_size : 0.0299
# 16700 Samples. Acceptance Rate:  60.19 % step_size : 0.0217
# 16800 Samples. Acceptance Rate:  63.10 % step_size : 0.0261
# 16900 Samples. Acceptance Rate:  61.40 % step_size : 0.0229
# 17000 Samples. Acceptance Rate:  62.29 % step_size : 0.0252
# 17100 Samples. Acceptance Rate:  62.41 % step_size : 0.0280
# 17200 Samples. Acceptance Rate:  60.90 % step_size : 0.0259
# 17300 Samples. Acceptance Rate:  63.14 % step_size : 0.0293
# 17400 Samples. Acceptance Rate:  60.10 % step_size : 0.0215
# 17500 Samples. Acceptance Rate:  62.49 % step_size : 0.0226
# 17600 Samples. Acceptance Rate:  60.59 % step_size : 0.0152
# 17700 Samples. Acceptance Rate:  64.58 % step_size : 0.0228
# 17800 Samples. Acceptance Rate:  62.79 % step_size : 0.0265
# 17900 Samples. Acceptance Rate:  62.02 % step_size : 0.0266
# 18000 Samples. Acceptance Rate:  60.20 % step_size : 0.0184
# 18100 Samples. Acceptance Rate:  64.40 % step_size : 0.0275
# 18200 Samples. Acceptance Rate:  61.16 % step_size : 0.0253
# 18300 Samples. Acceptance Rate:  61.66 % step_size : 0.0260
# 18400 Samples. Acceptance Rate:  61.32 % step_size : 0.0235
# 18500 Samples. Acceptance Rate:  61.27 % step_size : 0.0198
# 18600 Samples. Acceptance Rate:  61.12 % step_size : 0.0173
# 18700 Samples. Acceptance Rate:  62.39 % step_size : 0.0180
# 18800 Samples. Acceptance Rate:  63.17 % step_size : 0.0237
# 18900 Samples. Acceptance Rate:  61.00 % step_size : 0.0193
# 19000 Samples. Acceptance Rate:  62.56 % step_size : 0.0186
# 19100 Samples. Acceptance Rate:  62.75 % step_size : 0.0217
# 19200 Samples. Acceptance Rate:  61.98 % step_size : 0.0238
# 19300 Samples. Acceptance Rate:  61.44 % step_size : 0.0229
# 19400 Samples. Acceptance Rate:  59.92 % step_size : 0.0177
# 19500 Samples. Acceptance Rate:  64.18 % step_size : 0.0268
# 19600 Samples. Acceptance Rate:  62.60 % step_size : 0.0282
# 19700 Samples. Acceptance Rate:  60.14 % step_size : 0.0217
# 19800 Samples. Acceptance Rate:  59.08 % step_size : 0.0131
# 19900 Samples. Acceptance Rate:  63.99 % step_size : 0.0213
# 20000 Samples. Acceptance Rate:  63.04 % step_size : 0.0237
# 20100 Samples. Acceptance Rate:  63.43 % step_size : 0.0286
# 20200 Samples. Acceptance Rate:  59.67 % step_size : 0.0213
# 20300 Samples. Acceptance Rate:  62.59 % step_size : 0.0242
# 20400 Samples. Acceptance Rate:  60.66 % step_size : 0.0185
# 20500 Samples. Acceptance Rate:  63.60 % step_size : 0.0244
# 20600 Samples. Acceptance Rate:  61.75 % step_size : 0.0246
# 20700 Samples. Acceptance Rate:  60.32 % step_size : 0.0177
# 20800 Samples. Acceptance Rate:  62.30 % step_size : 0.0215
# 20900 Samples. Acceptance Rate:  61.91 % step_size : 0.0224
# 21000 Samples. Acceptance Rate:  62.29 % step_size : 0.0221
# 21100 Samples. Acceptance Rate:  61.74 % step_size : 0.0216
# 21200 Samples. Acceptance Rate:  63.78 % step_size : 0.0267
# 21300 Samples. Acceptance Rate:  57.89 % step_size : 0.0150
# 21400 Samples. Acceptance Rate:  65.12 % step_size : 0.0247
# 21500 Samples. Acceptance Rate:  60.36 % step_size : 0.0164
# 21600 Samples. Acceptance Rate:  61.08 % step_size : 0.0102
# 21700 Samples. Acceptance Rate:  61.49 % step_size : 0.0100
# 21800 Samples. Acceptance Rate:  61.84 % step_size : 0.0084
# 21900 Samples. Acceptance Rate:  62.68 % step_size : 0.0099
# 22000 Samples. Acceptance Rate:  62.41 % step_size : 0.0116
# 22100 Samples. Acceptance Rate:  63.11 % step_size : 0.0159
# 22200 Samples. Acceptance Rate:  62.26 % step_size : 0.0164
# 22300 Samples. Acceptance Rate:  65.91 % step_size : 0.0288
# 22400 Samples. Acceptance Rate:  59.93 % step_size : 0.0208
# 22500 Samples. Acceptance Rate:  62.23 % step_size : 0.0219
# 22600 Samples. Acceptance Rate:  60.88 % step_size : 0.0176
# 22700 Samples. Acceptance Rate:  61.97 % step_size : 0.0190
# 22800 Samples. Acceptance Rate:  63.07 % step_size : 0.0228
# 22900 Samples. Acceptance Rate:  60.77 % step_size : 0.0189
# 23000 Samples. Acceptance Rate:  63.39 % step_size : 0.0229
# 23100 Samples. Acceptance Rate:  62.67 % step_size : 0.0260
# 23200 Samples. Acceptance Rate:  60.96 % step_size : 0.0206
# 23300 Samples. Acceptance Rate:  62.05 % step_size : 0.0196
# 23400 Samples. Acceptance Rate:  62.52 % step_size : 0.0224
# 23500 Samples. Acceptance Rate:  63.24 % step_size : 0.0264
# 23600 Samples. Acceptance Rate:  61.55 % step_size : 0.0223
# 23700 Samples. Acceptance Rate:  62.95 % step_size : 0.0268
# 23800 Samples. Acceptance Rate:  60.69 % step_size : 0.0226
# 23900 Samples. Acceptance Rate:  62.18 % step_size : 0.0231
# 24000 Samples. Acceptance Rate:  63.88 % step_size : 0.0282
# 24100 Samples. Acceptance Rate:  61.01 % step_size : 0.0232
# 24200 Samples. Acceptance Rate:  60.79 % step_size : 0.0198
# 24300 Samples. Acceptance Rate:  63.89 % step_size : 0.0262
# 24400 Samples. Acceptance Rate:  60.72 % step_size : 0.0213
# 24500 Samples. Acceptance Rate:  61.26 % step_size : 0.0209
# 24600 Samples. Acceptance Rate:  61.52 % step_size : 0.0202
# 24700 Samples. Acceptance Rate:  63.09 % step_size : 0.0254
# 24800 Samples. Acceptance Rate:  62.79 % step_size : 0.0269
# 24900 Samples. Acceptance Rate:  62.00 % step_size : 0.0265
# 25000 Samples. Acceptance Rate:  60.05 % step_size : 0.0192
# 25100 Samples. Acceptance Rate:  62.76 % step_size : 0.0225
# 25200 Samples. Acceptance Rate:  64.05 % step_size : 0.0289
# 25300 Samples. Acceptance Rate:  62.12 % step_size : 0.0259
# 25400 Samples. Acceptance Rate:  62.42 % step_size : 0.0259
# 25500 Samples. Acceptance Rate:  62.83 % step_size : 0.0275
# 25600 Samples. Acceptance Rate:  63.37 % step_size : 0.0321
# 25700 Samples. Acceptance Rate:  60.39 % step_size : 0.0292
# 25800 Samples. Acceptance Rate:  62.88 % step_size : 0.0317
# 25900 Samples. Acceptance Rate:  59.50 % step_size : 0.0217
# 26000 Samples. Acceptance Rate:  61.17 % step_size : 0.0172
# 26100 Samples. Acceptance Rate:  60.41 % step_size : 0.0143
# 26200 Samples. Acceptance Rate:  61.61 % step_size : 0.0133
# 26300 Samples. Acceptance Rate:  60.96 % step_size : 0.0094
# 26400 Samples. Acceptance Rate:  63.31 % step_size : 0.0140
# 26500 Samples. Acceptance Rate:  61.23 % step_size : 0.0112
# 26600 Samples. Acceptance Rate:  61.72 % step_size : 0.0106
# 26700 Samples. Acceptance Rate:  63.13 % step_size : 0.0137
# 26800 Samples. Acceptance Rate:  61.33 % step_size : 0.0126
# 26900 Samples. Acceptance Rate:  65.13 % step_size : 0.0228
# 27000 Samples. Acceptance Rate:  62.70 % step_size : 0.0243
# 27100 Samples. Acceptance Rate:  62.02 % step_size : 0.0257
# 27200 Samples. Acceptance Rate:  58.33 % step_size : 0.0131
# 27300 Samples. Acceptance Rate:  62.19 % step_size : 0.0137
# 27400 Samples. Acceptance Rate:  61.94 % step_size : 0.0153
# 27500 Samples. Acceptance Rate:  64.95 % step_size : 0.0252
# 27600 Samples. Acceptance Rate:  61.71 % step_size : 0.0235
# 27700 Samples. Acceptance Rate:  61.26 % step_size : 0.0184
# 27800 Samples. Acceptance Rate:  62.96 % step_size : 0.0225
# 27900 Samples. Acceptance Rate:  60.89 % step_size : 0.0170
# 28000 Samples. Acceptance Rate:  61.83 % step_size : 0.0143
# 28100 Samples. Acceptance Rate:  61.79 % step_size : 0.0146
# 28200 Samples. Acceptance Rate:  60.37 % step_size : 0.0104
# 28300 Samples. Acceptance Rate:  63.62 % step_size : 0.0178
# 28400 Samples. Acceptance Rate:  62.75 % step_size : 0.0226
# 28500 Samples. Acceptance Rate:  62.24 % step_size : 0.0227
# 28600 Samples. Acceptance Rate:  62.59 % step_size : 0.0242
# 28700 Samples. Acceptance Rate:  61.77 % step_size : 0.0222
# 28800 Samples. Acceptance Rate:  60.80 % step_size : 0.0204
# 28900 Samples. Acceptance Rate:  61.80 % step_size : 0.0192
# 29000 Samples. Acceptance Rate:  63.37 % step_size : 0.0235
# 29100 Samples. Acceptance Rate:  60.55 % step_size : 0.0189
# 29200 Samples. Acceptance Rate:  63.43 % step_size : 0.0239
# 29300 Samples. Acceptance Rate:  65.05 % step_size : 0.0342
# 29400 Samples. Acceptance Rate:  59.50 % step_size : 0.0269
# 29500 Samples. Acceptance Rate:  61.79 % step_size : 0.0261
# 29600 Samples. Acceptance Rate:  62.21 % step_size : 0.0280
# 29700 Samples. Acceptance Rate:  60.22 % step_size : 0.0193
# 29800 Samples. Acceptance Rate:  62.83 % step_size : 0.0235
# 29900 Samples. Acceptance Rate:  61.43 % step_size : 0.0207
# 30000 Samples. Acceptance Rate:  62.53 % step_size : 0.0236
# 30100 Samples. Acceptance Rate:  61.85 % step_size : 0.0248
# 30200 Samples. Acceptance Rate:  61.21 % step_size : 0.0249
# 30300 Samples. Acceptance Rate:  63.49 % step_size : 0.0281
# 30400 Samples. Acceptance Rate:  60.19 % step_size : 0.0202
# 30500 Samples. Acceptance Rate:  61.71 % step_size : 0.0198
# 30600 Samples. Acceptance Rate:  61.07 % step_size : 0.0158
# 30700 Samples. Acceptance Rate:  61.94 % step_size : 0.0143
# 30800 Samples. Acceptance Rate:  65.14 % step_size : 0.0249
# 30900 Samples. Acceptance Rate:  61.51 % step_size : 0.0227
# 31000 Samples. Acceptance Rate:  60.39 % step_size : 0.0161
# 31100 Samples. Acceptance Rate:  64.12 % step_size : 0.0233
# 31200 Samples. Acceptance Rate:  62.74 % step_size : 0.0257
# 31300 Samples. Acceptance Rate:  61.71 % step_size : 0.0235
# 31400 Samples. Acceptance Rate:  61.52 % step_size : 0.0211
# 31500 Samples. Acceptance Rate:  61.71 % step_size : 0.0190
# 31600 Samples. Acceptance Rate:  63.22 % step_size : 0.0242
# 31700 Samples. Acceptance Rate:  61.62 % step_size : 0.0225
# 31800 Samples. Acceptance Rate:  59.42 % step_size : 0.0152
# 31900 Samples. Acceptance Rate:  60.65 % step_size : 0.0118
# 32000 Samples. Acceptance Rate:  61.08 % step_size : 0.0093
# 32100 Samples. Acceptance Rate:  63.98 % step_size : 0.0153
# 32200 Samples. Acceptance Rate:  61.59 % step_size : 0.0132
# 32300 Samples. Acceptance Rate:  64.14 % step_size : 0.0231
# 32400 Samples. Acceptance Rate:  63.11 % step_size : 0.0289
# 32500 Samples. Acceptance Rate:  60.36 % step_size : 0.0208
# 32600 Samples. Acceptance Rate:  61.55 % step_size : 0.0190
# 32700 Samples. Acceptance Rate:  63.59 % step_size : 0.0239
# 32800 Samples. Acceptance Rate:  61.68 % step_size : 0.0225
# 32900 Samples. Acceptance Rate:  61.91 % step_size : 0.0226
# 33000 Samples. Acceptance Rate:  59.18 % step_size : 0.0131
# 33100 Samples. Acceptance Rate:  63.47 % step_size : 0.0181
# 33200 Samples. Acceptance Rate:  63.20 % step_size : 0.0221
# 33300 Samples. Acceptance Rate:  60.23 % step_size : 0.0186
# 33400 Samples. Acceptance Rate:  61.82 % step_size : 0.0192
# 33500 Samples. Acceptance Rate:  63.20 % step_size : 0.0222
# 33600 Samples. Acceptance Rate:  62.36 % step_size : 0.0220
# 33700 Samples. Acceptance Rate:  62.60 % step_size : 0.0246
# 33800 Samples. Acceptance Rate:  61.86 % step_size : 0.0243
# 33900 Samples. Acceptance Rate:  61.98 % step_size : 0.0259
# 34000 Samples. Acceptance Rate:  60.40 % step_size : 0.0212
# 34100 Samples. Acceptance Rate:  61.50 % step_size : 0.0180
# 34200 Samples. Acceptance Rate:  63.65 % step_size : 0.0243
# 34300 Samples. Acceptance Rate:  60.53 % step_size : 0.0169
# 34400 Samples. Acceptance Rate:  61.54 % step_size : 0.0165
# 34500 Samples. Acceptance Rate:  63.59 % step_size : 0.0206
# 34600 Samples. Acceptance Rate:  61.58 % step_size : 0.0192
# 34700 Samples. Acceptance Rate:  61.19 % step_size : 0.0160
# 34800 Samples. Acceptance Rate:  63.14 % step_size : 0.0183
# 34900 Samples. Acceptance Rate:  62.50 % step_size : 0.0218
# 35000 Samples. Acceptance Rate:  63.39 % step_size : 0.0243
# 35100 Samples. Acceptance Rate:  62.66 % step_size : 0.0280
# 35200 Samples. Acceptance Rate:  62.62 % step_size : 0.0268
# 35300 Samples. Acceptance Rate:  60.43 % step_size : 0.0213
# 35400 Samples. Acceptance Rate:  64.59 % step_size : 0.0305
# 35500 Samples. Acceptance Rate:  60.56 % step_size : 0.0282
# 35600 Samples. Acceptance Rate:  61.44 % step_size : 0.0248
# 35700 Samples. Acceptance Rate:  62.10 % step_size : 0.0226
# 35800 Samples. Acceptance Rate:  62.94 % step_size : 0.0267
# 35900 Samples. Acceptance Rate:  61.20 % step_size : 0.0244
# 36000 Samples. Acceptance Rate:  60.43 % step_size : 0.0190
# 36100 Samples. Acceptance Rate:  63.53 % step_size : 0.0263
# 36200 Samples. Acceptance Rate:  61.19 % step_size : 0.0236
# 36300 Samples. Acceptance Rate:  62.58 % step_size : 0.0234
# 36400 Samples. Acceptance Rate:  62.80 % step_size : 0.0245
# 36500 Samples. Acceptance Rate:  61.18 % step_size : 0.0207
# 36600 Samples. Acceptance Rate:  63.76 % step_size : 0.0271
# 36700 Samples. Acceptance Rate:  60.08 % step_size : 0.0210
# 36800 Samples. Acceptance Rate:  63.44 % step_size : 0.0273
# 36900 Samples. Acceptance Rate:  59.94 % step_size : 0.0193
# 37000 Samples. Acceptance Rate:  60.90 % step_size : 0.0147
# 37100 Samples. Acceptance Rate:  63.66 % step_size : 0.0225
# 37200 Samples. Acceptance Rate:  61.35 % step_size : 0.0209
# 37300 Samples. Acceptance Rate:  59.93 % step_size : 0.0142
# 37400 Samples. Acceptance Rate:  65.81 % step_size : 0.0289
# 37500 Samples. Acceptance Rate:  61.56 % step_size : 0.0253
# 37600 Samples. Acceptance Rate:  59.54 % step_size : 0.0154
# 37700 Samples. Acceptance Rate:  61.85 % step_size : 0.0135
# 37800 Samples. Acceptance Rate:  63.28 % step_size : 0.0176
# 37900 Samples. Acceptance Rate:  63.87 % step_size : 0.0238
# 38000 Samples. Acceptance Rate:  61.31 % step_size : 0.0224
# 38100 Samples. Acceptance Rate:  60.49 % step_size : 0.0152
# 38200 Samples. Acceptance Rate:  65.01 % step_size : 0.0266
# 38300 Samples. Acceptance Rate:  62.26 % step_size : 0.0287
# 38400 Samples. Acceptance Rate:  60.17 % step_size : 0.0182
# 38500 Samples. Acceptance Rate:  61.29 % step_size : 0.0156
# 38600 Samples. Acceptance Rate:  64.21 % step_size : 0.0268
# 38700 Samples. Acceptance Rate:  61.79 % step_size : 0.0288
# 38800 Samples. Acceptance Rate:  58.52 % step_size : 0.0155
# 38900 Samples. Acceptance Rate:  63.06 % step_size : 0.0198
# 39000 Samples. Acceptance Rate:  61.53 % step_size : 0.0200
# 39100 Samples. Acceptance Rate:  63.46 % step_size : 0.0255
# 39200 Samples. Acceptance Rate:  61.23 % step_size : 0.0258
# 39300 Samples. Acceptance Rate:  61.44 % step_size : 0.0240
# 39400 Samples. Acceptance Rate:  60.84 % step_size : 0.0209
# 39500 Samples. Acceptance Rate:  63.36 % step_size : 0.0243
# 39600 Samples. Acceptance Rate:  61.62 % step_size : 0.0238
# 39700 Samples. Acceptance Rate:  60.80 % step_size : 0.0185
# 39800 Samples. Acceptance Rate:  62.97 % step_size : 0.0215
# 39900 Samples. Acceptance Rate:  61.36 % step_size : 0.0208
# 40000 Samples. Acceptance Rate:  61.96 % step_size : 0.0210
# 40100 Samples. Acceptance Rate:  62.77 % step_size : 0.0219
# 40200 Samples. Acceptance Rate:  62.40 % step_size : 0.0227
# 40300 Samples. Acceptance Rate:  60.70 % step_size : 0.0174
# 40400 Samples. Acceptance Rate:  63.44 % step_size : 0.0214
# 40500 Samples. Acceptance Rate:  63.59 % step_size : 0.0261
# 40600 Samples. Acceptance Rate:  62.28 % step_size : 0.0265
# 40700 Samples. Acceptance Rate:  60.79 % step_size : 0.0216
# 40800 Samples. Acceptance Rate:  62.90 % step_size : 0.0251
# 40900 Samples. Acceptance Rate:  60.57 % step_size : 0.0182
# 41000 Samples. Acceptance Rate:  62.61 % step_size : 0.0221
# 41100 Samples. Acceptance Rate:  63.94 % step_size : 0.0276
# 41200 Samples. Acceptance Rate:  59.29 % step_size : 0.0191
# 41300 Samples. Acceptance Rate:  61.96 % step_size : 0.0193
# 41400 Samples. Acceptance Rate:  63.21 % step_size : 0.0233
# 41500 Samples. Acceptance Rate:  61.68 % step_size : 0.0232
# 41600 Samples. Acceptance Rate:  62.61 % step_size : 0.0246
# 41700 Samples. Acceptance Rate:  62.11 % step_size : 0.0249
# 41800 Samples. Acceptance Rate:  61.78 % step_size : 0.0228
# 41900 Samples. Acceptance Rate:  62.18 % step_size : 0.0213
# 42000 Samples. Acceptance Rate:  62.77 % step_size : 0.0257
# 42100 Samples. Acceptance Rate:  61.97 % step_size : 0.0242
# 42200 Samples. Acceptance Rate:  63.08 % step_size : 0.0296
# 42300 Samples. Acceptance Rate:  60.71 % step_size : 0.0234
# 42400 Samples. Acceptance Rate:  61.97 % step_size : 0.0207
# 42500 Samples. Acceptance Rate:  60.92 % step_size : 0.0172
# 42600 Samples. Acceptance Rate:  61.13 % step_size : 0.0146
# 42700 Samples. Acceptance Rate:  61.62 % step_size : 0.0121
# 42800 Samples. Acceptance Rate:  63.50 % step_size : 0.0212
# 42900 Samples. Acceptance Rate:  63.99 % step_size : 0.0276
# 43000 Samples. Acceptance Rate:  59.75 % step_size : 0.0203
# 43100 Samples. Acceptance Rate:  63.00 % step_size : 0.0214
# 43200 Samples. Acceptance Rate:  63.27 % step_size : 0.0247
# 43300 Samples. Acceptance Rate:  62.45 % step_size : 0.0273
# 43400 Samples. Acceptance Rate:  59.43 % step_size : 0.0168
# 43500 Samples. Acceptance Rate:  62.65 % step_size : 0.0199
# 43600 Samples. Acceptance Rate:  61.17 % step_size : 0.0185
# 43700 Samples. Acceptance Rate:  61.43 % step_size : 0.0141
# 43800 Samples. Acceptance Rate:  65.06 % step_size : 0.0254
# 43900 Samples. Acceptance Rate:  61.63 % step_size : 0.0232
# 44000 Samples. Acceptance Rate:  62.12 % step_size : 0.0248
# 44100 Samples. Acceptance Rate:  62.95 % step_size : 0.0281
# 44200 Samples. Acceptance Rate:  61.37 % step_size : 0.0271
# 44300 Samples. Acceptance Rate:  59.97 % step_size : 0.0180
# 44400 Samples. Acceptance Rate:  63.20 % step_size : 0.0237
# 44500 Samples. Acceptance Rate:  63.24 % step_size : 0.0271
# 44600 Samples. Acceptance Rate:  61.77 % step_size : 0.0275
# 44700 Samples. Acceptance Rate:  59.91 % step_size : 0.0193
# 44800 Samples. Acceptance Rate:  62.66 % step_size : 0.0245
# 44900 Samples. Acceptance Rate:  62.94 % step_size : 0.0271
# 45000 Samples. Acceptance Rate:  61.40 % step_size : 0.0242
# 45100 Samples. Acceptance Rate:  61.37 % step_size : 0.0215
# 45200 Samples. Acceptance Rate:  61.66 % step_size : 0.0188
# 45300 Samples. Acceptance Rate:  63.59 % step_size : 0.0256
# 45400 Samples. Acceptance Rate:  59.47 % step_size : 0.0164
# 45500 Samples. Acceptance Rate:  62.70 % step_size : 0.0209
# 45600 Samples. Acceptance Rate:  60.79 % step_size : 0.0148
# 45700 Samples. Acceptance Rate:  60.02 % step_size : 0.0086
# 45800 Samples. Acceptance Rate:  64.20 % step_size : 0.0172
# 45900 Samples. Acceptance Rate:  62.67 % step_size : 0.0209
# 46000 Samples. Acceptance Rate:  61.80 % step_size : 0.0201
# 46100 Samples. Acceptance Rate:  61.57 % step_size : 0.0173
# 46200 Samples. Acceptance Rate:  63.20 % step_size : 0.0211
# 46300 Samples. Acceptance Rate:  61.83 % step_size : 0.0201
# 46400 Samples. Acceptance Rate:  62.75 % step_size : 0.0231
# 46500 Samples. Acceptance Rate:  59.66 % step_size : 0.0137
# 46600 Samples. Acceptance Rate:  61.89 % step_size : 0.0140
# 46700 Samples. Acceptance Rate:  62.34 % step_size : 0.0153
# 46800 Samples. Acceptance Rate:  62.50 % step_size : 0.0183
# 46900 Samples. Acceptance Rate:  62.54 % step_size : 0.0186
# 47000 Samples. Acceptance Rate:  63.97 % step_size : 0.0273
# 47100 Samples. Acceptance Rate:  61.72 % step_size : 0.0240
# 47200 Samples. Acceptance Rate:  62.07 % step_size : 0.0253
# 47300 Samples. Acceptance Rate:  63.06 % step_size : 0.0271
# 47400 Samples. Acceptance Rate:  59.55 % step_size : 0.0183
# 47500 Samples. Acceptance Rate:  62.22 % step_size : 0.0199
# 47600 Samples. Acceptance Rate:  62.15 % step_size : 0.0214
# 47700 Samples. Acceptance Rate:  62.21 % step_size : 0.0218
# 47800 Samples. Acceptance Rate:  66.32 % step_size : 0.0385
# 47900 Samples. Acceptance Rate:  55.04 % step_size : 0.0122
# 48000 Samples. Acceptance Rate:  63.07 % step_size : 0.0154
# 48100 Samples. Acceptance Rate:  64.25 % step_size : 0.0242
# 48200 Samples. Acceptance Rate:  62.09 % step_size : 0.0259
# 48300 Samples. Acceptance Rate:  61.55 % step_size : 0.0244
# 48400 Samples. Acceptance Rate:  63.93 % step_size : 0.0325
# 48500 Samples. Acceptance Rate:  59.13 % step_size : 0.0216
# 48600 Samples. Acceptance Rate:  60.76 % step_size : 0.0181
# 48700 Samples. Acceptance Rate:  64.35 % step_size : 0.0281
# 48800 Samples. Acceptance Rate:  59.47 % step_size : 0.0195
# 48900 Samples. Acceptance Rate:  64.04 % step_size : 0.0261
# 49000 Samples. Acceptance Rate:  61.74 % step_size : 0.0254
# 49100 Samples. Acceptance Rate:  60.69 % step_size : 0.0199
# 49200 Samples. Acceptance Rate:  61.41 % step_size : 0.0177
# 49300 Samples. Acceptance Rate:  61.67 % step_size : 0.0178
# 49400 Samples. Acceptance Rate:  61.96 % step_size : 0.0198
# 49500 Samples. Acceptance Rate:  61.15 % step_size : 0.0186
# 49600 Samples. Acceptance Rate:  62.72 % step_size : 0.0228
# 49700 Samples. Acceptance Rate:  60.58 % step_size : 0.0156
# 49800 Samples. Acceptance Rate:  63.41 % step_size : 0.0181
# 49900 Samples. Acceptance Rate:  62.57 % step_size : 0.0214
# 50000 Samples. Acceptance Rate:  63.10 % step_size : 0.0225
# 50100 Samples. Acceptance Rate:  61.83 % step_size : 0.0239
# 50200 Samples. Acceptance Rate:  62.58 % step_size : 0.0240
# 50300 Samples. Acceptance Rate:  60.14 % step_size : 0.0178
# 50400 Samples. Acceptance Rate:  64.23 % step_size : 0.0246
# 50500 Samples. Acceptance Rate:  62.22 % step_size : 0.0249
# 50600 Samples. Acceptance Rate:  61.65 % step_size : 0.0258
# 50700 Samples. Acceptance Rate:  61.42 % step_size : 0.0219
# 50800 Samples. Acceptance Rate:  61.05 % step_size : 0.0180
# 50900 Samples. Acceptance Rate:  62.75 % step_size : 0.0209
# 51000 Samples. Acceptance Rate:  61.95 % step_size : 0.0213
# 51100 Samples. Acceptance Rate:  61.50 % step_size : 0.0193
# 51200 Samples. Acceptance Rate:  62.70 % step_size : 0.0228
# 51300 Samples. Acceptance Rate:  61.26 % step_size : 0.0227
# 51400 Samples. Acceptance Rate:  62.37 % step_size : 0.0213
# 51500 Samples. Acceptance Rate:  63.41 % step_size : 0.0281
# 51600 Samples. Acceptance Rate:  61.32 % step_size : 0.0267
# 51700 Samples. Acceptance Rate:  61.80 % step_size : 0.0252
# 51800 Samples. Acceptance Rate:  63.54 % step_size : 0.0268
# 51900 Samples. Acceptance Rate:  60.58 % step_size : 0.0210
# 52000 Samples. Acceptance Rate:  61.13 % step_size : 0.0205
# 52100 Samples. Acceptance Rate:  60.74 % step_size : 0.0173
# 52200 Samples. Acceptance Rate:  64.85 % step_size : 0.0310
# 52300 Samples. Acceptance Rate:  63.50 % step_size : 0.0376
# 52400 Samples. Acceptance Rate:  60.23 % step_size : 0.0347
# 52500 Samples. Acceptance Rate:  60.07 % step_size : 0.0258
# 52600 Samples. Acceptance Rate:  63.80 % step_size : 0.0328
# 52700 Samples. Acceptance Rate:  62.29 % step_size : 0.0321
# 52800 Samples. Acceptance Rate:  62.09 % step_size : 0.0333
# 52900 Samples. Acceptance Rate:  62.68 % step_size : 0.0410
# 53000 Samples. Acceptance Rate:  58.75 % step_size : 0.0281
# 53100 Samples. Acceptance Rate:  62.55 % step_size : 0.0304
# 53200 Samples. Acceptance Rate:  60.54 % step_size : 0.0249
# 53300 Samples. Acceptance Rate:  65.96 % step_size : 0.0419
# 53400 Samples. Acceptance Rate:  58.34 % step_size : 0.0292
# 53500 Samples. Acceptance Rate:  61.15 % step_size : 0.0275
# 53600 Samples. Acceptance Rate:  62.82 % step_size : 0.0318
# 53700 Samples. Acceptance Rate:  61.06 % step_size : 0.0300
# 53800 Samples. Acceptance Rate:  62.01 % step_size : 0.0302
# 53900 Samples. Acceptance Rate:  61.91 % step_size : 0.0341
# 54000 Samples. Acceptance Rate:  64.17 % step_size : 0.0422
# 54100 Samples. Acceptance Rate:  59.77 % step_size : 0.0359
# 54200 Samples. Acceptance Rate:  62.26 % step_size : 0.0406
# 54300 Samples. Acceptance Rate:  60.05 % step_size : 0.0343
# 54400 Samples. Acceptance Rate:  61.06 % step_size : 0.0350
# 54500 Samples. Acceptance Rate:  62.31 % step_size : 0.0363
# 54600 Samples. Acceptance Rate:  61.20 % step_size : 0.0350
# 54700 Samples. Acceptance Rate:  59.89 % step_size : 0.0272
# 54800 Samples. Acceptance Rate:  58.91 % step_size : 0.0186
# 54900 Samples. Acceptance Rate:  67.40 % step_size : 0.0398
# 55000 Samples. Acceptance Rate:  57.58 % step_size : 0.0238
# 55100 Samples. Acceptance Rate:  62.29 % step_size : 0.0260
# 55200 Samples. Acceptance Rate:  57.67 % step_size : 0.0116
# 55300 Samples. Acceptance Rate:  62.12 % step_size : 0.0128
# 55400 Samples. Acceptance Rate:  63.64 % step_size : 0.0197
# 55500 Samples. Acceptance Rate:  61.60 % step_size : 0.0190
# 55600 Samples. Acceptance Rate:  62.07 % step_size : 0.0225
# 55700 Samples. Acceptance Rate:  61.42 % step_size : 0.0209
# 55800 Samples. Acceptance Rate:  61.54 % step_size : 0.0226
# 55900 Samples. Acceptance Rate:  62.29 % step_size : 0.0234
# 56000 Samples. Acceptance Rate:  62.93 % step_size : 0.0283
# 56100 Samples. Acceptance Rate:  61.10 % step_size : 0.0229
# 56200 Samples. Acceptance Rate:  61.34 % step_size : 0.0210
# 56300 Samples. Acceptance Rate:  63.88 % step_size : 0.0281
# 56400 Samples. Acceptance Rate:  62.67 % step_size : 0.0339
# 56500 Samples. Acceptance Rate:  59.44 % step_size : 0.0234
# 56600 Samples. Acceptance Rate:  59.54 % step_size : 0.0144
# 56700 Samples. Acceptance Rate:  65.10 % step_size : 0.0250
# 56800 Samples. Acceptance Rate:  62.47 % step_size : 0.0268
# 56900 Samples. Acceptance Rate:  64.21 % step_size : 0.0333
# 57000 Samples. Acceptance Rate:  59.53 % step_size : 0.0225
# 57100 Samples. Acceptance Rate:  61.56 % step_size : 0.0221
# 57200 Samples. Acceptance Rate:  61.74 % step_size : 0.0215
# 57300 Samples. Acceptance Rate:  62.14 % step_size : 0.0225
# 57400 Samples. Acceptance Rate:  61.56 % step_size : 0.0220
# 57500 Samples. Acceptance Rate:  62.58 % step_size : 0.0252
# 57600 Samples. Acceptance Rate:  60.21 % step_size : 0.0166
# 57700 Samples. Acceptance Rate:  62.69 % step_size : 0.0211
# 57800 Samples. Acceptance Rate:  63.71 % step_size : 0.0262
# 57900 Samples. Acceptance Rate:  61.66 % step_size : 0.0257
# 58000 Samples. Acceptance Rate:  59.63 % step_size : 0.0134
# 58100 Samples. Acceptance Rate:  62.87 % step_size : 0.0184
# 58200 Samples. Acceptance Rate:  62.44 % step_size : 0.0216
# 58300 Samples. Acceptance Rate:  59.41 % step_size : 0.0113
# 58400 Samples. Acceptance Rate:  64.88 % step_size : 0.0221
# 58500 Samples. Acceptance Rate:  62.79 % step_size : 0.0242
# 58600 Samples. Acceptance Rate:  63.36 % step_size : 0.0291
# 58700 Samples. Acceptance Rate:  59.79 % step_size : 0.0214
# 58800 Samples. Acceptance Rate:  60.79 % step_size : 0.0165
# 58900 Samples. Acceptance Rate:  60.20 % step_size : 0.0121
# 59000 Samples. Acceptance Rate:  64.86 % step_size : 0.0252
# 59100 Samples. Acceptance Rate:  59.18 % step_size : 0.0164
# 59200 Samples. Acceptance Rate:  63.10 % step_size : 0.0184
# 59300 Samples. Acceptance Rate:  63.96 % step_size : 0.0270
# 59400 Samples. Acceptance Rate:  62.10 % step_size : 0.0286
# 59500 Samples. Acceptance Rate:  63.21 % step_size : 0.0361
# 59600 Samples. Acceptance Rate:  63.74 % step_size : 0.0422
# 59700 Samples. Acceptance Rate:  58.70 % step_size : 0.0330
# 59800 Samples. Acceptance Rate:  60.33 % step_size : 0.0292
# 59900 Samples. Acceptance Rate:  63.54 % step_size : 0.0345
# 60000 Samples. Acceptance Rate:  61.70 % step_size : 0.0344
# 60100 Samples. Acceptance Rate:  61.70 % step_size : 0.0342
# 60200 Samples. Acceptance Rate:  61.61 % step_size : 0.0362
# 60300 Samples. Acceptance Rate:  59.54 % step_size : 0.0281
# 60400 Samples. Acceptance Rate:  60.77 % step_size : 0.0230
# 60500 Samples. Acceptance Rate:  61.05 % step_size : 0.0185
# 60600 Samples. Acceptance Rate:  64.53 % step_size : 0.0270
# 60700 Samples. Acceptance Rate:  61.61 % step_size : 0.0231
# 60800 Samples. Acceptance Rate:  61.76 % step_size : 0.0228
# 60900 Samples. Acceptance Rate:  62.25 % step_size : 0.0248
# 61000 Samples. Acceptance Rate:  61.06 % step_size : 0.0233
# 61100 Samples. Acceptance Rate:  60.94 % step_size : 0.0185
# 61200 Samples. Acceptance Rate:  62.01 % step_size : 0.0199
# 61300 Samples. Acceptance Rate:  61.98 % step_size : 0.0188
# 61400 Samples. Acceptance Rate:  62.59 % step_size : 0.0190
# 61500 Samples. Acceptance Rate:  62.87 % step_size : 0.0225
# 61600 Samples. Acceptance Rate:  62.85 % step_size : 0.0246
# 61700 Samples. Acceptance Rate:  63.45 % step_size : 0.0326
# 61800 Samples. Acceptance Rate:  59.17 % step_size : 0.0230
# 61900 Samples. Acceptance Rate:  60.79 % step_size : 0.0171
# 62000 Samples. Acceptance Rate:  61.77 % step_size : 0.0187
# 62100 Samples. Acceptance Rate:  62.97 % step_size : 0.0236
# 62200 Samples. Acceptance Rate:  61.32 % step_size : 0.0225
# 62300 Samples. Acceptance Rate:  62.75 % step_size : 0.0245
# 62400 Samples. Acceptance Rate:  62.10 % step_size : 0.0236
# 62500 Samples. Acceptance Rate:  62.54 % step_size : 0.0230
# 62600 Samples. Acceptance Rate:  60.96 % step_size : 0.0214
# 62700 Samples. Acceptance Rate:  60.07 % step_size : 0.0151
# 62800 Samples. Acceptance Rate:  60.22 % step_size : 0.0119
# 62900 Samples. Acceptance Rate:  61.43 % step_size : 0.0100
# 63000 Samples. Acceptance Rate:  62.29 % step_size : 0.0112
# 63100 Samples. Acceptance Rate:  62.26 % step_size : 0.0129
# 63200 Samples. Acceptance Rate:  61.85 % step_size : 0.0123
# 63300 Samples. Acceptance Rate:  62.46 % step_size : 0.0111
# 63400 Samples. Acceptance Rate:  61.32 % step_size : 0.0091
# 63500 Samples. Acceptance Rate:  61.88 % step_size : 0.0080
# 63600 Samples. Acceptance Rate:  62.59 % step_size : 0.0100
# 63700 Samples. Acceptance Rate:  62.83 % step_size : 0.0123
# 63800 Samples. Acceptance Rate:  61.83 % step_size : 0.0096
# 63900 Samples. Acceptance Rate:  62.59 % step_size : 0.0094
# 64000 Samples. Acceptance Rate:  62.37 % step_size : 0.0104
# 64100 Samples. Acceptance Rate:  62.02 % step_size : 0.0116
# 64200 Samples. Acceptance Rate:  61.85 % step_size : 0.0097
# 64300 Samples. Acceptance Rate:  61.68 % step_size : 0.0086
# 64400 Samples. Acceptance Rate:  62.25 % step_size : 0.0087
# 64500 Samples. Acceptance Rate:  61.65 % step_size : 0.0094
# 64600 Samples. Acceptance Rate:  61.54 % step_size : 0.0108
# 64700 Samples. Acceptance Rate:  62.60 % step_size : 0.0109
# 64800 Samples. Acceptance Rate:  61.64 % step_size : 0.0111
# 64900 Samples. Acceptance Rate:  61.23 % step_size : 0.0105
# 65000 Samples. Acceptance Rate:  61.64 % step_size : 0.0082
# 65100 Samples. Acceptance Rate:  62.25 % step_size : 0.0123
# 65200 Samples. Acceptance Rate:  62.08 % step_size : 0.0125
# 65300 Samples. Acceptance Rate:  62.41 % step_size : 0.0129
# 65400 Samples. Acceptance Rate:  61.82 % step_size : 0.0127
# 65500 Samples. Acceptance Rate:  63.79 % step_size : 0.0198
# 65600 Samples. Acceptance Rate:  62.67 % step_size : 0.0219
# 65700 Samples. Acceptance Rate:  61.83 % step_size : 0.0195
# 65800 Samples. Acceptance Rate:  63.67 % step_size : 0.0257
# 65900 Samples. Acceptance Rate:  60.80 % step_size : 0.0216
# 66000 Samples. Acceptance Rate:  63.88 % step_size : 0.0287
# 66100 Samples. Acceptance Rate:  60.88 % step_size : 0.0231
# 66200 Samples. Acceptance Rate:  63.79 % step_size : 0.0313
# 66300 Samples. Acceptance Rate:  59.96 % step_size : 0.0222
# 66400 Samples. Acceptance Rate:  60.68 % step_size : 0.0156
# 66500 Samples. Acceptance Rate:  61.17 % step_size : 0.0147
# 66600 Samples. Acceptance Rate:  59.78 % step_size : 0.0116
# 66700 Samples. Acceptance Rate:  62.64 % step_size : 0.0121
# 66800 Samples. Acceptance Rate:  63.44 % step_size : 0.0194
# 66900 Samples. Acceptance Rate:  60.36 % step_size : 0.0135
# 67000 Samples. Acceptance Rate:  65.08 % step_size : 0.0259
# 67100 Samples. Acceptance Rate:  62.21 % step_size : 0.0264
# 67200 Samples. Acceptance Rate:  62.09 % step_size : 0.0228
# 67300 Samples. Acceptance Rate:  62.83 % step_size : 0.0244
# 67400 Samples. Acceptance Rate:  59.24 % step_size : 0.0147
# 67500 Samples. Acceptance Rate:  61.67 % step_size : 0.0134
# 67600 Samples. Acceptance Rate:  63.36 % step_size : 0.0220
# 67700 Samples. Acceptance Rate:  60.58 % step_size : 0.0166
# 67800 Samples. Acceptance Rate:  65.80 % step_size : 0.0282
# 67900 Samples. Acceptance Rate:  59.49 % step_size : 0.0176
# 68000 Samples. Acceptance Rate:  63.26 % step_size : 0.0226
# 68100 Samples. Acceptance Rate:  62.51 % step_size : 0.0245
# 68200 Samples. Acceptance Rate:  63.09 % step_size : 0.0284
# 68300 Samples. Acceptance Rate:  59.31 % step_size : 0.0176
# 68400 Samples. Acceptance Rate:  64.13 % step_size : 0.0258
# 68500 Samples. Acceptance Rate:  61.89 % step_size : 0.0244
# 68600 Samples. Acceptance Rate:  61.58 % step_size : 0.0227
# 68700 Samples. Acceptance Rate:  63.28 % step_size : 0.0270
# 68800 Samples. Acceptance Rate:  59.63 % step_size : 0.0195
# 68900 Samples. Acceptance Rate:  63.83 % step_size : 0.0256
# 69000 Samples. Acceptance Rate:  63.18 % step_size : 0.0283
# 69100 Samples. Acceptance Rate:  60.33 % step_size : 0.0215
# 69200 Samples. Acceptance Rate:  61.32 % step_size : 0.0208
# 69300 Samples. Acceptance Rate:  61.60 % step_size : 0.0179
# 69400 Samples. Acceptance Rate:  62.33 % step_size : 0.0180
# 69500 Samples. Acceptance Rate:  60.35 % step_size : 0.0119
# 69600 Samples. Acceptance Rate:  63.78 % step_size : 0.0206
# 69700 Samples. Acceptance Rate:  62.00 % step_size : 0.0208
# 69800 Samples. Acceptance Rate:  63.06 % step_size : 0.0234
# 69900 Samples. Acceptance Rate:  60.93 % step_size : 0.0173
# 70000 Samples. Acceptance Rate:  64.55 % step_size : 0.0268
# 70100 Samples. Acceptance Rate:  61.30 % step_size : 0.0241
# 70200 Samples. Acceptance Rate:  62.12 % step_size : 0.0228
# 70300 Samples. Acceptance Rate:  62.81 % step_size : 0.0258
# 70400 Samples. Acceptance Rate:  60.78 % step_size : 0.0216
# 70500 Samples. Acceptance Rate:  61.47 % step_size : 0.0189
# 70600 Samples. Acceptance Rate:  62.85 % step_size : 0.0248
# 70700 Samples. Acceptance Rate:  62.19 % step_size : 0.0247
# 70800 Samples. Acceptance Rate:  61.45 % step_size : 0.0244
# 70900 Samples. Acceptance Rate:  61.88 % step_size : 0.0229
# 71000 Samples. Acceptance Rate:  60.53 % step_size : 0.0156
# 71100 Samples. Acceptance Rate:  64.27 % step_size : 0.0238
# 71200 Samples. Acceptance Rate:  61.32 % step_size : 0.0196
# 71300 Samples. Acceptance Rate:  61.03 % step_size : 0.0175
# 71400 Samples. Acceptance Rate:  63.59 % step_size : 0.0238
# 71500 Samples. Acceptance Rate:  62.47 % step_size : 0.0289
# 71600 Samples. Acceptance Rate:  60.37 % step_size : 0.0207
# 71700 Samples. Acceptance Rate:  63.74 % step_size : 0.0278
# 71800 Samples. Acceptance Rate:  61.27 % step_size : 0.0269
# 71900 Samples. Acceptance Rate:  60.44 % step_size : 0.0187
# 72000 Samples. Acceptance Rate:  63.57 % step_size : 0.0226
# 72100 Samples. Acceptance Rate:  61.86 % step_size : 0.0237
# 72200 Samples. Acceptance Rate:  62.42 % step_size : 0.0252
# 72300 Samples. Acceptance Rate:  61.42 % step_size : 0.0269
# 72400 Samples. Acceptance Rate:  60.87 % step_size : 0.0210
# 72500 Samples. Acceptance Rate:  62.68 % step_size : 0.0209
# 72600 Samples. Acceptance Rate:  61.99 % step_size : 0.0185
# 72700 Samples. Acceptance Rate:  63.24 % step_size : 0.0255
# 72800 Samples. Acceptance Rate:  59.05 % step_size : 0.0157
# 72900 Samples. Acceptance Rate:  61.05 % step_size : 0.0154
# 73000 Samples. Acceptance Rate:  62.22 % step_size : 0.0157
# 73100 Samples. Acceptance Rate:  64.90 % step_size : 0.0250
# 73200 Samples. Acceptance Rate:  62.67 % step_size : 0.0258
# 73300 Samples. Acceptance Rate:  59.60 % step_size : 0.0173
# 73400 Samples. Acceptance Rate:  62.99 % step_size : 0.0219
# 73500 Samples. Acceptance Rate:  62.15 % step_size : 0.0210
# 73600 Samples. Acceptance Rate:  61.20 % step_size : 0.0179
# 73700 Samples. Acceptance Rate:  61.00 % step_size : 0.0139
# 73800 Samples. Acceptance Rate:  61.91 % step_size : 0.0133
# 73900 Samples. Acceptance Rate:  62.30 % step_size : 0.0134
# 74000 Samples. Acceptance Rate:  62.69 % step_size : 0.0190
# 74100 Samples. Acceptance Rate:  61.01 % step_size : 0.0153
# 74200 Samples. Acceptance Rate:  64.25 % step_size : 0.0246
# 74300 Samples. Acceptance Rate:  61.27 % step_size : 0.0227
# 74400 Samples. Acceptance Rate:  60.20 % step_size : 0.0191
# 74500 Samples. Acceptance Rate:  62.80 % step_size : 0.0238
# 74600 Samples. Acceptance Rate:  60.15 % step_size : 0.0159
# 74700 Samples. Acceptance Rate:  62.29 % step_size : 0.0182
# 74800 Samples. Acceptance Rate:  61.87 % step_size : 0.0196
# 74900 Samples. Acceptance Rate:  62.15 % step_size : 0.0210
# 75000 Samples. Acceptance Rate:  63.24 % step_size : 0.0262
# 75100 Samples. Acceptance Rate:  61.94 % step_size : 0.0277
# 75200 Samples. Acceptance Rate:  61.68 % step_size : 0.0253
# 75300 Samples. Acceptance Rate:  60.61 % step_size : 0.0205
# 75400 Samples. Acceptance Rate:  61.08 % step_size : 0.0186
# 75500 Samples. Acceptance Rate:  63.15 % step_size : 0.0227
# 75600 Samples. Acceptance Rate:  61.44 % step_size : 0.0206
# 75700 Samples. Acceptance Rate:  60.82 % step_size : 0.0167
# 75800 Samples. Acceptance Rate:  63.61 % step_size : 0.0232
# 75900 Samples. Acceptance Rate:  60.07 % step_size : 0.0160
# 76000 Samples. Acceptance Rate:  65.53 % step_size : 0.0304
# 76100 Samples. Acceptance Rate:  60.85 % step_size : 0.0247
# 76200 Samples. Acceptance Rate:  62.90 % step_size : 0.0274
# 76300 Samples. Acceptance Rate:  60.64 % step_size : 0.0182
# 76400 Samples. Acceptance Rate:  63.80 % step_size : 0.0226
# 76500 Samples. Acceptance Rate:  61.07 % step_size : 0.0172
# 76600 Samples. Acceptance Rate:  63.45 % step_size : 0.0227
# 76700 Samples. Acceptance Rate:  60.74 % step_size : 0.0194
# 76800 Samples. Acceptance Rate:  62.36 % step_size : 0.0213
# 76900 Samples. Acceptance Rate:  62.56 % step_size : 0.0233
# 77000 Samples. Acceptance Rate:  63.41 % step_size : 0.0282
# 77100 Samples. Acceptance Rate:  60.76 % step_size : 0.0230
# 77200 Samples. Acceptance Rate:  60.73 % step_size : 0.0170
# 77300 Samples. Acceptance Rate:  62.68 % step_size : 0.0186
# 77400 Samples. Acceptance Rate:  63.90 % step_size : 0.0234
# 77500 Samples. Acceptance Rate:  61.90 % step_size : 0.0214
# 77600 Samples. Acceptance Rate:  62.94 % step_size : 0.0230
# 77700 Samples. Acceptance Rate:  61.42 % step_size : 0.0235
# 77800 Samples. Acceptance Rate:  60.27 % step_size : 0.0158
# 77900 Samples. Acceptance Rate:  64.33 % step_size : 0.0245
# 78000 Samples. Acceptance Rate:  61.13 % step_size : 0.0213
# 78100 Samples. Acceptance Rate:  63.83 % step_size : 0.0280
# 78200 Samples. Acceptance Rate:  62.00 % step_size : 0.0263
# 78300 Samples. Acceptance Rate:  61.05 % step_size : 0.0232
# 78400 Samples. Acceptance Rate:  61.84 % step_size : 0.0242
# 78500 Samples. Acceptance Rate:  60.98 % step_size : 0.0189
# 78600 Samples. Acceptance Rate:  62.61 % step_size : 0.0200
# 78700 Samples. Acceptance Rate:  63.51 % step_size : 0.0263
# 78800 Samples. Acceptance Rate:  61.50 % step_size : 0.0232
# 78900 Samples. Acceptance Rate:  61.94 % step_size : 0.0242
# 79000 Samples. Acceptance Rate:  62.80 % step_size : 0.0277
# 79100 Samples. Acceptance Rate:  59.89 % step_size : 0.0216
# 79200 Samples. Acceptance Rate:  61.32 % step_size : 0.0192
# 79300 Samples. Acceptance Rate:  63.28 % step_size : 0.0268
# 79400 Samples. Acceptance Rate:  60.30 % step_size : 0.0173
# 79500 Samples. Acceptance Rate:  61.79 % step_size : 0.0168
# 79600 Samples. Acceptance Rate:  65.09 % step_size : 0.0241
# 79700 Samples. Acceptance Rate:  61.39 % step_size : 0.0191
# 79800 Samples. Acceptance Rate:  63.02 % step_size : 0.0234
# 79900 Samples. Acceptance Rate:  63.48 % step_size : 0.0264
# 80000 Samples. Acceptance Rate:  61.66 % step_size : 0.0227
# 80100 Samples. Acceptance Rate:  60.78 % step_size : 0.0188
# ...
# 473900 Samples. Acceptance Rate:  63.58 % step_size : 0.0227
# 474000 Samples. Acceptance Rate:  62.14 % step_size : 0.0221
# 474100 Samples. Acceptance Rate:  62.00 % step_size : 0.0213
# 474200 Samples. Acceptance Rate:  63.62 % step_size : 0.0286
# 474300 Samples. Acceptance Rate:  59.93 % step_size : 0.0209
# 474400 Samples. Acceptance Rate:  63.76 % step_size : 0.0279
# 474500 Samples. Acceptance Rate:  61.05 % step_size : 0.0230
# 474600 Samples. Acceptance Rate:  62.10 % step_size : 0.0219
# 474700 Samples. Acceptance Rate:  64.23 % step_size : 0.0278
# 474800 Samples. Acceptance Rate:  60.35 % step_size : 0.0219
# 474900 Samples. Acceptance Rate:  65.75 % step_size : 0.0347
# 475000 Samples. Acceptance Rate:  60.32 % step_size : 0.0274
# 475100 Samples. Acceptance Rate:  60.63 % step_size : 0.0214
# 475200 Samples. Acceptance Rate:  61.10 % step_size : 0.0171
# 475300 Samples. Acceptance Rate:  62.82 % step_size : 0.0180
# 475400 Samples. Acceptance Rate:  64.81 % step_size : 0.0294
# 475500 Samples. Acceptance Rate:  62.09 % step_size : 0.0306
# 475600 Samples. Acceptance Rate:  61.83 % step_size : 0.0293
# 475700 Samples. Acceptance Rate:  61.31 % step_size : 0.0265
# 475800 Samples. Acceptance Rate:  62.29 % step_size : 0.0270
# 475900 Samples. Acceptance Rate:  58.51 % step_size : 0.0125
# 476000 Samples. Acceptance Rate:  62.36 % step_size : 0.0127
# 476100 Samples. Acceptance Rate:  64.59 % step_size : 0.0215
# 476200 Samples. Acceptance Rate:  63.08 % step_size : 0.0240
# 476300 Samples. Acceptance Rate:  63.09 % step_size : 0.0278
# 476400 Samples. Acceptance Rate:  63.90 % step_size : 0.0339
# 476500 Samples. Acceptance Rate:  57.29 % step_size : 0.0165
# 476600 Samples. Acceptance Rate:  64.46 % step_size : 0.0266
# 476700 Samples. Acceptance Rate:  62.70 % step_size : 0.0269
# 476800 Samples. Acceptance Rate:  61.36 % step_size : 0.0256
# 476900 Samples. Acceptance Rate:  60.59 % step_size : 0.0195
# 477000 Samples. Acceptance Rate:  63.07 % step_size : 0.0217
# 477100 Samples. Acceptance Rate:  62.82 % step_size : 0.0264
# 477200 Samples. Acceptance Rate:  61.85 % step_size : 0.0234
# 477300 Samples. Acceptance Rate:  60.83 % step_size : 0.0198
# 477400 Samples. Acceptance Rate:  61.15 % step_size : 0.0177
# 477500 Samples. Acceptance Rate:  63.32 % step_size : 0.0218
# 477600 Samples. Acceptance Rate:  60.33 % step_size : 0.0183
# 477700 Samples. Acceptance Rate:  61.61 % step_size : 0.0134
# 477800 Samples. Acceptance Rate:  62.23 % step_size : 0.0145
# 477900 Samples. Acceptance Rate:  61.62 % step_size : 0.0140
# 478000 Samples. Acceptance Rate:  63.69 % step_size : 0.0208
# 478100 Samples. Acceptance Rate:  60.95 % step_size : 0.0157
# 478200 Samples. Acceptance Rate:  62.63 % step_size : 0.0181
# 478300 Samples. Acceptance Rate:  63.24 % step_size : 0.0219
# 478400 Samples. Acceptance Rate:  60.58 % step_size : 0.0159
# 478500 Samples. Acceptance Rate:  61.18 % step_size : 0.0139
# 478600 Samples. Acceptance Rate:  61.60 % step_size : 0.0112
# 478700 Samples. Acceptance Rate:  62.95 % step_size : 0.0159
# 478800 Samples. Acceptance Rate:  62.68 % step_size : 0.0176
# 478900 Samples. Acceptance Rate:  62.11 % step_size : 0.0184
# 479000 Samples. Acceptance Rate:  60.47 % step_size : 0.0131
# 479100 Samples. Acceptance Rate:  65.25 % step_size : 0.0240
# 479200 Samples. Acceptance Rate:  61.78 % step_size : 0.0222
# 479300 Samples. Acceptance Rate:  61.93 % step_size : 0.0226
# 479400 Samples. Acceptance Rate:  62.68 % step_size : 0.0242
# 479500 Samples. Acceptance Rate:  62.34 % step_size : 0.0273
# 479600 Samples. Acceptance Rate:  60.44 % step_size : 0.0214
# 479700 Samples. Acceptance Rate:  60.55 % step_size : 0.0176
# 479800 Samples. Acceptance Rate:  64.36 % step_size : 0.0253
# 479900 Samples. Acceptance Rate:  62.15 % step_size : 0.0242
# 480000 Samples. Acceptance Rate:  61.80 % step_size : 0.0226
# 480100 Samples. Acceptance Rate:  62.63 % step_size : 0.0238
# 480200 Samples. Acceptance Rate:  63.48 % step_size : 0.0314
# 480300 Samples. Acceptance Rate:  59.88 % step_size : 0.0256
# 480400 Samples. Acceptance Rate:  61.88 % step_size : 0.0267
# 480500 Samples. Acceptance Rate:  65.04 % step_size : 0.0382
# 480600 Samples. Acceptance Rate:  57.52 % step_size : 0.0241
# 480700 Samples. Acceptance Rate:  63.02 % step_size : 0.0292
# 480800 Samples. Acceptance Rate:  64.11 % step_size : 0.0368
# 480900 Samples. Acceptance Rate:  59.49 % step_size : 0.0263
# 481000 Samples. Acceptance Rate:  58.48 % step_size : 0.0130
# 481100 Samples. Acceptance Rate:  65.32 % step_size : 0.0239
# 481200 Samples. Acceptance Rate:  62.56 % step_size : 0.0269
# 481300 Samples. Acceptance Rate:  62.17 % step_size : 0.0275
# 481400 Samples. Acceptance Rate:  60.37 % step_size : 0.0213
# 481500 Samples. Acceptance Rate:  66.46 % step_size : 0.0426
# 481600 Samples. Acceptance Rate:  55.05 % step_size : 0.0166
# 481700 Samples. Acceptance Rate:  66.76 % step_size : 0.0358
# 481800 Samples. Acceptance Rate:  56.90 % step_size : 0.0161
# 481900 Samples. Acceptance Rate:  62.60 % step_size : 0.0166
# 482000 Samples. Acceptance Rate:  61.29 % step_size : 0.0149
# 482100 Samples. Acceptance Rate:  64.73 % step_size : 0.0245
# 482200 Samples. Acceptance Rate:  62.34 % step_size : 0.0286
# 482300 Samples. Acceptance Rate:  60.33 % step_size : 0.0229
# 482400 Samples. Acceptance Rate:  61.09 % step_size : 0.0198
# 482500 Samples. Acceptance Rate:  63.63 % step_size : 0.0257
# 482600 Samples. Acceptance Rate:  61.23 % step_size : 0.0208
# 482700 Samples. Acceptance Rate:  62.58 % step_size : 0.0224
# 482800 Samples. Acceptance Rate:  64.66 % step_size : 0.0340
# 482900 Samples. Acceptance Rate:  60.38 % step_size : 0.0260
# 483000 Samples. Acceptance Rate:  61.06 % step_size : 0.0222
# 483100 Samples. Acceptance Rate:  62.06 % step_size : 0.0228
# 483200 Samples. Acceptance Rate:  61.97 % step_size : 0.0204
# 483300 Samples. Acceptance Rate:  59.70 % step_size : 0.0117
# 483400 Samples. Acceptance Rate:  61.62 % step_size : 0.0138
# 483500 Samples. Acceptance Rate:  63.61 % step_size : 0.0201
# 483600 Samples. Acceptance Rate:  61.08 % step_size : 0.0152
# 483700 Samples. Acceptance Rate:  61.48 % step_size : 0.0154
# 483800 Samples. Acceptance Rate:  62.38 % step_size : 0.0213
# 483900 Samples. Acceptance Rate:  60.80 % step_size : 0.0169
# 484000 Samples. Acceptance Rate:  64.79 % step_size : 0.0273
# 484100 Samples. Acceptance Rate:  62.30 % step_size : 0.0264
# 484200 Samples. Acceptance Rate:  60.89 % step_size : 0.0228
# 484300 Samples. Acceptance Rate:  61.07 % step_size : 0.0200
# 484400 Samples. Acceptance Rate:  63.94 % step_size : 0.0268
# 484500 Samples. Acceptance Rate:  60.95 % step_size : 0.0239
# 484600 Samples. Acceptance Rate:  61.84 % step_size : 0.0226
# 484700 Samples. Acceptance Rate:  61.81 % step_size : 0.0207
# 484800 Samples. Acceptance Rate:  59.97 % step_size : 0.0134
# 484900 Samples. Acceptance Rate:  63.54 % step_size : 0.0192
# 485000 Samples. Acceptance Rate:  63.99 % step_size : 0.0260
# 485100 Samples. Acceptance Rate:  61.27 % step_size : 0.0240
# 485200 Samples. Acceptance Rate:  61.87 % step_size : 0.0238
# 485300 Samples. Acceptance Rate:  62.19 % step_size : 0.0245
# 485400 Samples. Acceptance Rate:  61.49 % step_size : 0.0214
# 485500 Samples. Acceptance Rate:  62.91 % step_size : 0.0238
# 485600 Samples. Acceptance Rate:  60.00 % step_size : 0.0160
# 485700 Samples. Acceptance Rate:  63.69 % step_size : 0.0224
# 485800 Samples. Acceptance Rate:  60.44 % step_size : 0.0158
# 485900 Samples. Acceptance Rate:  61.45 % step_size : 0.0140
# 486000 Samples. Acceptance Rate:  64.47 % step_size : 0.0237
# 486100 Samples. Acceptance Rate:  62.89 % step_size : 0.0274
# 486200 Samples. Acceptance Rate:  61.61 % step_size : 0.0236
# 486300 Samples. Acceptance Rate:  63.46 % step_size : 0.0289
# 486400 Samples. Acceptance Rate:  60.86 % step_size : 0.0264
# 486500 Samples. Acceptance Rate:  61.11 % step_size : 0.0220
# 486600 Samples. Acceptance Rate:  60.20 % step_size : 0.0163
# 486700 Samples. Acceptance Rate:  61.24 % step_size : 0.0134
# 486800 Samples. Acceptance Rate:  62.79 % step_size : 0.0183
# 486900 Samples. Acceptance Rate:  62.17 % step_size : 0.0160
# 487000 Samples. Acceptance Rate:  63.94 % step_size : 0.0229
# 487100 Samples. Acceptance Rate:  63.47 % step_size : 0.0284
# 487200 Samples. Acceptance Rate:  60.67 % step_size : 0.0222
# 487300 Samples. Acceptance Rate:  62.37 % step_size : 0.0236
# 487400 Samples. Acceptance Rate:  61.84 % step_size : 0.0236
# 487500 Samples. Acceptance Rate:  61.62 % step_size : 0.0243
# 487600 Samples. Acceptance Rate:  62.88 % step_size : 0.0296
# 487700 Samples. Acceptance Rate:  61.57 % step_size : 0.0267
# 487800 Samples. Acceptance Rate:  62.01 % step_size : 0.0255
# 487900 Samples. Acceptance Rate:  61.23 % step_size : 0.0248
# 488000 Samples. Acceptance Rate:  60.07 % step_size : 0.0193
# 488100 Samples. Acceptance Rate:  61.71 % step_size : 0.0175
# 488200 Samples. Acceptance Rate:  61.83 % step_size : 0.0152
# 488300 Samples. Acceptance Rate:  62.74 % step_size : 0.0183
# 488400 Samples. Acceptance Rate:  63.68 % step_size : 0.0261
# 488500 Samples. Acceptance Rate:  61.77 % step_size : 0.0256
# 488600 Samples. Acceptance Rate:  61.67 % step_size : 0.0264
# 488700 Samples. Acceptance Rate:  61.67 % step_size : 0.0245
# 488800 Samples. Acceptance Rate:  61.04 % step_size : 0.0196
# 488900 Samples. Acceptance Rate:  62.21 % step_size : 0.0217
# 489000 Samples. Acceptance Rate:  61.82 % step_size : 0.0202
# 489100 Samples. Acceptance Rate:  64.13 % step_size : 0.0253
# 489200 Samples. Acceptance Rate:  61.37 % step_size : 0.0233
# 489300 Samples. Acceptance Rate:  61.66 % step_size : 0.0218
# 489400 Samples. Acceptance Rate:  61.48 % step_size : 0.0213
# 489500 Samples. Acceptance Rate:  62.88 % step_size : 0.0234
# 489600 Samples. Acceptance Rate:  62.47 % step_size : 0.0247
# 489700 Samples. Acceptance Rate:  61.51 % step_size : 0.0225
# 489800 Samples. Acceptance Rate:  62.74 % step_size : 0.0239
# 489900 Samples. Acceptance Rate:  60.24 % step_size : 0.0193
# 490000 Samples. Acceptance Rate:  61.85 % step_size : 0.0174
# 490100 Samples. Acceptance Rate:  63.86 % step_size : 0.0232
# 490200 Samples. Acceptance Rate:  62.26 % step_size : 0.0228
# 490300 Samples. Acceptance Rate:  60.03 % step_size : 0.0152
# 490400 Samples. Acceptance Rate:  63.97 % step_size : 0.0215
# 490500 Samples. Acceptance Rate:  62.67 % step_size : 0.0236
# 490600 Samples. Acceptance Rate:  62.07 % step_size : 0.0251
# 490700 Samples. Acceptance Rate:  60.35 % step_size : 0.0181
# 490800 Samples. Acceptance Rate:  62.70 % step_size : 0.0211
# 490900 Samples. Acceptance Rate:  60.61 % step_size : 0.0172
# 491000 Samples. Acceptance Rate:  62.48 % step_size : 0.0218
# 491100 Samples. Acceptance Rate:  62.29 % step_size : 0.0198
# 491200 Samples. Acceptance Rate:  63.32 % step_size : 0.0249
# 491300 Samples. Acceptance Rate:  59.53 % step_size : 0.0135
# 491400 Samples. Acceptance Rate:  64.22 % step_size : 0.0202
# 491500 Samples. Acceptance Rate:  60.89 % step_size : 0.0148
# 491600 Samples. Acceptance Rate:  64.46 % step_size : 0.0224
# 491700 Samples. Acceptance Rate:  62.24 % step_size : 0.0230
# 491800 Samples. Acceptance Rate:  62.19 % step_size : 0.0259
# 491900 Samples. Acceptance Rate:  61.52 % step_size : 0.0235
# 492000 Samples. Acceptance Rate:  61.41 % step_size : 0.0229
# 492100 Samples. Acceptance Rate:  63.24 % step_size : 0.0263
# 492200 Samples. Acceptance Rate:  61.20 % step_size : 0.0250
# 492300 Samples. Acceptance Rate:  59.91 % step_size : 0.0177
# 492400 Samples. Acceptance Rate:  63.06 % step_size : 0.0228
# 492500 Samples. Acceptance Rate:  61.28 % step_size : 0.0226
# 492600 Samples. Acceptance Rate:  61.22 % step_size : 0.0195
# 492700 Samples. Acceptance Rate:  63.19 % step_size : 0.0246
# 492800 Samples. Acceptance Rate:  60.50 % step_size : 0.0184
# 492900 Samples. Acceptance Rate:  62.24 % step_size : 0.0188
# 493000 Samples. Acceptance Rate:  61.17 % step_size : 0.0147
# 493100 Samples. Acceptance Rate:  64.70 % step_size : 0.0240
# 493200 Samples. Acceptance Rate:  63.45 % step_size : 0.0300
# 493300 Samples. Acceptance Rate:  59.53 % step_size : 0.0179
# 493400 Samples. Acceptance Rate:  64.21 % step_size : 0.0268
# 493500 Samples. Acceptance Rate:  63.07 % step_size : 0.0297
# 493600 Samples. Acceptance Rate:  60.01 % step_size : 0.0248
# 493700 Samples. Acceptance Rate:  62.52 % step_size : 0.0271
# 493800 Samples. Acceptance Rate:  62.27 % step_size : 0.0286
# 493900 Samples. Acceptance Rate:  58.39 % step_size : 0.0161
# 494000 Samples. Acceptance Rate:  60.53 % step_size : 0.0132
# 494100 Samples. Acceptance Rate:  62.00 % step_size : 0.0132
# 494200 Samples. Acceptance Rate:  61.66 % step_size : 0.0100
# 494300 Samples. Acceptance Rate:  61.71 % step_size : 0.0088
# 494400 Samples. Acceptance Rate:  61.28 % step_size : 0.0082
# 494500 Samples. Acceptance Rate:  62.21 % step_size : 0.0094
# 494600 Samples. Acceptance Rate:  61.88 % step_size : 0.0097
# 494700 Samples. Acceptance Rate:  61.98 % step_size : 0.0101
# 494800 Samples. Acceptance Rate:  61.88 % step_size : 0.0108
# 494900 Samples. Acceptance Rate:  62.69 % step_size : 0.0140
# 495000 Samples. Acceptance Rate:  61.29 % step_size : 0.0123
# 495100 Samples. Acceptance Rate:  62.50 % step_size : 0.0153
# 495200 Samples. Acceptance Rate:  63.66 % step_size : 0.0225
# 495300 Samples. Acceptance Rate:  60.90 % step_size : 0.0193
# 495400 Samples. Acceptance Rate:  61.31 % step_size : 0.0172
# 495500 Samples. Acceptance Rate:  61.74 % step_size : 0.0165
# 495600 Samples. Acceptance Rate:  63.64 % step_size : 0.0232
# 495700 Samples. Acceptance Rate:  60.15 % step_size : 0.0184
# 495800 Samples. Acceptance Rate:  63.88 % step_size : 0.0239
# 495900 Samples. Acceptance Rate:  60.82 % step_size : 0.0200
# 496000 Samples. Acceptance Rate:  63.02 % step_size : 0.0227
# 496100 Samples. Acceptance Rate:  63.01 % step_size : 0.0254
# 496200 Samples. Acceptance Rate:  61.14 % step_size : 0.0206
# 496300 Samples. Acceptance Rate:  63.01 % step_size : 0.0258
# 496400 Samples. Acceptance Rate:  61.39 % step_size : 0.0234
# 496500 Samples. Acceptance Rate:  61.99 % step_size : 0.0247
# 496600 Samples. Acceptance Rate:  59.08 % step_size : 0.0140
# 496700 Samples. Acceptance Rate:  62.06 % step_size : 0.0152
# 496800 Samples. Acceptance Rate:  63.85 % step_size : 0.0239
# 496900 Samples. Acceptance Rate:  61.33 % step_size : 0.0207
# 497000 Samples. Acceptance Rate:  62.05 % step_size : 0.0204
# 497100 Samples. Acceptance Rate:  63.00 % step_size : 0.0239
# 497200 Samples. Acceptance Rate:  60.38 % step_size : 0.0162
# 497300 Samples. Acceptance Rate:  62.62 % step_size : 0.0192
# 497400 Samples. Acceptance Rate:  62.41 % step_size : 0.0236
# 497500 Samples. Acceptance Rate:  61.04 % step_size : 0.0209
# 497600 Samples. Acceptance Rate:  61.98 % step_size : 0.0195
# 497700 Samples. Acceptance Rate:  60.50 % step_size : 0.0150
# 497800 Samples. Acceptance Rate:  62.67 % step_size : 0.0171
# 497900 Samples. Acceptance Rate:  63.51 % step_size : 0.0235
# 498000 Samples. Acceptance Rate:  61.54 % step_size : 0.0237
# 498100 Samples. Acceptance Rate:  59.67 % step_size : 0.0153
# 498200 Samples. Acceptance Rate:  61.12 % step_size : 0.0133
# 498300 Samples. Acceptance Rate:  61.83 % step_size : 0.0151
# 498400 Samples. Acceptance Rate:  62.05 % step_size : 0.0168
# 498500 Samples. Acceptance Rate:  63.42 % step_size : 0.0224
# 498600 Samples. Acceptance Rate:  61.50 % step_size : 0.0196
# 498700 Samples. Acceptance Rate:  62.96 % step_size : 0.0232
# 498800 Samples. Acceptance Rate:  61.80 % step_size : 0.0245
# 498900 Samples. Acceptance Rate:  62.24 % step_size : 0.0244
# 499000 Samples. Acceptance Rate:  61.87 % step_size : 0.0219
# 499100 Samples. Acceptance Rate:  60.72 % step_size : 0.0160
# 499200 Samples. Acceptance Rate:  64.77 % step_size : 0.0251
# 499300 Samples. Acceptance Rate:  61.61 % step_size : 0.0228
# 499400 Samples. Acceptance Rate:  63.55 % step_size : 0.0278
# 499500 Samples. Acceptance Rate:  60.37 % step_size : 0.0225
# 499600 Samples. Acceptance Rate:  62.38 % step_size : 0.0229
# 499700 Samples. Acceptance Rate:  59.41 % step_size : 0.0130
# 499800 Samples. Acceptance Rate:  65.65 % step_size : 0.0285
# 499900 Samples. Acceptance Rate:  60.23 % step_size : 0.0207
# 500000 Samples. Acceptance Rate:  61.36 % step_size : 0.0195

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 117.31 min

# %% [markdown]
# To check whether the HMC sampler has converged, we plot all the traceplot for all 16 params as follows:

# %%
for i in range(16):
    plt.plot(samples_nn_HMC_converge[:,i], alpha = 0.3);

# %% [markdown]
# From the plot above we can see that, we have made sure that almost all parameters have converged. Then we plot the picture to visualization the uncertainty:

# %%
np.random.seed(2019)
n_sample = 100
sample_indices = np.random.choice(np.arange(len(samples_nn_HMC_converge)), n_sample)
sample = samples_nn_HMC_converge[sample_indices]

x_test = np.linspace(-8, 8, 100)
y_test_bnn = nn.forward(sample, x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, 0.5, size = (100, 100))

# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |HMC (Original Dimension)')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|HMC (Original Dimension)')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %% [markdown]
# From the plots above, we can see that the one from full parameter space has clearly revealed both aleatoric and epistemic uncertainty.
#
# Comparing with the one we got from subspace inference (especially from the one with PCA subspace), we can see that:</br>
# <br>
# <br>**A. Inference on subspace has dramatically reduced the computation cost**
#
# |Method|Total (sec)|
# |---------------|----------------|
# |Random Subspace |644.51|
# |PCA Subspace |542.33|
# |Curve Subspace |507.02|
# |Full params space|7038.6|
#
# The table above compares the total sections needed for all methods combined with HMC inference. From the table above we can see that, to achieve a converged status, inference on full parameter space is 12 times larger than inference in subspace.
#
# <br>**B. Inference on subspace also reveals meaningful uncertainty information in visualization**
# ![Full space comparison](https://i.ibb.co/zQFKS7G/Fullspace.png)
#
#
# From the plots above we can see that, although subspace inference is still not as good as inference from the full parameter space, both of the plots has clearly revealed both kinds of certainties and provide useful information:
# - They have relatively thin uncertainty when there are some data points, where the interval here contains more the aleatoric uncertainty, which is representative of unknowns that could not be reduced by getting more data.
# - By contrast, they have relatively fat uncertainty interval when there are less data points, which is the representative of epistemic uncertainty and could be reduced by getting more data. Since we can reduce epistemic uncertainty by getting more data but can not easily tackle with aleatoric uncertainty, we prefer epistemic uncertainty than aleatoric uncertainty.
#
# **Therefore, we can draw the conclusion that the subspace inference methods documented in paper are both effective and efficient for Bayesian Deep Learning.**

# %% [markdown]
# #### 4.3.2. Deep and Wide difference
# - Queena results
#
# #### 4.3.3. Different initialization
# start with non_train.weights vs not.

# %% [markdown]
# #### 4.3.4. PCA variant
# In paper, the deviation matrix is updated during equal epoch intervals. However, to construct a more precise subspace, it's natural for us to have the hypothesis that forming the projection matrix $P$ with the PCA component of the smallest deviation could be better than that of the equal-interval deviations.
#
# To formulate the hypothesis, we define the expressions as follows:
# <br>$w0$: pretrained weights;
# <br>$\eta$: learning rate;
# <br>$T$: number of steps;
# <br>$c$: moment update frequency;
# <br>$M$: maximum number of columns in deviation matrix;
# <br>$K$: rank of PCA approximation;
# <br>$A$: deviation matrix;
# <br>$P$: projection matrix for subspace
#
#
# The original algorithm to construct subspace with PCA goes as follows:
#
# <p style="text-align: right">step0 [Initialize mean] </p>
# <br>$w_{SWA} \leftarrow w_0$
# <p style="text-align: right">step1 [SGD Update]</p>
# <br>for $i\leftarrow1,2,\cdots, T \text{ do}$
# <br>$\quad$ $w_i \leftarrow w_{i-1} - \eta \nabla_{w}\mathcal{L}(w_{i-1})$
# <p style="text-align: right">step2 [SWA Update]</p>
# <br>$\quad$ if MOD$(i,c)=0$ then
# <br>$\quad\quad$ $n\leftarrow i/c$
# <br>$\quad\quad$ $w_{SWA}\leftarrow \frac{nw_{SWA} + w_i}{n+1}$
# <p style="text-align: right">step3 [devation matrix Update]</p>
# <br>$\quad\quad$ if NUM_COLS($A$) = $M$ then
# <br>$\quad\quad\quad$ REMOVE_COL($A$[:,1])
# <br>$\quad\quad$ APPEND_COLS($A$, $w_i - \bar{w}$)
# <p style="text-align: right">step4 [Truncated SVD]</p>
# <br>$U,S,V^{T}\leftarrow SVD(A)$
# <br>return $\hat{w} = w_{SWA}$, $P = SV^T$
#
# In our algorithm, we construct the deviation matrix with the smallest $M$ deviations. The main difference betweem our algorithm and the paper lies in step3 (deviation matrix update process). One difficulty of our algorithm is how to find the minimum $M$ deviations with an efficient use of memory. That is to say, if we first store all possible devations in a matrix and then pick the smallest deviations, there will be a high demand for memory which makes our algorithm hard to scale up. Therefore, we come up with a training in on-line fashion, that is to construct a matrix which stores the smallest $M$ deviations so far and keep updating the matrix when new deviations come in. Under this method, the maximum of the use of memory is $M$, which is the same as theirs. To be more specific, our algorithm goes as below:
# <p style="text-align: right">step0 [Initialize mean] </p>
# <br>$w_{SWA} \leftarrow w_0$
# <p style="text-align: right">step1 [SGD Update]</p>
# <br>for $i\leftarrow1,2,\cdots, T \text{ do}$
# <br>$\quad$ $w_i \leftarrow w_{i-1} - \eta \nabla_{w}\mathcal{L}(w_{i-1})$
# <p style="text-align: right">step2 [SWA Update]</p>
# <br>$\quad$ if MOD$(i,c)=0$ then
# <br>$\quad\quad$ $n\leftarrow i/c$
# <br>$\quad\quad$ $w_{SWA}\leftarrow \frac{nw_{SWA} + w_i}{n+1}$
# <p style="text-align: right"><b>step3 [devation matrix Update]</b></p>
# <br>$\quad\quad$ if NUM_COLS($A$) = $M$ then
# <br>$\quad\quad\quad$ if norm($w_i - \bar{w}$) < norm(A[:,-1]) then
# <br>$\quad\quad\quad\quad$ REMOVE_COL($A$[:,-1])
# <br>$\quad\quad\quad\quad$ APPEND_COLS($A$, $w_i - \bar{w}$)
# <br>$\quad\quad\quad\quad$ SORT_BY_NORM($A$, ascending=True)
# <br>$\quad\quad$ else:
# <br>$\quad\quad\quad$ APPEND_COLS($A$, $w_i - \bar{w}$)
# <br>$\quad\quad\quad$ SORT_BY_NORM($A$, ascending=True)
# <p style="text-align: right">step4 [Truncated SVD]</p>
# <br>$U,S,V^{T}\leftarrow SVD(A)$
# <br>return $\hat{w} = w_{SWA}$, $P = SV^T$

# %%
my_subspace = Subspace.create(subspace_type="pca", model=my_nn, n_subspace=2)
my_subspace.collect_vector(X=x, y=y, method='S') # chose the method as L
P, w = my_subspace.get_space()

# %%
hmc_tune_params={'step_size':5e-2,
                'leapfrog_steps': 10,
                'total_samples': 20000,
                'burn_in': 0.2,
                'warm_start': True,
                'thinning_factor': 2,
                'mom_std': 1,
                'diagnostic_mode': False}

# %%
my_inference = Inference.create(inference_type="HMC", model=my_nn, P=P, w_hat=w,  tune_params=hmc_tune_params,
                               Sigma_Z=5)

# get initial weights (in subspace dimension!!)
position_init = my_nn.get_z_from_W(weights=my_nn.weights, P=my_inference.P, w_hat=my_inference.w_hat)

# %%
begin=time.time()
my_inference.train(X=x, y=y, warm_start=False, position_init=position_init)
end=time.time()
# Out:
# HMC 200: accept rate of 100.0 with step size 0.05
# HMC 400: accept rate of 100.0 with step size 0.05149605792925664
# HMC 600: accept rate of 100.0 with step size 0.05299605792925664
# HMC 800: accept rate of 99.875 with step size 0.054496057929256644
# HMC 1000: accept rate of 99.8 with step size 0.055996057929256646
# HMC 1200: accept rate of 99.83333333333333 with step size 0.0574947659062378
# HMC 1400: accept rate of 99.85714285714286 with step size 0.05898888637377429
# HMC 1600: accept rate of 99.875 with step size 0.06048835268356851
# HMC 1800: accept rate of 99.8888888888889 with step size 0.06198835268356851
# HMC 2000: accept rate of 99.9 with step size 0.0634883526835685
# HMC 2200: accept rate of 99.90909090909092 with step size 0.06497280104637061
# HMC 2400: accept rate of 99.91666666666667 with step size 0.06647280104637061
# HMC 2600: accept rate of 99.92307692307692 with step size 0.06796592043713326
# HMC 2800: accept rate of 99.92857142857143 with step size 0.06946380836921373
# HMC 3000: accept rate of 99.9 with step size 0.0709560305975279
# HMC 3200: accept rate of 99.90625 with step size 0.0724560305975279
# HMC 3400: accept rate of 99.91176470588236 with step size 0.07395603059752791
# HMC 3600: accept rate of 99.91666666666667 with step size 0.07545555293115049
# HMC 3800: accept rate of 99.92105263157895 with step size 0.0769533850693078
# HMC 200: accept rate of 100.0
# HMC 400: accept rate of 100.0
# HMC 600: accept rate of 100.0
# HMC 800: accept rate of 100.0
# HMC 1000: accept rate of 100.0
# HMC 1200: accept rate of 100.0
# HMC 1400: accept rate of 99.85714285714286
# HMC 1600: accept rate of 99.8125
# HMC 1800: accept rate of 99.83333333333333
# HMC 2000: accept rate of 99.85
# HMC 2200: accept rate of 99.81818181818181
# HMC 2400: accept rate of 99.83333333333333
# HMC 2600: accept rate of 99.84615384615384
# HMC 2800: accept rate of 99.85714285714286
# HMC 3000: accept rate of 99.86666666666666
# HMC 3200: accept rate of 99.875
# HMC 3400: accept rate of 99.88235294117646
# HMC 3600: accept rate of 99.88888888888889
# HMC 3800: accept rate of 99.86842105263158
# HMC 4000: accept rate of 99.85
# HMC 4200: accept rate of 99.85714285714286
# HMC 4400: accept rate of 99.8409090909091
# HMC 4600: accept rate of 99.82608695652173
# HMC 4800: accept rate of 99.8125
# HMC 5000: accept rate of 99.82
# HMC 5200: accept rate of 99.8076923076923
# HMC 5400: accept rate of 99.81481481481481
# HMC 5600: accept rate of 99.82142857142857
# HMC 5800: accept rate of 99.8103448275862
# HMC 6000: accept rate of 99.81666666666666
# HMC 6200: accept rate of 99.8225806451613
# HMC 6400: accept rate of 99.8125
# HMC 6600: accept rate of 99.81818181818181
# HMC 6800: accept rate of 99.80882352941177
# HMC 7000: accept rate of 99.77142857142857
# HMC 7200: accept rate of 99.76388888888889
# HMC 7400: accept rate of 99.75675675675676
# HMC 7600: accept rate of 99.76315789473684
# HMC 7800: accept rate of 99.75641025641026
# HMC 8000: accept rate of 99.7625
# HMC 8200: accept rate of 99.76829268292683
# HMC 8400: accept rate of 99.77380952380952
# HMC 8600: accept rate of 99.75581395348837
# HMC 8800: accept rate of 99.73863636363636
# HMC 9000: accept rate of 99.73333333333333
# HMC 9200: accept rate of 99.70652173913044
# HMC 9400: accept rate of 99.70212765957447
# HMC 9600: accept rate of 99.6875
# HMC 9800: accept rate of 99.6938775510204
# HMC 10000: accept rate of 99.7
# HMC 10200: accept rate of 99.70588235294117
# HMC 10400: accept rate of 99.70192307692308
# HMC 10600: accept rate of 99.70754716981132
# HMC 10800: accept rate of 99.71296296296296
# HMC 11000: accept rate of 99.66363636363636
# HMC 11200: accept rate of 99.66964285714286
# HMC 11400: accept rate of 99.67543859649123
# HMC 11600: accept rate of 99.68103448275862
# HMC 11800: accept rate of 99.6864406779661
# HMC 12000: accept rate of 99.69166666666666
# HMC 12200: accept rate of 99.69672131147541
# HMC 12400: accept rate of 99.70161290322581
# HMC 12600: accept rate of 99.7063492063492
# HMC 12800: accept rate of 99.6953125
# HMC 13000: accept rate of 99.6923076923077
# HMC 13200: accept rate of 99.68939393939394
# HMC 13400: accept rate of 99.69402985074628
# HMC 13600: accept rate of 99.69852941176471
# HMC 13800: accept rate of 99.69565217391305
# HMC 14000: accept rate of 99.7
# HMC 14200: accept rate of 99.69718309859155
# HMC 14400: accept rate of 99.70138888888889
# HMC 14600: accept rate of 99.70547945205479
# HMC 14800: accept rate of 99.70945945945945
# HMC 15000: accept rate of 99.70666666666666
# HMC 15200: accept rate of 99.70394736842105
# HMC 15400: accept rate of 99.7012987012987
# HMC 15600: accept rate of 99.7051282051282
# HMC 15800: accept rate of 99.70886075949367
# HMC 16000: accept rate of 99.70625
# HMC 16200: accept rate of 99.70987654320987
# HMC 16400: accept rate of 99.71341463414635
# HMC 16600: accept rate of 99.71084337349397
# HMC 16800: accept rate of 99.71428571428571
# HMC 17000: accept rate of 99.71176470588236
# HMC 17200: accept rate of 99.71511627906976
# HMC 17400: accept rate of 99.71264367816092
# HMC 17600: accept rate of 99.7159090909091
# HMC 17800: accept rate of 99.71348314606742
# HMC 18000: accept rate of 99.71111111111111
# HMC 18200: accept rate of 99.71428571428571
# HMC 18400: accept rate of 99.71739130434783
# HMC 18600: accept rate of 99.72043010752688
# HMC 18800: accept rate of 99.72340425531915
# HMC 19000: accept rate of 99.72631578947369
# HMC 19200: accept rate of 99.72916666666667
# HMC 19400: accept rate of 99.73195876288659
# HMC 19600: accept rate of 99.72448979591837
# HMC 19800: accept rate of 99.72727272727273

# %%
print('It costs {:.2f} min'.format((end-begin)/60))
# Out:
# It costs 10.91 min

# %%
# get posterior z
n_sample = 100
post_sample = my_inference.get_posterior(n_samples=n_sample)
x_test = np.linspace(-8, 8, 100)
y_test_bnn = my_nn.forward(P=P, w_hat=w,z=post_sample, X=x_test.reshape((1, -1))).reshape(100, 100) + np.random.normal(0, my_nn.Sigma_Y_det, size = (100, 100))

# %%
# plot
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.grid()
plt.title('Posterior Predictive of Bayesian NN |HMC')
# plt.ylim(-15, 15)
for i in range(n_sample):
    plt.plot(x_test, y_test_bnn[i], color='red', alpha=max(1 / n_sample, 0.1))
plt.scatter(x, y, color='black', label='data')
plt.legend()
plt.subplot(1, 2, 2)
plt.scatter(x, y, color='black')
plt.plot(x_test, y_test_bnn.mean(0), color='red', label='posterior predictive mean')
plt.fill_between(x_test, np.percentile(y_test_bnn, 0.25, axis=0), np.percentile(y_test_bnn, 97.5, axis=0),
                 color='red', label='95% CI', alpha=0.5)
plt.legend(loc='best')
plt.title('Posterior Predictive of Bayesian NN with 95% CI|HMC')
plt.grid()
# plt.ylim(-15, 15)
plt.show()

# %% [markdown]
# We also plotted the traceplots to check the convergence.

# %%
post_sample=my_inference.get_posterior(n_samples=10000)
fig, ax = plt.subplots(1, 2, figsize=(15, 4))
for i in range(my_inference.D_z):
#     row = 1
    col = i % 2
    ax[col].plot(range(len(post_sample)), post_sample[:, i], color='gray', alpha=0.7)
fig.suptitle('Trace plots for all neural network parameters')
plt.show()

# %% [markdown]
# From the traceplot above, it seems that the HMC sampler has already converged.

# %%
y_pred= my_nn.forward(P=P, w_hat=w,z=post_sample, X=x.reshape((1, -1))).reshape(-1, x.shape[-1])
log_lkhd_pca_smallest = log_likelihood(y, y_pred)
print('The Posterior Predictive Log likelihood of the observed data is {0:6.4f}'.format(log_lkhd_pca_smallest))
# Out:
# The Posterior Predictive Log likelihood of the observed data is -4.7667

# %% [markdown]
# From the test statistics above we can see that PCA with our extension of the smallest deviations (log likelihood: -4.7667) does a job as good as the PCA with equal interval published in the paper (log likelihood: -4.3521). However from the posterior predictive plots above, PCA with equal interval is more informative. We also tested it with BBB sampler and gets a similar result with a pretty good log likelihood (-2.9177) but a quite un-informative uncertainty visualization plot:
#
# ![pca_smallest](https://i.ibb.co/92VYMCy/pca-smallest-BBB.png)
#
# After careful analysis, we think this phenomenon is due to the fact that the deviation matrix actually contains little useful information in constructing the subspace. Following this analysis, PCA with largest deviations would also do a bad job in revealing the uncertainty but in an opposite way: it will widen the uncertainty bound as it captures more unrelevant information in constructing subspace by constrast. The experiment results below strongly support our hypothesis.
#
# ![pca_smallest](https://i.ibb.co/mb817dM/pca-largest.png)

# %% [markdown]
# **From the exploration of PCA variants we have deepened our understanding in how the deviation matrix affects the uncertaintly visualization at the end.**
# - If the matrix contains little useful information, it will give a conservative picture of the uncertainty. Specifically, it prones to provide a narrower uncertainty boundary and does not distinguish the 2 kinds of uncertainties clearly.
# - If the matrix contains much unrelevant information, it will overestimate the uncertainty and widen the uncertainty boundary inappropriately.
#
# Therefore, the size of the norm in deviation matrix is not the key to improve the PCA performance. What might be promising is to take snapshot of every local minima of the weights and record its corresponding deviation.

# %% [markdown]
# ## 5. Future Work
#
# 1. From the analysis in **4.3.4. PCA variant**, we believe that instead of take every T steps of the weights, taking snapshot of every local minima of the weights and record its corresponding deviation to update the deviation matrix could be promising in improving the performance.
